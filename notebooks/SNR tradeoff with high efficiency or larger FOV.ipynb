# %% [markdown]
# # Signal-to-noise tradeoff with high efficiency (larger FOV)

# %%
from matplotlib import pyplot as plt
import numpy as np
from scipy.special import jv, kv
from scipy.special import j1 # Bessel function of the first kind of order 1, for the diffraction pattern calculation
from scipy.optimize import root_scalar
from scipy.constants import c, epsilon_0, mu_0, pi
import scipy.integrate as integrate

# %%
# jn_zeros is a function that returns the zeros of the Bessel function of the first kind, 
# which are needed to find the roots for the LP01 mode in a step-index fibre
from scipy.special import jn_zeros  # NEW: needed to get the first zero of J0

# %%
from scipy.optimize import brentq
# The Brent's method is a root-finding algorithm that combines the bisection method, the secant method, and 
# inverse quadratic interpolation. 
# https://en.wikipedia.org/wiki/Brent%27s_method
# It is designed to find roots of a continuous function within a specified interval where the function changes
#  sign. The method is efficient and robust, making it suitable for finding roots of nonlinear equations.

# %%
min?
# Out:
# Docstring:
# min(iterable, *[, default=obj, key=func]) -> value
# min(arg1, arg2, *args, *[, key=func]) -> value
#
# With a single iterable argument, return its smallest item. The
# default keyword-only argument specifies an object to return if
# the provided iterable is empty.
# With two or more arguments, return the smallest argument.
# Type:      builtin_function_or_method

# %%
jn_zeros(0, 1)[0]
# Out:
# np.float64(2.404825557695773)

# %%
# # Given the X and Y roots for the LP01 mode from previous calculations
# X_root = 1.5590595758091075
# Y_root = 1.3985078062014993

def function_LP01(X, V):
    ""
    # Calculate Y based on the relationship Y^2 = V^2 - X^2
    Y = np.sqrt(V**2 - X**2)
    # Calculate the left-hand side and right-hand side of the equation using the Bessel functions
    lhs = X * jv(1, X) / jv(0, X)
    rhs = Y * kv(1, Y) / kv(0, Y)
    return lhs - rhs

def find_root_LP01(V, X_min, X_max):
    # Define a lambda function that takes X as input and uses the previously defined function f with the 
    # fixed V value. This allows us to use this function for root finding.
    function_m1 = lambda X: function_LP01(X, V)

    # NEW: restrict X_max to the first zero of J0 so we stay on the LP01 branch
    X_max = min(X_max, jn_zeros(0, 1)[0] - 1e-8)

    print(f'X_max restricted to {X_max:.6f} to stay on the LP01 branch')

    X_scan = np.linspace(X_min, X_max, 5000)
    F_scan = function_m1(X_scan) # Evaluate the function at the scan points

    bracket = None

    # We take length of scan - 1 because we are checking pairs of points for sign changes, 
    # -1 means we won't go out of bounds when checking F_scan[i + 1]
    for i in range(len(X_scan) - 1): # Loop through the length-1 of X_scan to find a sign change
        if F_scan[i] * F_scan[i + 1] < 0: # Check for a sign change
            x1 = X_scan[i]
            x2 = X_scan[i + 1]
            f1 = F_scan[i]
            f2 = F_scan[i + 1]

            # Skip non-finite values
            if not np.isfinite(f1) or not np.isfinite(f2):
                continue

            # sign chage detected between x1 and x2, we can use this as a bracket for root finding
            if f1*f2 < 0:
                bracket = (x1, x2) # Store the bracket where the sign change occurs
                break # Exit the loop after finding the first sign change

    if bracket is None:
        raise ValueError(f"No valid bracket found for V = {V:.6f}")

    X_root = brentq(function_m1, bracket[0], bracket[1]) # Use the found bracket for root finding
    Y_root = np.sqrt(V**2 - X_root**2)
    return X_root, Y_root

# %%
def calculate_electric_field(rho, X_root, Y_root):
    """ 
    Define a function to calculate the electric field distribution across the fibre 
    cross-section based on the roots found from the Bessel function equations. This function 
    will compute the electric field in both the core and cladding regions, normalise it, and 
    return both the normalised electric field and its intensity profile. 

    X_root: The root of the equation for the core region, which determines the behaviour of the electric field within the core.
    Y_root: The root of the equation for the cladding region, which determines the behaviour of the electric field in the cladding.
    rho: The normalised radius array (r/a) across which we want to calculate the electric field distribution.

    """

    # Step 2 - Create an array of zeros with the same shape as rho to store the electric field values
    E = np.zeros_like(rho)

    # Step 3 - Set the condition as the boundary between core and cladding, this helps to create a piecewise function for the electric field distribution
    core = rho <= 1
    cladding = rho > 1

    # Step 4 - Compute the electric field in the core region (rho <= 1) using the ordinary Bessel function J0.
    # E[core] uses conditional (boolean) assignment directly: values are assigned only where the condition is satisfied, allowing us to implement the piecewise solution of the wave equation without using loops.
    # Physically, this corresponds to applying the core solution E(rho) = J0(X*rho) only inside the fibre core.

    E[core] = jv(0, X_root * rho[core]) # Setting A = 1, multiplied by te Bessel function of zeroth order and ratio rho inside the core

    # Step 5 - Set the matching factor at the boundary (rho=1) as J0(X) / K0(Y), this makes the cladding field connect smoothly
    match_factor = jv(0,X_root) / kv(0,Y_root) 

    # Step 6 - Compute the electric field in the cladding region (rho > 1) using the modified Bessel function K0, multiplied by the matching factor to ensure continuity at the boundary
    E[cladding] = match_factor * kv(0, Y_root * rho[cladding])

    # Step 7 - Normalise the electric field distribution so that the maximum value is 1, this allows us to compare the relative field strength across the fibre cross-section
    E_norm = E / np.max(abs(E)) 

    # Step 8 - We also compute the intensity profile of the electric field, such that I represents the intensity profile and E represents the field amplitude. 
    I = np.abs(E_norm)**2

    return E_norm, I # note they are in normalised units

# %%
def coude_diffraction_limited_E_field(r, lam0, F_focus, alpha, E_S):

    """
    Function for calculating the E-field at diffraction limited E_field, specifically for
    the Coude focus (or a focus that has a long focal length resulting in high magnification)

    r: radial coordinate in the image plane (in meters)
    lam0: wavelength of the incoming beam in vacuum (in meters)
    F_focus: focal ratio (f/#) of the Coude focus, defined as the focal length divided by the diameter of the primary mirror
    alpha: ratio of the central obstruction diameter to the primary mirror diameter, which affects the diffraction pattern and thus the E-field distribution at the focus
    E_S: amplitude of the incoming E-field, which can be set to 1 for normalisation purposes
    """

    s = np.pi * r / (lam0 * F_focus) # Normalised radial coordinate for the diffraction pattern

    # Use safe division so the s=0 limit is finite (2*J1(x)/x -> 1 as x->0)
    airy_term = np.divide(2 * j1(s), s, out=np.ones_like(s), where=s != 0)
    obstruction_term = np.divide(2 * j1(alpha * s), alpha * s, out=np.ones_like(s), where=(alpha * s) != 0)

    # The electric field of image found from  the diffraction pattern of the telescope aperture, modified by the 
    # central obstruction, multiplied by the fibre mode field distribution to get the resulting image field 
    # distribution at the fibre input. Note: zero division at centre is artificially set to 1 
    E_image = E_S * (airy_term - alpha**2 * obstruction_term)

    # Intensity of the incoming beam forming an image at the fibre input 
    I_image = np.abs(E_image)**2

    return E_image, I_image

# %%
def demagnified_diffraction_limited_E_field(r, lam0, F_focus, alpha, E_S, Magnification):
    """
    r: the radius array created, representing distance vector in the ribre radius
    
    lam0: wavelength of the light in air

    F_focus: focal ratio F=f/D at the focus

    alpha: the ratio of central obstration to primary mirror diameter

    E_S: amplitude of the E-field of image normalised (assumed) to equal to 1 here

    Magnification: different to the magnification measurement between image at the telescope 
    and focus, the Magnification here refers to the required scale of "magnification" or inverted 
    demagnification required for the re-imaging optics

    """

    s_demag = np.pi * r / (lam0 * F_focus * Magnification) # Normalised radial coordinate for the diffraction pattern after demagnification

    # Use safe division so the s=0 sample does not produce NaN
    airy_term_demag = np.divide(2 * j1(s_demag), s_demag, out=np.ones_like(s_demag), where=s_demag != 0)
    obstruction_term_demag = np.divide(2 * j1(alpha * s_demag), alpha * s_demag,
        out=np.ones_like(s_demag),
        where=(alpha * s_demag) != 0,
    )

    # The electric field of image found from the diffraction pattern of the telescope aperture, modified by the 
    # central obstruction, multiplied by the fibre mode field distribution to get the resulting image field distribution at the fibre input.
    E_image_demag = E_S * (airy_term_demag - alpha**2 * obstruction_term_demag)

    # Intensity of the incoming beam forming an image at the fibre input 
    I_image_demag = np.abs(E_image_demag)**2

    return E_image_demag, I_image_demag

# %%
# The entire radial range
def coupling_efficiency_1d(E_image_demag, E_smf, r):
    """
    Input: 
    E_image_demag: electric field of demagnified image
    E_smf: electric field of single mode fibre

    Output: 
    numerator = |∫ E_image_demag * conj(E_smf) * 2πr dr|^2
    denominator = ∫ |E_smf|^2 * 2πr dr * ∫ |E_image_demag|^2 * 2πr dr
    efficiency eta: we integrate from infinitely large radius to the centre (but here 
    instead of infinity we use the finite range of r that we have where largest r must be larger
    than cladding radius to capture the Evanescent field distribution)
    
    """
    numerator = np.abs(np.trapezoid(E_image_demag * np.conjugate(E_smf) * 2*np.pi*r, x=r))**2
    denominator = np.trapezoid(np.abs(E_smf)**2 * 2*np.pi*r, x=r) * np.trapezoid(np.abs(E_image_demag)**2 * 2*np.pi*r, x=r)
    # Calculate efficiency:
    eta = numerator / denominator

    return eta, numerator, denominator

# %%
# wavelength of beam in vacuum
lam0 = 1.5e-6 
# fibre core radius
a = 5e-6 
# numerical aperture of fibre
NA = 0.1 

# Calculate the normalised frequency (V-number) of the fibre
V = 2 * pi * (a / lam0) * NA
print(f"V-number of the fibre: {V:.2f}")
# Out:
# V-number of the fibre: 2.09

# %%
# Approximate number of modes that the fibre can support using the V-number
M = V**2 / 4
print(f"Approximate number of modes that the fibre can support: {M:.2f}")
# Out:
# Approximate number of modes that the fibre can support: 1.10

# %%
X_min = 0 + 1e-8  # slightly above 0 to avoid singularity at Y=V
X_max = V - 1e-8  # slightly less than V to avoid singularity at Y=0

X_root, Y_root = find_root_LP01(V, X_min, X_max)

print("X root =", X_root)
print("Y root =", Y_root)

# Calculate the electric field distribution for the fundamental mode (LP01) in a step-index fibre
# Step 1- Create the radius array for plotting the electric field distribution
rho = np.linspace(0, 100, 5000) # From 0 to 100 times the core radius
print(f"Radius array (rho) created with {len(rho)} points.")
# Out:
# X_max restricted to 2.094395 to stay on the LP01 branch
# X root = 1.5590595758091206
# Y root = 1.3985078062014846
# Radius array (rho) created with 5000 points.

# %%
# Calculate electric field and intensity profiles using the function 
E_smf_5micron, I_smf_5_mircron = calculate_electric_field(rho, X_root, Y_root)
print(E_smf_5micron.shape, I_smf_5_mircron.shape)
# Out:
# (5000,) (5000,)

# %%
# Define a radial grid
r = rho * a # keep in metres

# Let's assume the focal ratio f/# is 49.9, where the focal length is 399m and D=8.0m (effectively)
F_focus = 49.9

print(f"Radius range (r) in microns: {r[0] * 1e6:.2f} µm to {r[-1] * 1e6:.2f} µm")
print(f"Focal ratio (f/#) ~ {F_focus:.4f}")
# Out:
# Radius range (r) in microns: 0.00 µm to 500.00 µm
# Focal ratio (f/#) ~ 49.9000

# %% [markdown]
# Using information from ESO website: https://www.eso.org/sci/facilities/paranal/telescopes/ut/m1unit.html#:~:text=Mounting%20of%20the%20axial%20interfaces,down%20to%20sub%2Dmicron%20accuracy.

# %%
# Define the diffraction limited E-field

# Not sure how big the obstruction is, assume it's 11.1 meters in diameter 
D_M1 = 8.0 # Diameter of the primary mirror in meters
D_obstruction = 1.0 # Diameter of the central obstruction in meters
# alpha = D_obstruction / D_M1 # Ratio of the central obstruction to the primary mirror diameter

alpha = 0

# Assume E_S = 1m exactly for the amplitude of the E-field
E_S = 1

# %% [markdown]
# Using information from ESO website: https://www.eso.org/sci/facilities/paranal/telescopes/ut/m1unit.html#:~:text=Mounting%20of%20the%20axial%20interfaces,down%20to%20sub%2Dmicron%20accuracy.

# %% [markdown]
# Since we assumed a numerical aperture of $\mathrm{NA} \approx 0.1$, which corresponds to a focal ratio of approximately $F \approx 5$ using the relation $\mathrm{NA} \approx 1/(2F)$.
#
# At the VLT coudé focus, the beam has a much slower focal ratio of $F \approx 49.9$. To match the fibre acceptance, re-imaging optics are used to convert this beam to the desired injection focal ratio.
#
# The required magnification (M = output size / input size) is therefore given by the ratio of the focal ratios,
#
# $$
# M = \frac{F_{\mathrm{inj}}}{F_{\mathrm{coud\acute{e}}}} = \frac{5}{49.9} \approx 0.10,
# $$
#
# corresponding to a demagnification of approximately 10×.

# %%
F_fibre = 1 / (2 * np.tan(np.arcsin(0.1)))
F_fibre
# Out:
# np.float64(4.9749371855331)

# %%
np.tan(np.arcsin(0.1))
# Out:
# np.float64(0.10050378152592121)

# %%
# Radius of airy disk at the first minimum after demagnification
r_airy = 1.22 * lam0 * F_focus
print(f"Radius of airy disk at the first minimum: {r_airy} meters")

Magnification = F_fibre / 49.9
r_airy_demag = (1.22*lam0 * F_focus) * Magnification

print(f"Radius of airy disk at the first minimum after demagnification: {r_airy_demag} meters")
print(f"Magnification factor: {Magnification:.9f}")
# Out:
# Radius of airy disk at the first minimum: 9.131700000000001e-05 meters
# Radius of airy disk at the first minimum after demagnification: 9.104135049525573e-06 meters
# Magnification factor: 0.099698140

# %% [markdown]
# But in reality we use $\lambda F$ the diffracion scale as the size of the image, and we use this value when we are estimating the coupling and matching fibre size.

# %%
r_image_demag = (lam0 * F_focus) * Magnification

print(f"Radius of airy disk at the first minimum after demagnification: {r_image_demag} meters")
# Out:
# Radius of airy disk at the first minimum after demagnification: 7.46240577829965e-06 meters

# %%
E_image_demag, I_image_demag = demagnified_diffraction_limited_E_field(r, lam0, F_focus, alpha, E_S, Magnification)
print(E_image_demag.shape, I_image_demag.shape)
# Out:
# (5000,) (5000,)

# %%
# numerator = np.abs(np.trapezoid(E_image_demag * np.conjugate(E_smf) * 2*np.pi*r, x=r))**2
# denominator = np.trapezoid(np.abs(E_smf)**2 * 2*np.pi*r, x=r) * np.trapezoid(np.abs(E_image_demag)**2 * 2*np.pi*r, x=r)
# # Calculate efficiency:
# eta = numerator / denominator

# print(f"Coupling efficiency (eta) with demagnification: {eta:.6f}")
# print(f"Numerator: {numerator:.6e}")
# print(f"Denominator: {denominator:.6e}")

# %%
E_image_demag * np.conjugate(E_smf_5micron)
# Out:
# array([1.00000000e+00, 9.99535293e-01, 9.98142190e-01, ...,
#        1.59627185e-65, 1.49399741e-65, 1.39362194e-65], shape=(5000,))

# %%
plt.plot(r, E_image_demag * np.conjugate(E_smf_5micron))
plt.xlabel('r')
plt.ylabel('E_image_demag * np.conjugate(E_smf_5micron)')
plt.title('Coupling Efficiency')
plt.xlim(0, 50e-6) # Limit x-axis to 50 microns for better visualization
plt.show()

# %% [markdown]
# # Coupling efficiency as a functino of core radius

# %% [markdown]
# ## Efficiency as a function of core radius for SMF

# %% [markdown]
# Since V $\leq$ 2.405 for a single mode fibre, the maximum core radius for a single mode fibre would be ~5.74 $\mu m$.

# %%
V_max_single = 2.405 # The cutoff V-number for single-mode operation in a step-index fibre
a_max_single = V_max_single * lam0 / (2 * np.pi * NA)
print(f"Maximum core radius for single-mode operation: {a_max_single*1e6:.4f} microns")
# Out:
# Maximum core radius for single-mode operation: 5.7415 microns

# %%
def efficiency_vs_core_radius(core_radius_range, cladding_radius_max, lam0, NA, F_focus, alpha, E_S, Magnification):
    
    efficiency_array = np.zeros_like(core_radius_range)
    for i, a in enumerate(core_radius_range):
        V = 2 * np.pi * (a / lam0) * NA # Calculate the V-number for the given radius
        X_min = 0 + 1e-8
        X_max = V - 1e-8
        # Find the X and Y roots for the given core radius a
        X_root, Y_root = find_root_LP01(V, X_min, X_max)
        # define a normalised radius r / a, with maximum at cladding size 125/2 micron
        fibre_rho = np.linspace(0, cladding_radius_max / a, 10000) 
        fibre_r = fibre_rho * a
        # Fibre field
        E_smf, I_smf = calculate_electric_field(fibre_rho, X_root, Y_root)
        # Image field
        E_image, I_image = demagnified_diffraction_limited_E_field(fibre_r, lam0, F_focus, alpha, E_S, Magnification)

        # Calculate coupling efficiency
        eta, numerator, denominator = coupling_efficiency_1d(E_image, E_smf, r=fibre_r)
        # Store the efficiency in the array corresponding to the current core radius, using np.where 
        # to find the index where core_radius_range equals a
        efficiency_array[i] = eta

        if a==core_radius_range[0]: # plot first one for visualisation
            plt.figure(figsize=(8,4))
            plt.plot(fibre_r, E_smf, color='royalblue')
            plt.axvline(a, color='gray', linestyle='--') # Add a horizontal line at y=0 for reference
            plt.xlabel('radius (m)')
            plt.ylabel('Normalised E-field amplitude')
            plt.title(f'E-smf at a={a} m')
            plt.figure(figsize=(8,4))
            plt.plot(fibre_r, E_image, color='firebrick')
            plt.axvline(a, color='gray', linestyle='--') # Add a horizontal line at y=0 for reference
            plt.xlabel('radius (m)')
            plt.ylabel('Normalised E-field amplitude')
            plt.title(f'E-image at a={a} m')
    return efficiency_array

# %%
core_radius_range = np.linspace(5e-6, 5.7415e-6, 1483 + 1) # from 5 to 5.75 microns in meters
# efficiency_array = np.zeros_like(core_radius_range)

# The cladding radius should be set to 125/2 micron
cladding_radius_max = 1250e-6 / 2

# %%
efficiency_array_signal = efficiency_vs_core_radius(core_radius_range, cladding_radius_max, lam0, NA, F_focus, alpha, E_S, Magnification)
# Out:
# X_max restricted to 2.094395 to stay on the LP01 branch
# X_max restricted to 2.094605 to stay on the LP01 branch
# X_max restricted to 2.094814 to stay on the LP01 branch
# X_max restricted to 2.095023 to stay on the LP01 branch
# X_max restricted to 2.095233 to stay on the LP01 branch
# X_max restricted to 2.095442 to stay on the LP01 branch
# X_max restricted to 2.095652 to stay on the LP01 branch
# X_max restricted to 2.095861 to stay on the LP01 branch
# X_max restricted to 2.096071 to stay on the LP01 branch
# X_max restricted to 2.096280 to stay on the LP01 branch
# X_max restricted to 2.096489 to stay on the LP01 branch
# X_max restricted to 2.096699 to stay on the LP01 branch
# X_max restricted to 2.096908 to stay on the LP01 branch
# X_max restricted to 2.097118 to stay on the LP01 branch
# X_max restricted to 2.097327 to stay on the LP01 branch
# X_max restricted to 2.097537 to stay on the LP01 branch
# X_max restricted to 2.097746 to stay on the LP01 branch
# X_max restricted to 2.097956 to stay on the LP01 branch
# X_max restricted to 2.098165 to stay on the LP01 branch
# X_max restricted to 2.098374 to stay on the LP01 branch
# X_max restricted to 2.098584 to stay on the LP01 branch
# X_max restricted to 2.098793 to stay on the LP01 branch
# X_max restricted to 2.099003 to stay on the LP01 branch
# X_max restricted to 2.099212 to stay on the LP01 branch
# X_max restricted to 2.099422 to stay on the LP01 branch
# X_max restricted to 2.099631 to stay on the LP01 branch
# X_max restricted to 2.099841 to stay on the LP01 branch
# X_max restricted to 2.100050 to stay on the LP01 branch
# X_max restricted to 2.100259 to stay on the LP01 branch
# X_max restricted to 2.100469 to stay on the LP01 branch
# X_max restricted to 2.100678 to stay on the LP01 branch
# X_max restricted to 2.100888 to stay on the LP01 branch
# X_max restricted to 2.101097 to stay on the LP01 branch
# X_max restricted to 2.101307 to stay on the LP01 branch
# X_max restricted to 2.101516 to stay on the LP01 branch
# X_max restricted to 2.101725 to stay on the LP01 branch
# X_max restricted to 2.101935 to stay on the LP01 branch
# X_max restricted to 2.102144 to stay on the LP01 branch
# X_max restricted to 2.102354 to stay on the LP01 branch
# X_max restricted to 2.102563 to stay on the LP01 branch
# X_max restricted to 2.102773 to stay on the LP01 branch
# X_max restricted to 2.102982 to stay on the LP01 branch
# X_max restricted to 2.103192 to stay on the LP01 branch
# X_max restricted to 2.103401 to stay on the LP01 branch
# X_max restricted to 2.103610 to stay on the LP01 branch
# X_max restricted to 2.103820 to stay on the LP01 branch
# X_max restricted to 2.104029 to stay on the LP01 branch
# X_max restricted to 2.104239 to stay on the LP01 branch
# X_max restricted to 2.104448 to stay on the LP01 branch
# X_max restricted to 2.104658 to stay on the LP01 branch
# X_max restricted to 2.104867 to stay on the LP01 branch
# X_max restricted to 2.105077 to stay on the LP01 branch
# X_max restricted to 2.105286 to stay on the LP01 branch
# X_max restricted to 2.105495 to stay on the LP01 branch
# X_max restricted to 2.105705 to stay on the LP01 branch
# X_max restricted to 2.105914 to stay on the LP01 branch
# X_max restricted to 2.106124 to stay on the LP01 branch
# X_max restricted to 2.106333 to stay on the LP01 branch
# X_max restricted to 2.106543 to stay on the LP01 branch
# X_max restricted to 2.106752 to stay on the LP01 branch
# X_max restricted to 2.106961 to stay on the LP01 branch
# X_max restricted to 2.107171 to stay on the LP01 branch
# X_max restricted to 2.107380 to stay on the LP01 branch
# X_max restricted to 2.107590 to stay on the LP01 branch
# X_max restricted to 2.107799 to stay on the LP01 branch
# X_max restricted to 2.108009 to stay on the LP01 branch
# X_max restricted to 2.108218 to stay on the LP01 branch
# X_max restricted to 2.108428 to stay on the LP01 branch
# X_max restricted to 2.108637 to stay on the LP01 branch
# X_max restricted to 2.108846 to stay on the LP01 branch
# X_max restricted to 2.109056 to stay on the LP01 branch
# X_max restricted to 2.109265 to stay on the LP01 branch
# X_max restricted to 2.109475 to stay on the LP01 branch
# X_max restricted to 2.109684 to stay on the LP01 branch
# X_max restricted to 2.109894 to stay on the LP01 branch
# X_max restricted to 2.110103 to stay on the LP01 branch
# X_max restricted to 2.110312 to stay on the LP01 branch
# X_max restricted to 2.110522 to stay on the LP01 branch
# X_max restricted to 2.110731 to stay on the LP01 branch
# X_max restricted to 2.110941 to stay on the LP01 branch
# X_max restricted to 2.111150 to stay on the LP01 branch
# X_max restricted to 2.111360 to stay on the LP01 branch
# X_max restricted to 2.111569 to stay on the LP01 branch
# X_max restricted to 2.111779 to stay on the LP01 branch
# X_max restricted to 2.111988 to stay on the LP01 branch
# X_max restricted to 2.112197 to stay on the LP01 branch
# X_max restricted to 2.112407 to stay on the LP01 branch
# X_max restricted to 2.112616 to stay on the LP01 branch
# X_max restricted to 2.112826 to stay on the LP01 branch
# X_max restricted to 2.113035 to stay on the LP01 branch
# X_max restricted to 2.113245 to stay on the LP01 branch
# X_max restricted to 2.113454 to stay on the LP01 branch
# X_max restricted to 2.113664 to stay on the LP01 branch
# X_max restricted to 2.113873 to stay on the LP01 branch
# X_max restricted to 2.114082 to stay on the LP01 branch
# X_max restricted to 2.114292 to stay on the LP01 branch
# X_max restricted to 2.114501 to stay on the LP01 branch
# X_max restricted to 2.114711 to stay on the LP01 branch
# X_max restricted to 2.114920 to stay on the LP01 branch
# X_max restricted to 2.115130 to stay on the LP01 branch
# X_max restricted to 2.115339 to stay on the LP01 branch
# X_max restricted to 2.115548 to stay on the LP01 branch
# X_max restricted to 2.115758 to stay on the LP01 branch
# X_max restricted to 2.115967 to stay on the LP01 branch
# X_max restricted to 2.116177 to stay on the LP01 branch
# X_max restricted to 2.116386 to stay on the LP01 branch
# X_max restricted to 2.116596 to stay on the LP01 branch
# X_max restricted to 2.116805 to stay on the LP01 branch
# X_max restricted to 2.117015 to stay on the LP01 branch
# X_max restricted to 2.117224 to stay on the LP01 branch
# X_max restricted to 2.117433 to stay on the LP01 branch
# X_max restricted to 2.117643 to stay on the LP01 branch
# X_max restricted to 2.117852 to stay on the LP01 branch
# X_max restricted to 2.118062 to stay on the LP01 branch
# X_max restricted to 2.118271 to stay on the LP01 branch
# X_max restricted to 2.118481 to stay on the LP01 branch
# X_max restricted to 2.118690 to stay on the LP01 branch
# X_max restricted to 2.118900 to stay on the LP01 branch
# X_max restricted to 2.119109 to stay on the LP01 branch
# X_max restricted to 2.119318 to stay on the LP01 branch
# X_max restricted to 2.119528 to stay on the LP01 branch
# X_max restricted to 2.119737 to stay on the LP01 branch
# X_max restricted to 2.119947 to stay on the LP01 branch
# X_max restricted to 2.120156 to stay on the LP01 branch
# X_max restricted to 2.120366 to stay on the LP01 branch
# X_max restricted to 2.120575 to stay on the LP01 branch
# X_max restricted to 2.120784 to stay on the LP01 branch
# X_max restricted to 2.120994 to stay on the LP01 branch
# X_max restricted to 2.121203 to stay on the LP01 branch
# X_max restricted to 2.121413 to stay on the LP01 branch
# X_max restricted to 2.121622 to stay on the LP01 branch
# X_max restricted to 2.121832 to stay on the LP01 branch
# X_max restricted to 2.122041 to stay on the LP01 branch
# X_max restricted to 2.122251 to stay on the LP01 branch
# X_max restricted to 2.122460 to stay on the LP01 branch
# X_max restricted to 2.122669 to stay on the LP01 branch
# X_max restricted to 2.122879 to stay on the LP01 branch
# X_max restricted to 2.123088 to stay on the LP01 branch
# X_max restricted to 2.123298 to stay on the LP01 branch
# X_max restricted to 2.123507 to stay on the LP01 branch
# X_max restricted to 2.123717 to stay on the LP01 branch
# X_max restricted to 2.123926 to stay on the LP01 branch
# X_max restricted to 2.124136 to stay on the LP01 branch
# X_max restricted to 2.124345 to stay on the LP01 branch
# X_max restricted to 2.124554 to stay on the LP01 branch
# X_max restricted to 2.124764 to stay on the LP01 branch
# X_max restricted to 2.124973 to stay on the LP01 branch
# X_max restricted to 2.125183 to stay on the LP01 branch
# X_max restricted to 2.125392 to stay on the LP01 branch
# X_max restricted to 2.125602 to stay on the LP01 branch
# X_max restricted to 2.125811 to stay on the LP01 branch
# X_max restricted to 2.126020 to stay on the LP01 branch
# X_max restricted to 2.126230 to stay on the LP01 branch
# X_max restricted to 2.126439 to stay on the LP01 branch
# X_max restricted to 2.126649 to stay on the LP01 branch
# X_max restricted to 2.126858 to stay on the LP01 branch
# X_max restricted to 2.127068 to stay on the LP01 branch
# X_max restricted to 2.127277 to stay on the LP01 branch
# X_max restricted to 2.127487 to stay on the LP01 branch
# X_max restricted to 2.127696 to stay on the LP01 branch
# X_max restricted to 2.127905 to stay on the LP01 branch
# X_max restricted to 2.128115 to stay on the LP01 branch
# X_max restricted to 2.128324 to stay on the LP01 branch
# X_max restricted to 2.128534 to stay on the LP01 branch
# X_max restricted to 2.128743 to stay on the LP01 branch
# X_max restricted to 2.128953 to stay on the LP01 branch
# X_max restricted to 2.129162 to stay on the LP01 branch
# X_max restricted to 2.129371 to stay on the LP01 branch
# X_max restricted to 2.129581 to stay on the LP01 branch
# X_max restricted to 2.129790 to stay on the LP01 branch
# X_max restricted to 2.130000 to stay on the LP01 branch
# X_max restricted to 2.130209 to stay on the LP01 branch
# X_max restricted to 2.130419 to stay on the LP01 branch
# X_max restricted to 2.130628 to stay on the LP01 branch
# X_max restricted to 2.130838 to stay on the LP01 branch
# X_max restricted to 2.131047 to stay on the LP01 branch
# X_max restricted to 2.131256 to stay on the LP01 branch
# X_max restricted to 2.131466 to stay on the LP01 branch
# X_max restricted to 2.131675 to stay on the LP01 branch
# X_max restricted to 2.131885 to stay on the LP01 branch
# X_max restricted to 2.132094 to stay on the LP01 branch
# X_max restricted to 2.132304 to stay on the LP01 branch
# X_max restricted to 2.132513 to stay on the LP01 branch
# X_max restricted to 2.132723 to stay on the LP01 branch
# X_max restricted to 2.132932 to stay on the LP01 branch
# X_max restricted to 2.133141 to stay on the LP01 branch
# X_max restricted to 2.133351 to stay on the LP01 branch
# X_max restricted to 2.133560 to stay on the LP01 branch
# X_max restricted to 2.133770 to stay on the LP01 branch
# X_max restricted to 2.133979 to stay on the LP01 branch
# X_max restricted to 2.134189 to stay on the LP01 branch
# X_max restricted to 2.134398 to stay on the LP01 branch
# X_max restricted to 2.134607 to stay on the LP01 branch
# X_max restricted to 2.134817 to stay on the LP01 branch
# X_max restricted to 2.135026 to stay on the LP01 branch
# X_max restricted to 2.135236 to stay on the LP01 branch
# X_max restricted to 2.135445 to stay on the LP01 branch
# X_max restricted to 2.135655 to stay on the LP01 branch
# X_max restricted to 2.135864 to stay on the LP01 branch
# X_max restricted to 2.136074 to stay on the LP01 branch
# X_max restricted to 2.136283 to stay on the LP01 branch
# X_max restricted to 2.136492 to stay on the LP01 branch
# X_max restricted to 2.136702 to stay on the LP01 branch
# X_max restricted to 2.136911 to stay on the LP01 branch
# X_max restricted to 2.137121 to stay on the LP01 branch
# X_max restricted to 2.137330 to stay on the LP01 branch
# X_max restricted to 2.137540 to stay on the LP01 branch
# X_max restricted to 2.137749 to stay on the LP01 branch
# X_max restricted to 2.137959 to stay on the LP01 branch
# X_max restricted to 2.138168 to stay on the LP01 branch
# X_max restricted to 2.138377 to stay on the LP01 branch
# X_max restricted to 2.138587 to stay on the LP01 branch
# X_max restricted to 2.138796 to stay on the LP01 branch
# X_max restricted to 2.139006 to stay on the LP01 branch
# X_max restricted to 2.139215 to stay on the LP01 branch
# X_max restricted to 2.139425 to stay on the LP01 branch
# X_max restricted to 2.139634 to stay on the LP01 branch
# X_max restricted to 2.139843 to stay on the LP01 branch
# X_max restricted to 2.140053 to stay on the LP01 branch
# X_max restricted to 2.140262 to stay on the LP01 branch
# X_max restricted to 2.140472 to stay on the LP01 branch
# X_max restricted to 2.140681 to stay on the LP01 branch
# X_max restricted to 2.140891 to stay on the LP01 branch
# X_max restricted to 2.141100 to stay on the LP01 branch
# X_max restricted to 2.141310 to stay on the LP01 branch
# X_max restricted to 2.141519 to stay on the LP01 branch
# X_max restricted to 2.141728 to stay on the LP01 branch
# X_max restricted to 2.141938 to stay on the LP01 branch
# X_max restricted to 2.142147 to stay on the LP01 branch
# X_max restricted to 2.142357 to stay on the LP01 branch
# X_max restricted to 2.142566 to stay on the LP01 branch
# X_max restricted to 2.142776 to stay on the LP01 branch
# X_max restricted to 2.142985 to stay on the LP01 branch
# X_max restricted to 2.143194 to stay on the LP01 branch
# X_max restricted to 2.143404 to stay on the LP01 branch
# X_max restricted to 2.143613 to stay on the LP01 branch
# X_max restricted to 2.143823 to stay on the LP01 branch
# X_max restricted to 2.144032 to stay on the LP01 branch
# X_max restricted to 2.144242 to stay on the LP01 branch
# X_max restricted to 2.144451 to stay on the LP01 branch
# X_max restricted to 2.144661 to stay on the LP01 branch
# X_max restricted to 2.144870 to stay on the LP01 branch
# X_max restricted to 2.145079 to stay on the LP01 branch
# X_max restricted to 2.145289 to stay on the LP01 branch
# X_max restricted to 2.145498 to stay on the LP01 branch
# X_max restricted to 2.145708 to stay on the LP01 branch
# X_max restricted to 2.145917 to stay on the LP01 branch
# X_max restricted to 2.146127 to stay on the LP01 branch
# X_max restricted to 2.146336 to stay on the LP01 branch
# X_max restricted to 2.146546 to stay on the LP01 branch
# X_max restricted to 2.146755 to stay on the LP01 branch
# X_max restricted to 2.146964 to stay on the LP01 branch
# X_max restricted to 2.147174 to stay on the LP01 branch
# X_max restricted to 2.147383 to stay on the LP01 branch
# X_max restricted to 2.147593 to stay on the LP01 branch
# X_max restricted to 2.147802 to stay on the LP01 branch
# X_max restricted to 2.148012 to stay on the LP01 branch
# X_max restricted to 2.148221 to stay on the LP01 branch
# X_max restricted to 2.148430 to stay on the LP01 branch
# X_max restricted to 2.148640 to stay on the LP01 branch
# X_max restricted to 2.148849 to stay on the LP01 branch
# X_max restricted to 2.149059 to stay on the LP01 branch
# X_max restricted to 2.149268 to stay on the LP01 branch
# X_max restricted to 2.149478 to stay on the LP01 branch
# X_max restricted to 2.149687 to stay on the LP01 branch
# X_max restricted to 2.149897 to stay on the LP01 branch
# X_max restricted to 2.150106 to stay on the LP01 branch
# X_max restricted to 2.150315 to stay on the LP01 branch
# X_max restricted to 2.150525 to stay on the LP01 branch
# X_max restricted to 2.150734 to stay on the LP01 branch
# X_max restricted to 2.150944 to stay on the LP01 branch
# X_max restricted to 2.151153 to stay on the LP01 branch
# X_max restricted to 2.151363 to stay on the LP01 branch
# X_max restricted to 2.151572 to stay on the LP01 branch
# X_max restricted to 2.151782 to stay on the LP01 branch
# X_max restricted to 2.151991 to stay on the LP01 branch
# X_max restricted to 2.152200 to stay on the LP01 branch
# X_max restricted to 2.152410 to stay on the LP01 branch
# X_max restricted to 2.152619 to stay on the LP01 branch
# X_max restricted to 2.152829 to stay on the LP01 branch
# X_max restricted to 2.153038 to stay on the LP01 branch
# X_max restricted to 2.153248 to stay on the LP01 branch
# X_max restricted to 2.153457 to stay on the LP01 branch
# X_max restricted to 2.153666 to stay on the LP01 branch
# X_max restricted to 2.153876 to stay on the LP01 branch
# X_max restricted to 2.154085 to stay on the LP01 branch
# X_max restricted to 2.154295 to stay on the LP01 branch
# X_max restricted to 2.154504 to stay on the LP01 branch
# X_max restricted to 2.154714 to stay on the LP01 branch
# X_max restricted to 2.154923 to stay on the LP01 branch
# X_max restricted to 2.155133 to stay on the LP01 branch
# X_max restricted to 2.155342 to stay on the LP01 branch
# X_max restricted to 2.155551 to stay on the LP01 branch
# X_max restricted to 2.155761 to stay on the LP01 branch
# X_max restricted to 2.155970 to stay on the LP01 branch
# X_max restricted to 2.156180 to stay on the LP01 branch
# X_max restricted to 2.156389 to stay on the LP01 branch
# X_max restricted to 2.156599 to stay on the LP01 branch
# X_max restricted to 2.156808 to stay on the LP01 branch
# X_max restricted to 2.157018 to stay on the LP01 branch
# X_max restricted to 2.157227 to stay on the LP01 branch
# X_max restricted to 2.157436 to stay on the LP01 branch
# X_max restricted to 2.157646 to stay on the LP01 branch
# X_max restricted to 2.157855 to stay on the LP01 branch
# X_max restricted to 2.158065 to stay on the LP01 branch
# X_max restricted to 2.158274 to stay on the LP01 branch
# X_max restricted to 2.158484 to stay on the LP01 branch
# X_max restricted to 2.158693 to stay on the LP01 branch
# X_max restricted to 2.158902 to stay on the LP01 branch
# X_max restricted to 2.159112 to stay on the LP01 branch
# X_max restricted to 2.159321 to stay on the LP01 branch
# X_max restricted to 2.159531 to stay on the LP01 branch
# X_max restricted to 2.159740 to stay on the LP01 branch
# X_max restricted to 2.159950 to stay on the LP01 branch
# X_max restricted to 2.160159 to stay on the LP01 branch
# X_max restricted to 2.160369 to stay on the LP01 branch
# X_max restricted to 2.160578 to stay on the LP01 branch
# X_max restricted to 2.160787 to stay on the LP01 branch
# X_max restricted to 2.160997 to stay on the LP01 branch
# X_max restricted to 2.161206 to stay on the LP01 branch
# X_max restricted to 2.161416 to stay on the LP01 branch
# X_max restricted to 2.161625 to stay on the LP01 branch
# X_max restricted to 2.161835 to stay on the LP01 branch
# X_max restricted to 2.162044 to stay on the LP01 branch
# X_max restricted to 2.162253 to stay on the LP01 branch
# X_max restricted to 2.162463 to stay on the LP01 branch
# X_max restricted to 2.162672 to stay on the LP01 branch
# X_max restricted to 2.162882 to stay on the LP01 branch
# X_max restricted to 2.163091 to stay on the LP01 branch
# X_max restricted to 2.163301 to stay on the LP01 branch
# X_max restricted to 2.163510 to stay on the LP01 branch
# X_max restricted to 2.163720 to stay on the LP01 branch
# X_max restricted to 2.163929 to stay on the LP01 branch
# X_max restricted to 2.164138 to stay on the LP01 branch
# X_max restricted to 2.164348 to stay on the LP01 branch
# X_max restricted to 2.164557 to stay on the LP01 branch
# X_max restricted to 2.164767 to stay on the LP01 branch
# X_max restricted to 2.164976 to stay on the LP01 branch
# X_max restricted to 2.165186 to stay on the LP01 branch
# X_max restricted to 2.165395 to stay on the LP01 branch
# X_max restricted to 2.165605 to stay on the LP01 branch
# X_max restricted to 2.165814 to stay on the LP01 branch
# X_max restricted to 2.166023 to stay on the LP01 branch
# X_max restricted to 2.166233 to stay on the LP01 branch
# X_max restricted to 2.166442 to stay on the LP01 branch
# X_max restricted to 2.166652 to stay on the LP01 branch
# X_max restricted to 2.166861 to stay on the LP01 branch
# X_max restricted to 2.167071 to stay on the LP01 branch
# X_max restricted to 2.167280 to stay on the LP01 branch
# X_max restricted to 2.167489 to stay on the LP01 branch
# X_max restricted to 2.167699 to stay on the LP01 branch
# X_max restricted to 2.167908 to stay on the LP01 branch
# X_max restricted to 2.168118 to stay on the LP01 branch
# X_max restricted to 2.168327 to stay on the LP01 branch
# X_max restricted to 2.168537 to stay on the LP01 branch
# X_max restricted to 2.168746 to stay on the LP01 branch
# X_max restricted to 2.168956 to stay on the LP01 branch
# X_max restricted to 2.169165 to stay on the LP01 branch
# X_max restricted to 2.169374 to stay on the LP01 branch
# X_max restricted to 2.169584 to stay on the LP01 branch
# X_max restricted to 2.169793 to stay on the LP01 branch
# X_max restricted to 2.170003 to stay on the LP01 branch
# X_max restricted to 2.170212 to stay on the LP01 branch
# X_max restricted to 2.170422 to stay on the LP01 branch
# X_max restricted to 2.170631 to stay on the LP01 branch
# X_max restricted to 2.170841 to stay on the LP01 branch
# X_max restricted to 2.171050 to stay on the LP01 branch
# X_max restricted to 2.171259 to stay on the LP01 branch
# X_max restricted to 2.171469 to stay on the LP01 branch
# X_max restricted to 2.171678 to stay on the LP01 branch
# X_max restricted to 2.171888 to stay on the LP01 branch
# X_max restricted to 2.172097 to stay on the LP01 branch
# X_max restricted to 2.172307 to stay on the LP01 branch
# X_max restricted to 2.172516 to stay on the LP01 branch
# X_max restricted to 2.172725 to stay on the LP01 branch
# X_max restricted to 2.172935 to stay on the LP01 branch
# X_max restricted to 2.173144 to stay on the LP01 branch
# X_max restricted to 2.173354 to stay on the LP01 branch
# X_max restricted to 2.173563 to stay on the LP01 branch
# X_max restricted to 2.173773 to stay on the LP01 branch
# X_max restricted to 2.173982 to stay on the LP01 branch
# X_max restricted to 2.174192 to stay on the LP01 branch
# X_max restricted to 2.174401 to stay on the LP01 branch
# X_max restricted to 2.174610 to stay on the LP01 branch
# X_max restricted to 2.174820 to stay on the LP01 branch
# X_max restricted to 2.175029 to stay on the LP01 branch
# X_max restricted to 2.175239 to stay on the LP01 branch
# X_max restricted to 2.175448 to stay on the LP01 branch
# X_max restricted to 2.175658 to stay on the LP01 branch
# X_max restricted to 2.175867 to stay on the LP01 branch
# X_max restricted to 2.176077 to stay on the LP01 branch
# X_max restricted to 2.176286 to stay on the LP01 branch
# X_max restricted to 2.176495 to stay on the LP01 branch
# X_max restricted to 2.176705 to stay on the LP01 branch
# X_max restricted to 2.176914 to stay on the LP01 branch
# X_max restricted to 2.177124 to stay on the LP01 branch
# X_max restricted to 2.177333 to stay on the LP01 branch
# X_max restricted to 2.177543 to stay on the LP01 branch
# X_max restricted to 2.177752 to stay on the LP01 branch
# X_max restricted to 2.177961 to stay on the LP01 branch
# X_max restricted to 2.178171 to stay on the LP01 branch
# X_max restricted to 2.178380 to stay on the LP01 branch
# X_max restricted to 2.178590 to stay on the LP01 branch
# X_max restricted to 2.178799 to stay on the LP01 branch
# X_max restricted to 2.179009 to stay on the LP01 branch
# X_max restricted to 2.179218 to stay on the LP01 branch
# X_max restricted to 2.179428 to stay on the LP01 branch
# X_max restricted to 2.179637 to stay on the LP01 branch
# X_max restricted to 2.179846 to stay on the LP01 branch
# X_max restricted to 2.180056 to stay on the LP01 branch
# X_max restricted to 2.180265 to stay on the LP01 branch
# X_max restricted to 2.180475 to stay on the LP01 branch
# X_max restricted to 2.180684 to stay on the LP01 branch
# X_max restricted to 2.180894 to stay on the LP01 branch
# X_max restricted to 2.181103 to stay on the LP01 branch
# X_max restricted to 2.181312 to stay on the LP01 branch
# X_max restricted to 2.181522 to stay on the LP01 branch
# X_max restricted to 2.181731 to stay on the LP01 branch
# X_max restricted to 2.181941 to stay on the LP01 branch
# X_max restricted to 2.182150 to stay on the LP01 branch
# X_max restricted to 2.182360 to stay on the LP01 branch
# X_max restricted to 2.182569 to stay on the LP01 branch
# X_max restricted to 2.182779 to stay on the LP01 branch
# X_max restricted to 2.182988 to stay on the LP01 branch
# X_max restricted to 2.183197 to stay on the LP01 branch
# X_max restricted to 2.183407 to stay on the LP01 branch
# X_max restricted to 2.183616 to stay on the LP01 branch
# X_max restricted to 2.183826 to stay on the LP01 branch
# X_max restricted to 2.184035 to stay on the LP01 branch
# X_max restricted to 2.184245 to stay on the LP01 branch
# X_max restricted to 2.184454 to stay on the LP01 branch
# X_max restricted to 2.184664 to stay on the LP01 branch
# X_max restricted to 2.184873 to stay on the LP01 branch
# X_max restricted to 2.185082 to stay on the LP01 branch
# X_max restricted to 2.185292 to stay on the LP01 branch
# X_max restricted to 2.185501 to stay on the LP01 branch
# X_max restricted to 2.185711 to stay on the LP01 branch
# X_max restricted to 2.185920 to stay on the LP01 branch
# X_max restricted to 2.186130 to stay on the LP01 branch
# X_max restricted to 2.186339 to stay on the LP01 branch
# X_max restricted to 2.186548 to stay on the LP01 branch
# X_max restricted to 2.186758 to stay on the LP01 branch
# X_max restricted to 2.186967 to stay on the LP01 branch
# X_max restricted to 2.187177 to stay on the LP01 branch
# X_max restricted to 2.187386 to stay on the LP01 branch
# X_max restricted to 2.187596 to stay on the LP01 branch
# X_max restricted to 2.187805 to stay on the LP01 branch
# X_max restricted to 2.188015 to stay on the LP01 branch
# X_max restricted to 2.188224 to stay on the LP01 branch
# X_max restricted to 2.188433 to stay on the LP01 branch
# X_max restricted to 2.188643 to stay on the LP01 branch
# X_max restricted to 2.188852 to stay on the LP01 branch
# X_max restricted to 2.189062 to stay on the LP01 branch
# X_max restricted to 2.189271 to stay on the LP01 branch
# X_max restricted to 2.189481 to stay on the LP01 branch
# X_max restricted to 2.189690 to stay on the LP01 branch
# X_max restricted to 2.189900 to stay on the LP01 branch
# X_max restricted to 2.190109 to stay on the LP01 branch
# X_max restricted to 2.190318 to stay on the LP01 branch
# X_max restricted to 2.190528 to stay on the LP01 branch
# X_max restricted to 2.190737 to stay on the LP01 branch
# X_max restricted to 2.190947 to stay on the LP01 branch
# X_max restricted to 2.191156 to stay on the LP01 branch
# X_max restricted to 2.191366 to stay on the LP01 branch
# X_max restricted to 2.191575 to stay on the LP01 branch
# X_max restricted to 2.191784 to stay on the LP01 branch
# X_max restricted to 2.191994 to stay on the LP01 branch
# X_max restricted to 2.192203 to stay on the LP01 branch
# X_max restricted to 2.192413 to stay on the LP01 branch
# X_max restricted to 2.192622 to stay on the LP01 branch
# X_max restricted to 2.192832 to stay on the LP01 branch
# X_max restricted to 2.193041 to stay on the LP01 branch
# X_max restricted to 2.193251 to stay on the LP01 branch
# X_max restricted to 2.193460 to stay on the LP01 branch
# X_max restricted to 2.193669 to stay on the LP01 branch
# X_max restricted to 2.193879 to stay on the LP01 branch
# X_max restricted to 2.194088 to stay on the LP01 branch
# X_max restricted to 2.194298 to stay on the LP01 branch
# X_max restricted to 2.194507 to stay on the LP01 branch
# X_max restricted to 2.194717 to stay on the LP01 branch
# X_max restricted to 2.194926 to stay on the LP01 branch
# X_max restricted to 2.195135 to stay on the LP01 branch
# X_max restricted to 2.195345 to stay on the LP01 branch
# X_max restricted to 2.195554 to stay on the LP01 branch
# X_max restricted to 2.195764 to stay on the LP01 branch
# X_max restricted to 2.195973 to stay on the LP01 branch
# X_max restricted to 2.196183 to stay on the LP01 branch
# X_max restricted to 2.196392 to stay on the LP01 branch
# X_max restricted to 2.196602 to stay on the LP01 branch
# X_max restricted to 2.196811 to stay on the LP01 branch
# X_max restricted to 2.197020 to stay on the LP01 branch
# X_max restricted to 2.197230 to stay on the LP01 branch
# X_max restricted to 2.197439 to stay on the LP01 branch
# X_max restricted to 2.197649 to stay on the LP01 branch
# X_max restricted to 2.197858 to stay on the LP01 branch
# X_max restricted to 2.198068 to stay on the LP01 branch
# X_max restricted to 2.198277 to stay on the LP01 branch
# X_max restricted to 2.198487 to stay on the LP01 branch
# X_max restricted to 2.198696 to stay on the LP01 branch
# X_max restricted to 2.198905 to stay on the LP01 branch
# X_max restricted to 2.199115 to stay on the LP01 branch
# X_max restricted to 2.199324 to stay on the LP01 branch
# X_max restricted to 2.199534 to stay on the LP01 branch
# X_max restricted to 2.199743 to stay on the LP01 branch
# X_max restricted to 2.199953 to stay on the LP01 branch
# X_max restricted to 2.200162 to stay on the LP01 branch
# X_max restricted to 2.200371 to stay on the LP01 branch
# X_max restricted to 2.200581 to stay on the LP01 branch
# X_max restricted to 2.200790 to stay on the LP01 branch
# X_max restricted to 2.201000 to stay on the LP01 branch
# X_max restricted to 2.201209 to stay on the LP01 branch
# X_max restricted to 2.201419 to stay on the LP01 branch
# X_max restricted to 2.201628 to stay on the LP01 branch
# X_max restricted to 2.201838 to stay on the LP01 branch
# X_max restricted to 2.202047 to stay on the LP01 branch
# X_max restricted to 2.202256 to stay on the LP01 branch
# X_max restricted to 2.202466 to stay on the LP01 branch
# X_max restricted to 2.202675 to stay on the LP01 branch
# X_max restricted to 2.202885 to stay on the LP01 branch
# X_max restricted to 2.203094 to stay on the LP01 branch
# X_max restricted to 2.203304 to stay on the LP01 branch
# X_max restricted to 2.203513 to stay on the LP01 branch
# X_max restricted to 2.203723 to stay on the LP01 branch
# X_max restricted to 2.203932 to stay on the LP01 branch
# X_max restricted to 2.204141 to stay on the LP01 branch
# X_max restricted to 2.204351 to stay on the LP01 branch
# X_max restricted to 2.204560 to stay on the LP01 branch
# X_max restricted to 2.204770 to stay on the LP01 branch
# X_max restricted to 2.204979 to stay on the LP01 branch
# X_max restricted to 2.205189 to stay on the LP01 branch
# X_max restricted to 2.205398 to stay on the LP01 branch
# X_max restricted to 2.205607 to stay on the LP01 branch
# X_max restricted to 2.205817 to stay on the LP01 branch
# X_max restricted to 2.206026 to stay on the LP01 branch
# X_max restricted to 2.206236 to stay on the LP01 branch
# X_max restricted to 2.206445 to stay on the LP01 branch
# X_max restricted to 2.206655 to stay on the LP01 branch
# X_max restricted to 2.206864 to stay on the LP01 branch
# X_max restricted to 2.207074 to stay on the LP01 branch
# X_max restricted to 2.207283 to stay on the LP01 branch
# X_max restricted to 2.207492 to stay on the LP01 branch
# X_max restricted to 2.207702 to stay on the LP01 branch
# X_max restricted to 2.207911 to stay on the LP01 branch
# X_max restricted to 2.208121 to stay on the LP01 branch
# X_max restricted to 2.208330 to stay on the LP01 branch
# X_max restricted to 2.208540 to stay on the LP01 branch
# X_max restricted to 2.208749 to stay on the LP01 branch
# X_max restricted to 2.208959 to stay on the LP01 branch
# X_max restricted to 2.209168 to stay on the LP01 branch
# X_max restricted to 2.209377 to stay on the LP01 branch
# X_max restricted to 2.209587 to stay on the LP01 branch
# X_max restricted to 2.209796 to stay on the LP01 branch
# X_max restricted to 2.210006 to stay on the LP01 branch
# X_max restricted to 2.210215 to stay on the LP01 branch
# X_max restricted to 2.210425 to stay on the LP01 branch
# X_max restricted to 2.210634 to stay on the LP01 branch
# X_max restricted to 2.210843 to stay on the LP01 branch
# X_max restricted to 2.211053 to stay on the LP01 branch
# X_max restricted to 2.211262 to stay on the LP01 branch
# X_max restricted to 2.211472 to stay on the LP01 branch
# X_max restricted to 2.211681 to stay on the LP01 branch
# X_max restricted to 2.211891 to stay on the LP01 branch
# X_max restricted to 2.212100 to stay on the LP01 branch
# X_max restricted to 2.212310 to stay on the LP01 branch
# X_max restricted to 2.212519 to stay on the LP01 branch
# X_max restricted to 2.212728 to stay on the LP01 branch
# X_max restricted to 2.212938 to stay on the LP01 branch
# X_max restricted to 2.213147 to stay on the LP01 branch
# X_max restricted to 2.213357 to stay on the LP01 branch
# X_max restricted to 2.213566 to stay on the LP01 branch
# X_max restricted to 2.213776 to stay on the LP01 branch
# X_max restricted to 2.213985 to stay on the LP01 branch
# X_max restricted to 2.214194 to stay on the LP01 branch
# X_max restricted to 2.214404 to stay on the LP01 branch
# X_max restricted to 2.214613 to stay on the LP01 branch
# X_max restricted to 2.214823 to stay on the LP01 branch
# X_max restricted to 2.215032 to stay on the LP01 branch
# X_max restricted to 2.215242 to stay on the LP01 branch
# X_max restricted to 2.215451 to stay on the LP01 branch
# X_max restricted to 2.215661 to stay on the LP01 branch
# X_max restricted to 2.215870 to stay on the LP01 branch
# X_max restricted to 2.216079 to stay on the LP01 branch
# X_max restricted to 2.216289 to stay on the LP01 branch
# X_max restricted to 2.216498 to stay on the LP01 branch
# X_max restricted to 2.216708 to stay on the LP01 branch
# X_max restricted to 2.216917 to stay on the LP01 branch
# X_max restricted to 2.217127 to stay on the LP01 branch
# X_max restricted to 2.217336 to stay on the LP01 branch
# X_max restricted to 2.217546 to stay on the LP01 branch
# X_max restricted to 2.217755 to stay on the LP01 branch
# X_max restricted to 2.217964 to stay on the LP01 branch
# X_max restricted to 2.218174 to stay on the LP01 branch
# X_max restricted to 2.218383 to stay on the LP01 branch
# X_max restricted to 2.218593 to stay on the LP01 branch
# X_max restricted to 2.218802 to stay on the LP01 branch
# X_max restricted to 2.219012 to stay on the LP01 branch
# X_max restricted to 2.219221 to stay on the LP01 branch
# X_max restricted to 2.219430 to stay on the LP01 branch
# X_max restricted to 2.219640 to stay on the LP01 branch
# X_max restricted to 2.219849 to stay on the LP01 branch
# X_max restricted to 2.220059 to stay on the LP01 branch
# X_max restricted to 2.220268 to stay on the LP01 branch
# X_max restricted to 2.220478 to stay on the LP01 branch
# X_max restricted to 2.220687 to stay on the LP01 branch
# X_max restricted to 2.220897 to stay on the LP01 branch
# X_max restricted to 2.221106 to stay on the LP01 branch
# X_max restricted to 2.221315 to stay on the LP01 branch
# X_max restricted to 2.221525 to stay on the LP01 branch
# X_max restricted to 2.221734 to stay on the LP01 branch
# X_max restricted to 2.221944 to stay on the LP01 branch
# X_max restricted to 2.222153 to stay on the LP01 branch
# X_max restricted to 2.222363 to stay on the LP01 branch
# X_max restricted to 2.222572 to stay on the LP01 branch
# X_max restricted to 2.222782 to stay on the LP01 branch
# X_max restricted to 2.222991 to stay on the LP01 branch
# X_max restricted to 2.223200 to stay on the LP01 branch
# X_max restricted to 2.223410 to stay on the LP01 branch
# X_max restricted to 2.223619 to stay on the LP01 branch
# X_max restricted to 2.223829 to stay on the LP01 branch
# X_max restricted to 2.224038 to stay on the LP01 branch
# X_max restricted to 2.224248 to stay on the LP01 branch
# X_max restricted to 2.224457 to stay on the LP01 branch
# X_max restricted to 2.224666 to stay on the LP01 branch
# X_max restricted to 2.224876 to stay on the LP01 branch
# X_max restricted to 2.225085 to stay on the LP01 branch
# X_max restricted to 2.225295 to stay on the LP01 branch
# X_max restricted to 2.225504 to stay on the LP01 branch
# X_max restricted to 2.225714 to stay on the LP01 branch
# X_max restricted to 2.225923 to stay on the LP01 branch
# X_max restricted to 2.226133 to stay on the LP01 branch
# X_max restricted to 2.226342 to stay on the LP01 branch
# X_max restricted to 2.226551 to stay on the LP01 branch
# X_max restricted to 2.226761 to stay on the LP01 branch
# X_max restricted to 2.226970 to stay on the LP01 branch
# X_max restricted to 2.227180 to stay on the LP01 branch
# X_max restricted to 2.227389 to stay on the LP01 branch
# X_max restricted to 2.227599 to stay on the LP01 branch
# X_max restricted to 2.227808 to stay on the LP01 branch
# X_max restricted to 2.228017 to stay on the LP01 branch
# X_max restricted to 2.228227 to stay on the LP01 branch
# X_max restricted to 2.228436 to stay on the LP01 branch
# X_max restricted to 2.228646 to stay on the LP01 branch
# X_max restricted to 2.228855 to stay on the LP01 branch
# X_max restricted to 2.229065 to stay on the LP01 branch
# X_max restricted to 2.229274 to stay on the LP01 branch
# X_max restricted to 2.229484 to stay on the LP01 branch
# X_max restricted to 2.229693 to stay on the LP01 branch
# X_max restricted to 2.229902 to stay on the LP01 branch
# X_max restricted to 2.230112 to stay on the LP01 branch
# X_max restricted to 2.230321 to stay on the LP01 branch
# X_max restricted to 2.230531 to stay on the LP01 branch
# X_max restricted to 2.230740 to stay on the LP01 branch
# X_max restricted to 2.230950 to stay on the LP01 branch
# X_max restricted to 2.231159 to stay on the LP01 branch
# X_max restricted to 2.231369 to stay on the LP01 branch
# X_max restricted to 2.231578 to stay on the LP01 branch
# X_max restricted to 2.231787 to stay on the LP01 branch
# X_max restricted to 2.231997 to stay on the LP01 branch
# X_max restricted to 2.232206 to stay on the LP01 branch
# X_max restricted to 2.232416 to stay on the LP01 branch
# X_max restricted to 2.232625 to stay on the LP01 branch
# X_max restricted to 2.232835 to stay on the LP01 branch
# X_max restricted to 2.233044 to stay on the LP01 branch
# X_max restricted to 2.233253 to stay on the LP01 branch
# X_max restricted to 2.233463 to stay on the LP01 branch
# X_max restricted to 2.233672 to stay on the LP01 branch
# X_max restricted to 2.233882 to stay on the LP01 branch
# X_max restricted to 2.234091 to stay on the LP01 branch
# X_max restricted to 2.234301 to stay on the LP01 branch
# X_max restricted to 2.234510 to stay on the LP01 branch
# X_max restricted to 2.234720 to stay on the LP01 branch
# X_max restricted to 2.234929 to stay on the LP01 branch
# X_max restricted to 2.235138 to stay on the LP01 branch
# X_max restricted to 2.235348 to stay on the LP01 branch
# X_max restricted to 2.235557 to stay on the LP01 branch
# X_max restricted to 2.235767 to stay on the LP01 branch
# X_max restricted to 2.235976 to stay on the LP01 branch
# X_max restricted to 2.236186 to stay on the LP01 branch
# X_max restricted to 2.236395 to stay on the LP01 branch
# X_max restricted to 2.236605 to stay on the LP01 branch
# X_max restricted to 2.236814 to stay on the LP01 branch
# X_max restricted to 2.237023 to stay on the LP01 branch
# X_max restricted to 2.237233 to stay on the LP01 branch
# X_max restricted to 2.237442 to stay on the LP01 branch
# X_max restricted to 2.237652 to stay on the LP01 branch
# X_max restricted to 2.237861 to stay on the LP01 branch
# X_max restricted to 2.238071 to stay on the LP01 branch
# X_max restricted to 2.238280 to stay on the LP01 branch
# X_max restricted to 2.238489 to stay on the LP01 branch
# X_max restricted to 2.238699 to stay on the LP01 branch
# X_max restricted to 2.238908 to stay on the LP01 branch
# X_max restricted to 2.239118 to stay on the LP01 branch
# X_max restricted to 2.239327 to stay on the LP01 branch
# X_max restricted to 2.239537 to stay on the LP01 branch
# X_max restricted to 2.239746 to stay on the LP01 branch
# X_max restricted to 2.239956 to stay on the LP01 branch
# X_max restricted to 2.240165 to stay on the LP01 branch
# X_max restricted to 2.240374 to stay on the LP01 branch
# X_max restricted to 2.240584 to stay on the LP01 branch
# X_max restricted to 2.240793 to stay on the LP01 branch
# X_max restricted to 2.241003 to stay on the LP01 branch
# X_max restricted to 2.241212 to stay on the LP01 branch
# X_max restricted to 2.241422 to stay on the LP01 branch
# X_max restricted to 2.241631 to stay on the LP01 branch
# X_max restricted to 2.241841 to stay on the LP01 branch
# X_max restricted to 2.242050 to stay on the LP01 branch
# X_max restricted to 2.242259 to stay on the LP01 branch
# X_max restricted to 2.242469 to stay on the LP01 branch
# X_max restricted to 2.242678 to stay on the LP01 branch
# X_max restricted to 2.242888 to stay on the LP01 branch
# X_max restricted to 2.243097 to stay on the LP01 branch
# X_max restricted to 2.243307 to stay on the LP01 branch
# X_max restricted to 2.243516 to stay on the LP01 branch
# X_max restricted to 2.243725 to stay on the LP01 branch
# X_max restricted to 2.243935 to stay on the LP01 branch
# X_max restricted to 2.244144 to stay on the LP01 branch
# X_max restricted to 2.244354 to stay on the LP01 branch
# X_max restricted to 2.244563 to stay on the LP01 branch
# X_max restricted to 2.244773 to stay on the LP01 branch
# X_max restricted to 2.244982 to stay on the LP01 branch
# X_max restricted to 2.245192 to stay on the LP01 branch
# X_max restricted to 2.245401 to stay on the LP01 branch
# X_max restricted to 2.245610 to stay on the LP01 branch
# X_max restricted to 2.245820 to stay on the LP01 branch
# X_max restricted to 2.246029 to stay on the LP01 branch
# X_max restricted to 2.246239 to stay on the LP01 branch
# X_max restricted to 2.246448 to stay on the LP01 branch
# X_max restricted to 2.246658 to stay on the LP01 branch
# X_max restricted to 2.246867 to stay on the LP01 branch
# X_max restricted to 2.247076 to stay on the LP01 branch
# X_max restricted to 2.247286 to stay on the LP01 branch
# X_max restricted to 2.247495 to stay on the LP01 branch
# X_max restricted to 2.247705 to stay on the LP01 branch
# X_max restricted to 2.247914 to stay on the LP01 branch
# X_max restricted to 2.248124 to stay on the LP01 branch
# X_max restricted to 2.248333 to stay on the LP01 branch
# X_max restricted to 2.248543 to stay on the LP01 branch
# X_max restricted to 2.248752 to stay on the LP01 branch
# X_max restricted to 2.248961 to stay on the LP01 branch
# X_max restricted to 2.249171 to stay on the LP01 branch
# X_max restricted to 2.249380 to stay on the LP01 branch
# X_max restricted to 2.249590 to stay on the LP01 branch
# X_max restricted to 2.249799 to stay on the LP01 branch
# X_max restricted to 2.250009 to stay on the LP01 branch
# X_max restricted to 2.250218 to stay on the LP01 branch
# X_max restricted to 2.250428 to stay on the LP01 branch
# X_max restricted to 2.250637 to stay on the LP01 branch
# X_max restricted to 2.250846 to stay on the LP01 branch
# X_max restricted to 2.251056 to stay on the LP01 branch
# X_max restricted to 2.251265 to stay on the LP01 branch
# X_max restricted to 2.251475 to stay on the LP01 branch
# X_max restricted to 2.251684 to stay on the LP01 branch
# X_max restricted to 2.251894 to stay on the LP01 branch
# X_max restricted to 2.252103 to stay on the LP01 branch
# X_max restricted to 2.252312 to stay on the LP01 branch
# X_max restricted to 2.252522 to stay on the LP01 branch
# X_max restricted to 2.252731 to stay on the LP01 branch
# X_max restricted to 2.252941 to stay on the LP01 branch
# X_max restricted to 2.253150 to stay on the LP01 branch
# X_max restricted to 2.253360 to stay on the LP01 branch
# X_max restricted to 2.253569 to stay on the LP01 branch
# X_max restricted to 2.253779 to stay on the LP01 branch
# X_max restricted to 2.253988 to stay on the LP01 branch
# X_max restricted to 2.254197 to stay on the LP01 branch
# X_max restricted to 2.254407 to stay on the LP01 branch
# X_max restricted to 2.254616 to stay on the LP01 branch
# X_max restricted to 2.254826 to stay on the LP01 branch
# X_max restricted to 2.255035 to stay on the LP01 branch
# X_max restricted to 2.255245 to stay on the LP01 branch
# X_max restricted to 2.255454 to stay on the LP01 branch
# X_max restricted to 2.255664 to stay on the LP01 branch
# X_max restricted to 2.255873 to stay on the LP01 branch
# X_max restricted to 2.256082 to stay on the LP01 branch
# X_max restricted to 2.256292 to stay on the LP01 branch
# X_max restricted to 2.256501 to stay on the LP01 branch
# X_max restricted to 2.256711 to stay on the LP01 branch
# X_max restricted to 2.256920 to stay on the LP01 branch
# X_max restricted to 2.257130 to stay on the LP01 branch
# X_max restricted to 2.257339 to stay on the LP01 branch
# X_max restricted to 2.257548 to stay on the LP01 branch
# X_max restricted to 2.257758 to stay on the LP01 branch
# X_max restricted to 2.257967 to stay on the LP01 branch
# X_max restricted to 2.258177 to stay on the LP01 branch
# X_max restricted to 2.258386 to stay on the LP01 branch
# X_max restricted to 2.258596 to stay on the LP01 branch
# X_max restricted to 2.258805 to stay on the LP01 branch
# X_max restricted to 2.259015 to stay on the LP01 branch
# X_max restricted to 2.259224 to stay on the LP01 branch
# X_max restricted to 2.259433 to stay on the LP01 branch
# X_max restricted to 2.259643 to stay on the LP01 branch
# X_max restricted to 2.259852 to stay on the LP01 branch
# X_max restricted to 2.260062 to stay on the LP01 branch
# X_max restricted to 2.260271 to stay on the LP01 branch
# X_max restricted to 2.260481 to stay on the LP01 branch
# X_max restricted to 2.260690 to stay on the LP01 branch
# X_max restricted to 2.260900 to stay on the LP01 branch
# X_max restricted to 2.261109 to stay on the LP01 branch
# X_max restricted to 2.261318 to stay on the LP01 branch
# X_max restricted to 2.261528 to stay on the LP01 branch
# X_max restricted to 2.261737 to stay on the LP01 branch
# X_max restricted to 2.261947 to stay on the LP01 branch
# X_max restricted to 2.262156 to stay on the LP01 branch
# X_max restricted to 2.262366 to stay on the LP01 branch
# X_max restricted to 2.262575 to stay on the LP01 branch
# X_max restricted to 2.262784 to stay on the LP01 branch
# X_max restricted to 2.262994 to stay on the LP01 branch
# X_max restricted to 2.263203 to stay on the LP01 branch
# X_max restricted to 2.263413 to stay on the LP01 branch
# X_max restricted to 2.263622 to stay on the LP01 branch
# X_max restricted to 2.263832 to stay on the LP01 branch
# X_max restricted to 2.264041 to stay on the LP01 branch
# X_max restricted to 2.264251 to stay on the LP01 branch
# X_max restricted to 2.264460 to stay on the LP01 branch
# X_max restricted to 2.264669 to stay on the LP01 branch
# X_max restricted to 2.264879 to stay on the LP01 branch
# X_max restricted to 2.265088 to stay on the LP01 branch
# X_max restricted to 2.265298 to stay on the LP01 branch
# X_max restricted to 2.265507 to stay on the LP01 branch
# X_max restricted to 2.265717 to stay on the LP01 branch
# X_max restricted to 2.265926 to stay on the LP01 branch
# X_max restricted to 2.266135 to stay on the LP01 branch
# X_max restricted to 2.266345 to stay on the LP01 branch
# X_max restricted to 2.266554 to stay on the LP01 branch
# X_max restricted to 2.266764 to stay on the LP01 branch
# X_max restricted to 2.266973 to stay on the LP01 branch
# X_max restricted to 2.267183 to stay on the LP01 branch
# X_max restricted to 2.267392 to stay on the LP01 branch
# X_max restricted to 2.267602 to stay on the LP01 branch
# X_max restricted to 2.267811 to stay on the LP01 branch
# X_max restricted to 2.268020 to stay on the LP01 branch
# X_max restricted to 2.268230 to stay on the LP01 branch
# X_max restricted to 2.268439 to stay on the LP01 branch
# X_max restricted to 2.268649 to stay on the LP01 branch
# X_max restricted to 2.268858 to stay on the LP01 branch
# X_max restricted to 2.269068 to stay on the LP01 branch
# X_max restricted to 2.269277 to stay on the LP01 branch
# X_max restricted to 2.269487 to stay on the LP01 branch
# X_max restricted to 2.269696 to stay on the LP01 branch
# X_max restricted to 2.269905 to stay on the LP01 branch
# X_max restricted to 2.270115 to stay on the LP01 branch
# X_max restricted to 2.270324 to stay on the LP01 branch
# X_max restricted to 2.270534 to stay on the LP01 branch
# X_max restricted to 2.270743 to stay on the LP01 branch
# X_max restricted to 2.270953 to stay on the LP01 branch
# X_max restricted to 2.271162 to stay on the LP01 branch
# X_max restricted to 2.271371 to stay on the LP01 branch
# X_max restricted to 2.271581 to stay on the LP01 branch
# X_max restricted to 2.271790 to stay on the LP01 branch
# X_max restricted to 2.272000 to stay on the LP01 branch
# X_max restricted to 2.272209 to stay on the LP01 branch
# X_max restricted to 2.272419 to stay on the LP01 branch
# X_max restricted to 2.272628 to stay on the LP01 branch
# X_max restricted to 2.272838 to stay on the LP01 branch
# X_max restricted to 2.273047 to stay on the LP01 branch
# X_max restricted to 2.273256 to stay on the LP01 branch
# X_max restricted to 2.273466 to stay on the LP01 branch
# X_max restricted to 2.273675 to stay on the LP01 branch
# ...
# X_max restricted to 2.345513 to stay on the LP01 branch
# X_max restricted to 2.345723 to stay on the LP01 branch
# X_max restricted to 2.345932 to stay on the LP01 branch
# X_max restricted to 2.346141 to stay on the LP01 branch
# X_max restricted to 2.346351 to stay on the LP01 branch
# X_max restricted to 2.346560 to stay on the LP01 branch
# X_max restricted to 2.346770 to stay on the LP01 branch
# X_max restricted to 2.346979 to stay on the LP01 branch
# X_max restricted to 2.347189 to stay on the LP01 branch
# X_max restricted to 2.347398 to stay on the LP01 branch
# X_max restricted to 2.347607 to stay on the LP01 branch
# X_max restricted to 2.347817 to stay on the LP01 branch
# X_max restricted to 2.348026 to stay on the LP01 branch
# X_max restricted to 2.348236 to stay on the LP01 branch
# X_max restricted to 2.348445 to stay on the LP01 branch
# X_max restricted to 2.348655 to stay on the LP01 branch
# X_max restricted to 2.348864 to stay on the LP01 branch
# X_max restricted to 2.349074 to stay on the LP01 branch
# X_max restricted to 2.349283 to stay on the LP01 branch
# X_max restricted to 2.349492 to stay on the LP01 branch
# X_max restricted to 2.349702 to stay on the LP01 branch
# X_max restricted to 2.349911 to stay on the LP01 branch
# X_max restricted to 2.350121 to stay on the LP01 branch
# X_max restricted to 2.350330 to stay on the LP01 branch
# X_max restricted to 2.350540 to stay on the LP01 branch
# X_max restricted to 2.350749 to stay on the LP01 branch
# X_max restricted to 2.350958 to stay on the LP01 branch
# X_max restricted to 2.351168 to stay on the LP01 branch
# X_max restricted to 2.351377 to stay on the LP01 branch
# X_max restricted to 2.351587 to stay on the LP01 branch
# X_max restricted to 2.351796 to stay on the LP01 branch
# X_max restricted to 2.352006 to stay on the LP01 branch
# X_max restricted to 2.352215 to stay on the LP01 branch
# X_max restricted to 2.352425 to stay on the LP01 branch
# X_max restricted to 2.352634 to stay on the LP01 branch
# X_max restricted to 2.352843 to stay on the LP01 branch
# X_max restricted to 2.353053 to stay on the LP01 branch
# X_max restricted to 2.353262 to stay on the LP01 branch
# X_max restricted to 2.353472 to stay on the LP01 branch
# X_max restricted to 2.353681 to stay on the LP01 branch
# X_max restricted to 2.353891 to stay on the LP01 branch
# X_max restricted to 2.354100 to stay on the LP01 branch
# X_max restricted to 2.354310 to stay on the LP01 branch
# X_max restricted to 2.354519 to stay on the LP01 branch
# X_max restricted to 2.354728 to stay on the LP01 branch
# X_max restricted to 2.354938 to stay on the LP01 branch
# X_max restricted to 2.355147 to stay on the LP01 branch
# X_max restricted to 2.355357 to stay on the LP01 branch
# X_max restricted to 2.355566 to stay on the LP01 branch
# X_max restricted to 2.355776 to stay on the LP01 branch
# X_max restricted to 2.355985 to stay on the LP01 branch
# X_max restricted to 2.356194 to stay on the LP01 branch
# X_max restricted to 2.356404 to stay on the LP01 branch
# X_max restricted to 2.356613 to stay on the LP01 branch
# X_max restricted to 2.356823 to stay on the LP01 branch
# X_max restricted to 2.357032 to stay on the LP01 branch
# X_max restricted to 2.357242 to stay on the LP01 branch
# X_max restricted to 2.357451 to stay on the LP01 branch
# X_max restricted to 2.357661 to stay on the LP01 branch
# X_max restricted to 2.357870 to stay on the LP01 branch
# X_max restricted to 2.358079 to stay on the LP01 branch
# X_max restricted to 2.358289 to stay on the LP01 branch
# X_max restricted to 2.358498 to stay on the LP01 branch
# X_max restricted to 2.358708 to stay on the LP01 branch
# X_max restricted to 2.358917 to stay on the LP01 branch
# X_max restricted to 2.359127 to stay on the LP01 branch
# X_max restricted to 2.359336 to stay on the LP01 branch
# X_max restricted to 2.359546 to stay on the LP01 branch
# X_max restricted to 2.359755 to stay on the LP01 branch
# X_max restricted to 2.359964 to stay on the LP01 branch
# X_max restricted to 2.360174 to stay on the LP01 branch
# X_max restricted to 2.360383 to stay on the LP01 branch
# X_max restricted to 2.360593 to stay on the LP01 branch
# X_max restricted to 2.360802 to stay on the LP01 branch
# X_max restricted to 2.361012 to stay on the LP01 branch
# X_max restricted to 2.361221 to stay on the LP01 branch
# X_max restricted to 2.361430 to stay on the LP01 branch
# X_max restricted to 2.361640 to stay on the LP01 branch
# X_max restricted to 2.361849 to stay on the LP01 branch
# X_max restricted to 2.362059 to stay on the LP01 branch
# X_max restricted to 2.362268 to stay on the LP01 branch
# X_max restricted to 2.362478 to stay on the LP01 branch
# X_max restricted to 2.362687 to stay on the LP01 branch
# X_max restricted to 2.362897 to stay on the LP01 branch
# X_max restricted to 2.363106 to stay on the LP01 branch
# X_max restricted to 2.363315 to stay on the LP01 branch
# X_max restricted to 2.363525 to stay on the LP01 branch
# X_max restricted to 2.363734 to stay on the LP01 branch
# X_max restricted to 2.363944 to stay on the LP01 branch
# X_max restricted to 2.364153 to stay on the LP01 branch
# X_max restricted to 2.364363 to stay on the LP01 branch
# X_max restricted to 2.364572 to stay on the LP01 branch
# X_max restricted to 2.364782 to stay on the LP01 branch
# X_max restricted to 2.364991 to stay on the LP01 branch
# X_max restricted to 2.365200 to stay on the LP01 branch
# X_max restricted to 2.365410 to stay on the LP01 branch
# X_max restricted to 2.365619 to stay on the LP01 branch
# X_max restricted to 2.365829 to stay on the LP01 branch
# X_max restricted to 2.366038 to stay on the LP01 branch
# X_max restricted to 2.366248 to stay on the LP01 branch
# X_max restricted to 2.366457 to stay on the LP01 branch
# X_max restricted to 2.366666 to stay on the LP01 branch
# X_max restricted to 2.366876 to stay on the LP01 branch
# X_max restricted to 2.367085 to stay on the LP01 branch
# X_max restricted to 2.367295 to stay on the LP01 branch
# X_max restricted to 2.367504 to stay on the LP01 branch
# X_max restricted to 2.367714 to stay on the LP01 branch
# X_max restricted to 2.367923 to stay on the LP01 branch
# X_max restricted to 2.368133 to stay on the LP01 branch
# X_max restricted to 2.368342 to stay on the LP01 branch
# X_max restricted to 2.368551 to stay on the LP01 branch
# X_max restricted to 2.368761 to stay on the LP01 branch
# X_max restricted to 2.368970 to stay on the LP01 branch
# X_max restricted to 2.369180 to stay on the LP01 branch
# X_max restricted to 2.369389 to stay on the LP01 branch
# X_max restricted to 2.369599 to stay on the LP01 branch
# X_max restricted to 2.369808 to stay on the LP01 branch
# X_max restricted to 2.370017 to stay on the LP01 branch
# X_max restricted to 2.370227 to stay on the LP01 branch
# X_max restricted to 2.370436 to stay on the LP01 branch
# X_max restricted to 2.370646 to stay on the LP01 branch
# X_max restricted to 2.370855 to stay on the LP01 branch
# X_max restricted to 2.371065 to stay on the LP01 branch
# X_max restricted to 2.371274 to stay on the LP01 branch
# X_max restricted to 2.371484 to stay on the LP01 branch
# X_max restricted to 2.371693 to stay on the LP01 branch
# X_max restricted to 2.371902 to stay on the LP01 branch
# X_max restricted to 2.372112 to stay on the LP01 branch
# X_max restricted to 2.372321 to stay on the LP01 branch
# X_max restricted to 2.372531 to stay on the LP01 branch
# X_max restricted to 2.372740 to stay on the LP01 branch
# X_max restricted to 2.372950 to stay on the LP01 branch
# X_max restricted to 2.373159 to stay on the LP01 branch
# X_max restricted to 2.373369 to stay on the LP01 branch
# X_max restricted to 2.373578 to stay on the LP01 branch
# X_max restricted to 2.373787 to stay on the LP01 branch
# X_max restricted to 2.373997 to stay on the LP01 branch
# X_max restricted to 2.374206 to stay on the LP01 branch
# X_max restricted to 2.374416 to stay on the LP01 branch
# X_max restricted to 2.374625 to stay on the LP01 branch
# X_max restricted to 2.374835 to stay on the LP01 branch
# X_max restricted to 2.375044 to stay on the LP01 branch
# X_max restricted to 2.375253 to stay on the LP01 branch
# X_max restricted to 2.375463 to stay on the LP01 branch
# X_max restricted to 2.375672 to stay on the LP01 branch
# X_max restricted to 2.375882 to stay on the LP01 branch
# X_max restricted to 2.376091 to stay on the LP01 branch
# X_max restricted to 2.376301 to stay on the LP01 branch
# X_max restricted to 2.376510 to stay on the LP01 branch
# X_max restricted to 2.376720 to stay on the LP01 branch
# X_max restricted to 2.376929 to stay on the LP01 branch
# X_max restricted to 2.377138 to stay on the LP01 branch
# X_max restricted to 2.377348 to stay on the LP01 branch
# X_max restricted to 2.377557 to stay on the LP01 branch
# X_max restricted to 2.377767 to stay on the LP01 branch
# X_max restricted to 2.377976 to stay on the LP01 branch
# X_max restricted to 2.378186 to stay on the LP01 branch
# X_max restricted to 2.378395 to stay on the LP01 branch
# X_max restricted to 2.378605 to stay on the LP01 branch
# X_max restricted to 2.378814 to stay on the LP01 branch
# X_max restricted to 2.379023 to stay on the LP01 branch
# X_max restricted to 2.379233 to stay on the LP01 branch
# X_max restricted to 2.379442 to stay on the LP01 branch
# X_max restricted to 2.379652 to stay on the LP01 branch
# X_max restricted to 2.379861 to stay on the LP01 branch
# X_max restricted to 2.380071 to stay on the LP01 branch
# X_max restricted to 2.380280 to stay on the LP01 branch
# X_max restricted to 2.380489 to stay on the LP01 branch
# X_max restricted to 2.380699 to stay on the LP01 branch
# X_max restricted to 2.380908 to stay on the LP01 branch
# X_max restricted to 2.381118 to stay on the LP01 branch
# X_max restricted to 2.381327 to stay on the LP01 branch
# X_max restricted to 2.381537 to stay on the LP01 branch
# X_max restricted to 2.381746 to stay on the LP01 branch
# X_max restricted to 2.381956 to stay on the LP01 branch
# X_max restricted to 2.382165 to stay on the LP01 branch
# X_max restricted to 2.382374 to stay on the LP01 branch
# X_max restricted to 2.382584 to stay on the LP01 branch
# X_max restricted to 2.382793 to stay on the LP01 branch
# X_max restricted to 2.383003 to stay on the LP01 branch
# X_max restricted to 2.383212 to stay on the LP01 branch
# X_max restricted to 2.383422 to stay on the LP01 branch
# X_max restricted to 2.383631 to stay on the LP01 branch
# X_max restricted to 2.383840 to stay on the LP01 branch
# X_max restricted to 2.384050 to stay on the LP01 branch
# X_max restricted to 2.384259 to stay on the LP01 branch
# X_max restricted to 2.384469 to stay on the LP01 branch
# X_max restricted to 2.384678 to stay on the LP01 branch
# X_max restricted to 2.384888 to stay on the LP01 branch
# X_max restricted to 2.385097 to stay on the LP01 branch
# X_max restricted to 2.385307 to stay on the LP01 branch
# X_max restricted to 2.385516 to stay on the LP01 branch
# X_max restricted to 2.385725 to stay on the LP01 branch
# X_max restricted to 2.385935 to stay on the LP01 branch
# X_max restricted to 2.386144 to stay on the LP01 branch
# X_max restricted to 2.386354 to stay on the LP01 branch
# X_max restricted to 2.386563 to stay on the LP01 branch
# X_max restricted to 2.386773 to stay on the LP01 branch
# X_max restricted to 2.386982 to stay on the LP01 branch
# X_max restricted to 2.387192 to stay on the LP01 branch
# X_max restricted to 2.387401 to stay on the LP01 branch
# X_max restricted to 2.387610 to stay on the LP01 branch
# X_max restricted to 2.387820 to stay on the LP01 branch
# X_max restricted to 2.388029 to stay on the LP01 branch
# X_max restricted to 2.388239 to stay on the LP01 branch
# X_max restricted to 2.388448 to stay on the LP01 branch
# X_max restricted to 2.388658 to stay on the LP01 branch
# X_max restricted to 2.388867 to stay on the LP01 branch
# X_max restricted to 2.389076 to stay on the LP01 branch
# X_max restricted to 2.389286 to stay on the LP01 branch
# X_max restricted to 2.389495 to stay on the LP01 branch
# X_max restricted to 2.389705 to stay on the LP01 branch
# X_max restricted to 2.389914 to stay on the LP01 branch
# X_max restricted to 2.390124 to stay on the LP01 branch
# X_max restricted to 2.390333 to stay on the LP01 branch
# X_max restricted to 2.390543 to stay on the LP01 branch
# X_max restricted to 2.390752 to stay on the LP01 branch
# X_max restricted to 2.390961 to stay on the LP01 branch
# X_max restricted to 2.391171 to stay on the LP01 branch
# X_max restricted to 2.391380 to stay on the LP01 branch
# X_max restricted to 2.391590 to stay on the LP01 branch
# X_max restricted to 2.391799 to stay on the LP01 branch
# X_max restricted to 2.392009 to stay on the LP01 branch
# X_max restricted to 2.392218 to stay on the LP01 branch
# X_max restricted to 2.392428 to stay on the LP01 branch
# X_max restricted to 2.392637 to stay on the LP01 branch
# X_max restricted to 2.392846 to stay on the LP01 branch
# X_max restricted to 2.393056 to stay on the LP01 branch
# X_max restricted to 2.393265 to stay on the LP01 branch
# X_max restricted to 2.393475 to stay on the LP01 branch
# X_max restricted to 2.393684 to stay on the LP01 branch
# X_max restricted to 2.393894 to stay on the LP01 branch
# X_max restricted to 2.394103 to stay on the LP01 branch
# X_max restricted to 2.394312 to stay on the LP01 branch
# X_max restricted to 2.394522 to stay on the LP01 branch
# X_max restricted to 2.394731 to stay on the LP01 branch
# X_max restricted to 2.394941 to stay on the LP01 branch
# X_max restricted to 2.395150 to stay on the LP01 branch
# X_max restricted to 2.395360 to stay on the LP01 branch
# X_max restricted to 2.395569 to stay on the LP01 branch
# X_max restricted to 2.395779 to stay on the LP01 branch
# X_max restricted to 2.395988 to stay on the LP01 branch
# X_max restricted to 2.396197 to stay on the LP01 branch
# X_max restricted to 2.396407 to stay on the LP01 branch
# X_max restricted to 2.396616 to stay on the LP01 branch
# X_max restricted to 2.396826 to stay on the LP01 branch
# X_max restricted to 2.397035 to stay on the LP01 branch
# X_max restricted to 2.397245 to stay on the LP01 branch
# X_max restricted to 2.397454 to stay on the LP01 branch
# X_max restricted to 2.397664 to stay on the LP01 branch
# X_max restricted to 2.397873 to stay on the LP01 branch
# X_max restricted to 2.398082 to stay on the LP01 branch
# X_max restricted to 2.398292 to stay on the LP01 branch
# X_max restricted to 2.398501 to stay on the LP01 branch
# X_max restricted to 2.398711 to stay on the LP01 branch
# X_max restricted to 2.398920 to stay on the LP01 branch
# X_max restricted to 2.399130 to stay on the LP01 branch
# X_max restricted to 2.399339 to stay on the LP01 branch
# X_max restricted to 2.399548 to stay on the LP01 branch
# X_max restricted to 2.399758 to stay on the LP01 branch
# X_max restricted to 2.399967 to stay on the LP01 branch
# X_max restricted to 2.400177 to stay on the LP01 branch
# X_max restricted to 2.400386 to stay on the LP01 branch
# X_max restricted to 2.400596 to stay on the LP01 branch
# X_max restricted to 2.400805 to stay on the LP01 branch
# X_max restricted to 2.401015 to stay on the LP01 branch
# X_max restricted to 2.401224 to stay on the LP01 branch
# X_max restricted to 2.401433 to stay on the LP01 branch
# X_max restricted to 2.401643 to stay on the LP01 branch
# X_max restricted to 2.401852 to stay on the LP01 branch
# X_max restricted to 2.402062 to stay on the LP01 branch
# X_max restricted to 2.402271 to stay on the LP01 branch
# X_max restricted to 2.402481 to stay on the LP01 branch
# X_max restricted to 2.402690 to stay on the LP01 branch
# X_max restricted to 2.402899 to stay on the LP01 branch
# X_max restricted to 2.403109 to stay on the LP01 branch
# X_max restricted to 2.403318 to stay on the LP01 branch
# X_max restricted to 2.403528 to stay on the LP01 branch
# X_max restricted to 2.403737 to stay on the LP01 branch
# X_max restricted to 2.403947 to stay on the LP01 branch
# X_max restricted to 2.404156 to stay on the LP01 branch
# X_max restricted to 2.404366 to stay on the LP01 branch
# X_max restricted to 2.404575 to stay on the LP01 branch
# X_max restricted to 2.404784 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch

# %%
index = np.argmax(efficiency_array_signal)
print(f'The most optimal radius occurs at {core_radius_range[index]} with an efficiency of {efficiency_array_signal[index]}.' )
# Out:
# The most optimal radius occurs at 5.658e-06 with an efficiency of 0.761758160193745.

# %%
plt.figure(figsize=(8,4))
plt.scatter(core_radius_range, efficiency_array_signal, s=1, marker='o')
plt.scatter(core_radius_range[index], efficiency_array_signal[index], color='red', marker = 'x',
            label=f'Max Efficiency: {efficiency_array_signal[index]:.4f} at a={core_radius_range[index]*1e6:.2f} µm')
plt.xlabel('Core radius (m)')
plt.ylabel('Coupling Efficiency (η)')
plt.title('Signal Coupling Efficiency vs Core Radius')
plt.legend()

# %%
alpha
# Out:
# 0

# %% [markdown]
# ## Simulate a E-field for noise

# %%
# The intensity and electric field would be nearly uniform for the background when 
# pointing to a patch of sky
E_uniform = np.ones_like(r) * 1
I_uniform = np.abs(E_uniform) **2

# %%
# Haha
plt.figure(figsize=(12,6))
plt.plot(r, E_uniform, label='Uniform E-field (background)', color='purple')
plt.plot(r, I_uniform, label='Uniform Intensity (background)', color='magenta')
plt.plot(r, E_image_demag, label='Demagnified diffraction-limited E-field', color='blue')
plt.plot(r, I_image_demag, label='Demagnified diffraction-limited Intensity', color='green')
plt.xlim(0,125e-6)
plt.xlabel("radius (m)")
plt.ylabel("Normalised Amplitude")
plt.title("Uniform background E-field and Intensity")
plt.legend()
plt.show()

# %%
plt.plot(r, np.multiply(E_uniform, np.conjugate(E_smf_5micron)))
plt.xlabel('r')
plt.ylabel('E_uniform * np.conjugate(E_smf_5micron)')
# plt.title('Coupling Efficiency with Uniform Background')
plt.xlim(0, 100e-6) # Limit x-axis to 50
# Out:
# (0.0, 0.0001)

# %%
np.trapezoid(np.multiply(E_uniform, np.conjugate(E_smf_5micron)) * 2*np.pi*r, x=r)
# Out:
# np.float64(1.277770492365e-10)

# %%
np.trapezoid(np.abs(E_smf_5micron)**2 * 2*np.pi*r, x=r)
# Out:
# np.float64(5.632342219977363e-11)

# %%
np.trapezoid(E_uniform * 2*np.pi*r, x=r)
# Out:
# np.float64(7.853981633974483e-07)

# %%
def efficiency_vs_core_radius_noise_only(core_radius_range, cladding_radius_max, lam0, NA, F_focus, 
                                         alpha, E_S, Magnification):
    efficiency_array_noise_only = np.zeros_like(core_radius_range)
    for a in core_radius_range: 
        V = 2 * np.pi * (a / lam0) * NA # Calculate the V-number for the given radius
        X_min = 0 + 1e-8
        X_max = V - 1e-8
        # Find the X and Y roots for the given core radius a
        X_root, Y_root = find_root_LP01(V, X_min, X_max)
        # define a normalised radius r / a, with maximum at cladding size 125/2 micron
        fibre_rho = np.linspace(0, cladding_radius_max / a, int(cladding_radius_max*1e6*1000))
        fibre_r = fibre_rho * a
        # Fibre field
        E_smf, I_smf = calculate_electric_field(fibre_rho, X_root, Y_root)
        # Background field
        E_uniform = np.ones_like(fibre_r) * 1
        I_uniform = np.abs(E_uniform) **2

        # Calculate coupling efficiency
        eta, numerator, denominator = coupling_efficiency_1d(E_uniform, E_smf, r=fibre_r)
        # Store the efficiency in the array corresponding to the current core radius, using np.where 
        # to find the index where core_radius_range equals a
        efficiency_array_noise_only[np.where(core_radius_range == a)] = eta

        if a==core_radius_range[0]:
            plt.figure(figsize=(8,4))
            plt.plot(fibre_r, E_smf, color='royalblue')
            plt.axvline(a, color='gray', linestyle='--') # Add a horizontal line at y=0 for reference
            plt.xlabel('radius (m)')
            plt.ylabel('Normalised E-field amplitude')
            plt.title(f'E-smf at a={a} m')
            plt.figure(figsize=(8,4))
            plt.plot(fibre_r, E_uniform, color='firebrick')
            plt.axvline(a, color='gray', linestyle='--') # Add a horizontal line at y=0 for reference
            plt.xlabel('radius (m)')
            plt.ylabel('Normalised E-field amplitude')
            plt.title(f'E-image at a={a} m')
    return efficiency_array_noise_only

# %%
# efficiency_array_noise_only = np.zeros_like(core_radius_range)
efficiency_array_noise = efficiency_vs_core_radius_noise_only(core_radius_range, cladding_radius_max, lam0, NA, F_focus, 
                                         alpha, E_S, Magnification)
# Out:
# X_max restricted to 2.094395 to stay on the LP01 branch
# X_max restricted to 2.094605 to stay on the LP01 branch
# X_max restricted to 2.094814 to stay on the LP01 branch
# X_max restricted to 2.095023 to stay on the LP01 branch
# X_max restricted to 2.095233 to stay on the LP01 branch
# X_max restricted to 2.095442 to stay on the LP01 branch
# X_max restricted to 2.095652 to stay on the LP01 branch
# X_max restricted to 2.095861 to stay on the LP01 branch
# X_max restricted to 2.096071 to stay on the LP01 branch
# X_max restricted to 2.096280 to stay on the LP01 branch
# X_max restricted to 2.096489 to stay on the LP01 branch
# X_max restricted to 2.096699 to stay on the LP01 branch
# X_max restricted to 2.096908 to stay on the LP01 branch
# X_max restricted to 2.097118 to stay on the LP01 branch
# X_max restricted to 2.097327 to stay on the LP01 branch
# X_max restricted to 2.097537 to stay on the LP01 branch
# X_max restricted to 2.097746 to stay on the LP01 branch
# X_max restricted to 2.097956 to stay on the LP01 branch
# X_max restricted to 2.098165 to stay on the LP01 branch
# X_max restricted to 2.098374 to stay on the LP01 branch
# X_max restricted to 2.098584 to stay on the LP01 branch
# X_max restricted to 2.098793 to stay on the LP01 branch
# X_max restricted to 2.099003 to stay on the LP01 branch
# X_max restricted to 2.099212 to stay on the LP01 branch
# X_max restricted to 2.099422 to stay on the LP01 branch
# X_max restricted to 2.099631 to stay on the LP01 branch
# X_max restricted to 2.099841 to stay on the LP01 branch
# X_max restricted to 2.100050 to stay on the LP01 branch
# X_max restricted to 2.100259 to stay on the LP01 branch
# X_max restricted to 2.100469 to stay on the LP01 branch
# X_max restricted to 2.100678 to stay on the LP01 branch
# X_max restricted to 2.100888 to stay on the LP01 branch
# X_max restricted to 2.101097 to stay on the LP01 branch
# X_max restricted to 2.101307 to stay on the LP01 branch
# X_max restricted to 2.101516 to stay on the LP01 branch
# X_max restricted to 2.101725 to stay on the LP01 branch
# X_max restricted to 2.101935 to stay on the LP01 branch
# X_max restricted to 2.102144 to stay on the LP01 branch
# X_max restricted to 2.102354 to stay on the LP01 branch
# X_max restricted to 2.102563 to stay on the LP01 branch
# X_max restricted to 2.102773 to stay on the LP01 branch
# X_max restricted to 2.102982 to stay on the LP01 branch
# X_max restricted to 2.103192 to stay on the LP01 branch
# X_max restricted to 2.103401 to stay on the LP01 branch
# X_max restricted to 2.103610 to stay on the LP01 branch
# X_max restricted to 2.103820 to stay on the LP01 branch
# X_max restricted to 2.104029 to stay on the LP01 branch
# X_max restricted to 2.104239 to stay on the LP01 branch
# X_max restricted to 2.104448 to stay on the LP01 branch
# X_max restricted to 2.104658 to stay on the LP01 branch
# X_max restricted to 2.104867 to stay on the LP01 branch
# X_max restricted to 2.105077 to stay on the LP01 branch
# X_max restricted to 2.105286 to stay on the LP01 branch
# X_max restricted to 2.105495 to stay on the LP01 branch
# X_max restricted to 2.105705 to stay on the LP01 branch
# X_max restricted to 2.105914 to stay on the LP01 branch
# X_max restricted to 2.106124 to stay on the LP01 branch
# X_max restricted to 2.106333 to stay on the LP01 branch
# X_max restricted to 2.106543 to stay on the LP01 branch
# X_max restricted to 2.106752 to stay on the LP01 branch
# X_max restricted to 2.106961 to stay on the LP01 branch
# X_max restricted to 2.107171 to stay on the LP01 branch
# X_max restricted to 2.107380 to stay on the LP01 branch
# X_max restricted to 2.107590 to stay on the LP01 branch
# X_max restricted to 2.107799 to stay on the LP01 branch
# X_max restricted to 2.108009 to stay on the LP01 branch
# X_max restricted to 2.108218 to stay on the LP01 branch
# X_max restricted to 2.108428 to stay on the LP01 branch
# X_max restricted to 2.108637 to stay on the LP01 branch
# X_max restricted to 2.108846 to stay on the LP01 branch
# X_max restricted to 2.109056 to stay on the LP01 branch
# X_max restricted to 2.109265 to stay on the LP01 branch
# X_max restricted to 2.109475 to stay on the LP01 branch
# X_max restricted to 2.109684 to stay on the LP01 branch
# X_max restricted to 2.109894 to stay on the LP01 branch
# X_max restricted to 2.110103 to stay on the LP01 branch
# X_max restricted to 2.110312 to stay on the LP01 branch
# X_max restricted to 2.110522 to stay on the LP01 branch
# X_max restricted to 2.110731 to stay on the LP01 branch
# X_max restricted to 2.110941 to stay on the LP01 branch
# X_max restricted to 2.111150 to stay on the LP01 branch
# X_max restricted to 2.111360 to stay on the LP01 branch
# X_max restricted to 2.111569 to stay on the LP01 branch
# X_max restricted to 2.111779 to stay on the LP01 branch
# X_max restricted to 2.111988 to stay on the LP01 branch
# X_max restricted to 2.112197 to stay on the LP01 branch
# X_max restricted to 2.112407 to stay on the LP01 branch
# X_max restricted to 2.112616 to stay on the LP01 branch
# X_max restricted to 2.112826 to stay on the LP01 branch
# X_max restricted to 2.113035 to stay on the LP01 branch
# X_max restricted to 2.113245 to stay on the LP01 branch
# X_max restricted to 2.113454 to stay on the LP01 branch
# X_max restricted to 2.113664 to stay on the LP01 branch
# X_max restricted to 2.113873 to stay on the LP01 branch
# X_max restricted to 2.114082 to stay on the LP01 branch
# X_max restricted to 2.114292 to stay on the LP01 branch
# X_max restricted to 2.114501 to stay on the LP01 branch
# X_max restricted to 2.114711 to stay on the LP01 branch
# X_max restricted to 2.114920 to stay on the LP01 branch
# X_max restricted to 2.115130 to stay on the LP01 branch
# X_max restricted to 2.115339 to stay on the LP01 branch
# X_max restricted to 2.115548 to stay on the LP01 branch
# X_max restricted to 2.115758 to stay on the LP01 branch
# X_max restricted to 2.115967 to stay on the LP01 branch
# X_max restricted to 2.116177 to stay on the LP01 branch
# X_max restricted to 2.116386 to stay on the LP01 branch
# X_max restricted to 2.116596 to stay on the LP01 branch
# X_max restricted to 2.116805 to stay on the LP01 branch
# X_max restricted to 2.117015 to stay on the LP01 branch
# X_max restricted to 2.117224 to stay on the LP01 branch
# X_max restricted to 2.117433 to stay on the LP01 branch
# X_max restricted to 2.117643 to stay on the LP01 branch
# X_max restricted to 2.117852 to stay on the LP01 branch
# X_max restricted to 2.118062 to stay on the LP01 branch
# X_max restricted to 2.118271 to stay on the LP01 branch
# X_max restricted to 2.118481 to stay on the LP01 branch
# X_max restricted to 2.118690 to stay on the LP01 branch
# X_max restricted to 2.118900 to stay on the LP01 branch
# X_max restricted to 2.119109 to stay on the LP01 branch
# X_max restricted to 2.119318 to stay on the LP01 branch
# X_max restricted to 2.119528 to stay on the LP01 branch
# X_max restricted to 2.119737 to stay on the LP01 branch
# X_max restricted to 2.119947 to stay on the LP01 branch
# X_max restricted to 2.120156 to stay on the LP01 branch
# X_max restricted to 2.120366 to stay on the LP01 branch
# X_max restricted to 2.120575 to stay on the LP01 branch
# X_max restricted to 2.120784 to stay on the LP01 branch
# X_max restricted to 2.120994 to stay on the LP01 branch
# X_max restricted to 2.121203 to stay on the LP01 branch
# X_max restricted to 2.121413 to stay on the LP01 branch
# X_max restricted to 2.121622 to stay on the LP01 branch
# X_max restricted to 2.121832 to stay on the LP01 branch
# X_max restricted to 2.122041 to stay on the LP01 branch
# X_max restricted to 2.122251 to stay on the LP01 branch
# X_max restricted to 2.122460 to stay on the LP01 branch
# X_max restricted to 2.122669 to stay on the LP01 branch
# X_max restricted to 2.122879 to stay on the LP01 branch
# X_max restricted to 2.123088 to stay on the LP01 branch
# X_max restricted to 2.123298 to stay on the LP01 branch
# X_max restricted to 2.123507 to stay on the LP01 branch
# X_max restricted to 2.123717 to stay on the LP01 branch
# X_max restricted to 2.123926 to stay on the LP01 branch
# X_max restricted to 2.124136 to stay on the LP01 branch
# X_max restricted to 2.124345 to stay on the LP01 branch
# X_max restricted to 2.124554 to stay on the LP01 branch
# X_max restricted to 2.124764 to stay on the LP01 branch
# X_max restricted to 2.124973 to stay on the LP01 branch
# X_max restricted to 2.125183 to stay on the LP01 branch
# X_max restricted to 2.125392 to stay on the LP01 branch
# X_max restricted to 2.125602 to stay on the LP01 branch
# X_max restricted to 2.125811 to stay on the LP01 branch
# X_max restricted to 2.126020 to stay on the LP01 branch
# X_max restricted to 2.126230 to stay on the LP01 branch
# X_max restricted to 2.126439 to stay on the LP01 branch
# X_max restricted to 2.126649 to stay on the LP01 branch
# X_max restricted to 2.126858 to stay on the LP01 branch
# X_max restricted to 2.127068 to stay on the LP01 branch
# X_max restricted to 2.127277 to stay on the LP01 branch
# X_max restricted to 2.127487 to stay on the LP01 branch
# X_max restricted to 2.127696 to stay on the LP01 branch
# X_max restricted to 2.127905 to stay on the LP01 branch
# X_max restricted to 2.128115 to stay on the LP01 branch
# X_max restricted to 2.128324 to stay on the LP01 branch
# X_max restricted to 2.128534 to stay on the LP01 branch
# X_max restricted to 2.128743 to stay on the LP01 branch
# X_max restricted to 2.128953 to stay on the LP01 branch
# X_max restricted to 2.129162 to stay on the LP01 branch
# X_max restricted to 2.129371 to stay on the LP01 branch
# X_max restricted to 2.129581 to stay on the LP01 branch
# X_max restricted to 2.129790 to stay on the LP01 branch
# X_max restricted to 2.130000 to stay on the LP01 branch
# X_max restricted to 2.130209 to stay on the LP01 branch
# X_max restricted to 2.130419 to stay on the LP01 branch
# X_max restricted to 2.130628 to stay on the LP01 branch
# X_max restricted to 2.130838 to stay on the LP01 branch
# X_max restricted to 2.131047 to stay on the LP01 branch
# X_max restricted to 2.131256 to stay on the LP01 branch
# X_max restricted to 2.131466 to stay on the LP01 branch
# X_max restricted to 2.131675 to stay on the LP01 branch
# X_max restricted to 2.131885 to stay on the LP01 branch
# X_max restricted to 2.132094 to stay on the LP01 branch
# X_max restricted to 2.132304 to stay on the LP01 branch
# X_max restricted to 2.132513 to stay on the LP01 branch
# X_max restricted to 2.132723 to stay on the LP01 branch
# X_max restricted to 2.132932 to stay on the LP01 branch
# X_max restricted to 2.133141 to stay on the LP01 branch
# X_max restricted to 2.133351 to stay on the LP01 branch
# X_max restricted to 2.133560 to stay on the LP01 branch
# X_max restricted to 2.133770 to stay on the LP01 branch
# X_max restricted to 2.133979 to stay on the LP01 branch
# X_max restricted to 2.134189 to stay on the LP01 branch
# X_max restricted to 2.134398 to stay on the LP01 branch
# X_max restricted to 2.134607 to stay on the LP01 branch
# X_max restricted to 2.134817 to stay on the LP01 branch
# X_max restricted to 2.135026 to stay on the LP01 branch
# X_max restricted to 2.135236 to stay on the LP01 branch
# X_max restricted to 2.135445 to stay on the LP01 branch
# X_max restricted to 2.135655 to stay on the LP01 branch
# X_max restricted to 2.135864 to stay on the LP01 branch
# X_max restricted to 2.136074 to stay on the LP01 branch
# X_max restricted to 2.136283 to stay on the LP01 branch
# X_max restricted to 2.136492 to stay on the LP01 branch
# X_max restricted to 2.136702 to stay on the LP01 branch
# X_max restricted to 2.136911 to stay on the LP01 branch
# X_max restricted to 2.137121 to stay on the LP01 branch
# X_max restricted to 2.137330 to stay on the LP01 branch
# X_max restricted to 2.137540 to stay on the LP01 branch
# X_max restricted to 2.137749 to stay on the LP01 branch
# X_max restricted to 2.137959 to stay on the LP01 branch
# X_max restricted to 2.138168 to stay on the LP01 branch
# X_max restricted to 2.138377 to stay on the LP01 branch
# X_max restricted to 2.138587 to stay on the LP01 branch
# X_max restricted to 2.138796 to stay on the LP01 branch
# X_max restricted to 2.139006 to stay on the LP01 branch
# X_max restricted to 2.139215 to stay on the LP01 branch
# X_max restricted to 2.139425 to stay on the LP01 branch
# X_max restricted to 2.139634 to stay on the LP01 branch
# X_max restricted to 2.139843 to stay on the LP01 branch
# X_max restricted to 2.140053 to stay on the LP01 branch
# X_max restricted to 2.140262 to stay on the LP01 branch
# X_max restricted to 2.140472 to stay on the LP01 branch
# X_max restricted to 2.140681 to stay on the LP01 branch
# X_max restricted to 2.140891 to stay on the LP01 branch
# X_max restricted to 2.141100 to stay on the LP01 branch
# X_max restricted to 2.141310 to stay on the LP01 branch
# X_max restricted to 2.141519 to stay on the LP01 branch
# X_max restricted to 2.141728 to stay on the LP01 branch
# X_max restricted to 2.141938 to stay on the LP01 branch
# X_max restricted to 2.142147 to stay on the LP01 branch
# X_max restricted to 2.142357 to stay on the LP01 branch
# X_max restricted to 2.142566 to stay on the LP01 branch
# X_max restricted to 2.142776 to stay on the LP01 branch
# X_max restricted to 2.142985 to stay on the LP01 branch
# X_max restricted to 2.143194 to stay on the LP01 branch
# X_max restricted to 2.143404 to stay on the LP01 branch
# X_max restricted to 2.143613 to stay on the LP01 branch
# X_max restricted to 2.143823 to stay on the LP01 branch
# X_max restricted to 2.144032 to stay on the LP01 branch
# X_max restricted to 2.144242 to stay on the LP01 branch
# X_max restricted to 2.144451 to stay on the LP01 branch
# X_max restricted to 2.144661 to stay on the LP01 branch
# X_max restricted to 2.144870 to stay on the LP01 branch
# X_max restricted to 2.145079 to stay on the LP01 branch
# X_max restricted to 2.145289 to stay on the LP01 branch
# X_max restricted to 2.145498 to stay on the LP01 branch
# X_max restricted to 2.145708 to stay on the LP01 branch
# X_max restricted to 2.145917 to stay on the LP01 branch
# X_max restricted to 2.146127 to stay on the LP01 branch
# X_max restricted to 2.146336 to stay on the LP01 branch
# X_max restricted to 2.146546 to stay on the LP01 branch
# X_max restricted to 2.146755 to stay on the LP01 branch
# X_max restricted to 2.146964 to stay on the LP01 branch
# X_max restricted to 2.147174 to stay on the LP01 branch
# X_max restricted to 2.147383 to stay on the LP01 branch
# X_max restricted to 2.147593 to stay on the LP01 branch
# X_max restricted to 2.147802 to stay on the LP01 branch
# X_max restricted to 2.148012 to stay on the LP01 branch
# X_max restricted to 2.148221 to stay on the LP01 branch
# X_max restricted to 2.148430 to stay on the LP01 branch
# X_max restricted to 2.148640 to stay on the LP01 branch
# X_max restricted to 2.148849 to stay on the LP01 branch
# X_max restricted to 2.149059 to stay on the LP01 branch
# X_max restricted to 2.149268 to stay on the LP01 branch
# X_max restricted to 2.149478 to stay on the LP01 branch
# X_max restricted to 2.149687 to stay on the LP01 branch
# X_max restricted to 2.149897 to stay on the LP01 branch
# X_max restricted to 2.150106 to stay on the LP01 branch
# X_max restricted to 2.150315 to stay on the LP01 branch
# X_max restricted to 2.150525 to stay on the LP01 branch
# X_max restricted to 2.150734 to stay on the LP01 branch
# X_max restricted to 2.150944 to stay on the LP01 branch
# X_max restricted to 2.151153 to stay on the LP01 branch
# X_max restricted to 2.151363 to stay on the LP01 branch
# X_max restricted to 2.151572 to stay on the LP01 branch
# X_max restricted to 2.151782 to stay on the LP01 branch
# X_max restricted to 2.151991 to stay on the LP01 branch
# X_max restricted to 2.152200 to stay on the LP01 branch
# X_max restricted to 2.152410 to stay on the LP01 branch
# X_max restricted to 2.152619 to stay on the LP01 branch
# X_max restricted to 2.152829 to stay on the LP01 branch
# X_max restricted to 2.153038 to stay on the LP01 branch
# X_max restricted to 2.153248 to stay on the LP01 branch
# X_max restricted to 2.153457 to stay on the LP01 branch
# X_max restricted to 2.153666 to stay on the LP01 branch
# X_max restricted to 2.153876 to stay on the LP01 branch
# X_max restricted to 2.154085 to stay on the LP01 branch
# X_max restricted to 2.154295 to stay on the LP01 branch
# X_max restricted to 2.154504 to stay on the LP01 branch
# X_max restricted to 2.154714 to stay on the LP01 branch
# X_max restricted to 2.154923 to stay on the LP01 branch
# X_max restricted to 2.155133 to stay on the LP01 branch
# X_max restricted to 2.155342 to stay on the LP01 branch
# X_max restricted to 2.155551 to stay on the LP01 branch
# X_max restricted to 2.155761 to stay on the LP01 branch
# X_max restricted to 2.155970 to stay on the LP01 branch
# X_max restricted to 2.156180 to stay on the LP01 branch
# X_max restricted to 2.156389 to stay on the LP01 branch
# X_max restricted to 2.156599 to stay on the LP01 branch
# X_max restricted to 2.156808 to stay on the LP01 branch
# X_max restricted to 2.157018 to stay on the LP01 branch
# X_max restricted to 2.157227 to stay on the LP01 branch
# X_max restricted to 2.157436 to stay on the LP01 branch
# X_max restricted to 2.157646 to stay on the LP01 branch
# X_max restricted to 2.157855 to stay on the LP01 branch
# X_max restricted to 2.158065 to stay on the LP01 branch
# X_max restricted to 2.158274 to stay on the LP01 branch
# X_max restricted to 2.158484 to stay on the LP01 branch
# X_max restricted to 2.158693 to stay on the LP01 branch
# X_max restricted to 2.158902 to stay on the LP01 branch
# X_max restricted to 2.159112 to stay on the LP01 branch
# X_max restricted to 2.159321 to stay on the LP01 branch
# X_max restricted to 2.159531 to stay on the LP01 branch
# X_max restricted to 2.159740 to stay on the LP01 branch
# X_max restricted to 2.159950 to stay on the LP01 branch
# X_max restricted to 2.160159 to stay on the LP01 branch
# X_max restricted to 2.160369 to stay on the LP01 branch
# X_max restricted to 2.160578 to stay on the LP01 branch
# X_max restricted to 2.160787 to stay on the LP01 branch
# X_max restricted to 2.160997 to stay on the LP01 branch
# X_max restricted to 2.161206 to stay on the LP01 branch
# X_max restricted to 2.161416 to stay on the LP01 branch
# X_max restricted to 2.161625 to stay on the LP01 branch
# X_max restricted to 2.161835 to stay on the LP01 branch
# X_max restricted to 2.162044 to stay on the LP01 branch
# X_max restricted to 2.162253 to stay on the LP01 branch
# X_max restricted to 2.162463 to stay on the LP01 branch
# X_max restricted to 2.162672 to stay on the LP01 branch
# X_max restricted to 2.162882 to stay on the LP01 branch
# X_max restricted to 2.163091 to stay on the LP01 branch
# X_max restricted to 2.163301 to stay on the LP01 branch
# X_max restricted to 2.163510 to stay on the LP01 branch
# X_max restricted to 2.163720 to stay on the LP01 branch
# X_max restricted to 2.163929 to stay on the LP01 branch
# X_max restricted to 2.164138 to stay on the LP01 branch
# X_max restricted to 2.164348 to stay on the LP01 branch
# X_max restricted to 2.164557 to stay on the LP01 branch
# X_max restricted to 2.164767 to stay on the LP01 branch
# X_max restricted to 2.164976 to stay on the LP01 branch
# X_max restricted to 2.165186 to stay on the LP01 branch
# X_max restricted to 2.165395 to stay on the LP01 branch
# X_max restricted to 2.165605 to stay on the LP01 branch
# X_max restricted to 2.165814 to stay on the LP01 branch
# X_max restricted to 2.166023 to stay on the LP01 branch
# X_max restricted to 2.166233 to stay on the LP01 branch
# X_max restricted to 2.166442 to stay on the LP01 branch
# X_max restricted to 2.166652 to stay on the LP01 branch
# X_max restricted to 2.166861 to stay on the LP01 branch
# X_max restricted to 2.167071 to stay on the LP01 branch
# X_max restricted to 2.167280 to stay on the LP01 branch
# X_max restricted to 2.167489 to stay on the LP01 branch
# X_max restricted to 2.167699 to stay on the LP01 branch
# X_max restricted to 2.167908 to stay on the LP01 branch
# X_max restricted to 2.168118 to stay on the LP01 branch
# X_max restricted to 2.168327 to stay on the LP01 branch
# X_max restricted to 2.168537 to stay on the LP01 branch
# X_max restricted to 2.168746 to stay on the LP01 branch
# X_max restricted to 2.168956 to stay on the LP01 branch
# X_max restricted to 2.169165 to stay on the LP01 branch
# X_max restricted to 2.169374 to stay on the LP01 branch
# X_max restricted to 2.169584 to stay on the LP01 branch
# X_max restricted to 2.169793 to stay on the LP01 branch
# X_max restricted to 2.170003 to stay on the LP01 branch
# X_max restricted to 2.170212 to stay on the LP01 branch
# X_max restricted to 2.170422 to stay on the LP01 branch
# X_max restricted to 2.170631 to stay on the LP01 branch
# X_max restricted to 2.170841 to stay on the LP01 branch
# X_max restricted to 2.171050 to stay on the LP01 branch
# X_max restricted to 2.171259 to stay on the LP01 branch
# X_max restricted to 2.171469 to stay on the LP01 branch
# X_max restricted to 2.171678 to stay on the LP01 branch
# X_max restricted to 2.171888 to stay on the LP01 branch
# X_max restricted to 2.172097 to stay on the LP01 branch
# X_max restricted to 2.172307 to stay on the LP01 branch
# X_max restricted to 2.172516 to stay on the LP01 branch
# X_max restricted to 2.172725 to stay on the LP01 branch
# X_max restricted to 2.172935 to stay on the LP01 branch
# X_max restricted to 2.173144 to stay on the LP01 branch
# X_max restricted to 2.173354 to stay on the LP01 branch
# X_max restricted to 2.173563 to stay on the LP01 branch
# X_max restricted to 2.173773 to stay on the LP01 branch
# X_max restricted to 2.173982 to stay on the LP01 branch
# X_max restricted to 2.174192 to stay on the LP01 branch
# X_max restricted to 2.174401 to stay on the LP01 branch
# X_max restricted to 2.174610 to stay on the LP01 branch
# X_max restricted to 2.174820 to stay on the LP01 branch
# X_max restricted to 2.175029 to stay on the LP01 branch
# X_max restricted to 2.175239 to stay on the LP01 branch
# X_max restricted to 2.175448 to stay on the LP01 branch
# X_max restricted to 2.175658 to stay on the LP01 branch
# X_max restricted to 2.175867 to stay on the LP01 branch
# X_max restricted to 2.176077 to stay on the LP01 branch
# X_max restricted to 2.176286 to stay on the LP01 branch
# X_max restricted to 2.176495 to stay on the LP01 branch
# X_max restricted to 2.176705 to stay on the LP01 branch
# X_max restricted to 2.176914 to stay on the LP01 branch
# X_max restricted to 2.177124 to stay on the LP01 branch
# X_max restricted to 2.177333 to stay on the LP01 branch
# X_max restricted to 2.177543 to stay on the LP01 branch
# X_max restricted to 2.177752 to stay on the LP01 branch
# X_max restricted to 2.177961 to stay on the LP01 branch
# X_max restricted to 2.178171 to stay on the LP01 branch
# X_max restricted to 2.178380 to stay on the LP01 branch
# X_max restricted to 2.178590 to stay on the LP01 branch
# X_max restricted to 2.178799 to stay on the LP01 branch
# X_max restricted to 2.179009 to stay on the LP01 branch
# X_max restricted to 2.179218 to stay on the LP01 branch
# X_max restricted to 2.179428 to stay on the LP01 branch
# X_max restricted to 2.179637 to stay on the LP01 branch
# X_max restricted to 2.179846 to stay on the LP01 branch
# X_max restricted to 2.180056 to stay on the LP01 branch
# X_max restricted to 2.180265 to stay on the LP01 branch
# X_max restricted to 2.180475 to stay on the LP01 branch
# X_max restricted to 2.180684 to stay on the LP01 branch
# X_max restricted to 2.180894 to stay on the LP01 branch
# X_max restricted to 2.181103 to stay on the LP01 branch
# X_max restricted to 2.181312 to stay on the LP01 branch
# X_max restricted to 2.181522 to stay on the LP01 branch
# X_max restricted to 2.181731 to stay on the LP01 branch
# X_max restricted to 2.181941 to stay on the LP01 branch
# X_max restricted to 2.182150 to stay on the LP01 branch
# X_max restricted to 2.182360 to stay on the LP01 branch
# X_max restricted to 2.182569 to stay on the LP01 branch
# X_max restricted to 2.182779 to stay on the LP01 branch
# X_max restricted to 2.182988 to stay on the LP01 branch
# X_max restricted to 2.183197 to stay on the LP01 branch
# X_max restricted to 2.183407 to stay on the LP01 branch
# X_max restricted to 2.183616 to stay on the LP01 branch
# X_max restricted to 2.183826 to stay on the LP01 branch
# X_max restricted to 2.184035 to stay on the LP01 branch
# X_max restricted to 2.184245 to stay on the LP01 branch
# X_max restricted to 2.184454 to stay on the LP01 branch
# X_max restricted to 2.184664 to stay on the LP01 branch
# X_max restricted to 2.184873 to stay on the LP01 branch
# X_max restricted to 2.185082 to stay on the LP01 branch
# X_max restricted to 2.185292 to stay on the LP01 branch
# X_max restricted to 2.185501 to stay on the LP01 branch
# X_max restricted to 2.185711 to stay on the LP01 branch
# X_max restricted to 2.185920 to stay on the LP01 branch
# X_max restricted to 2.186130 to stay on the LP01 branch
# X_max restricted to 2.186339 to stay on the LP01 branch
# X_max restricted to 2.186548 to stay on the LP01 branch
# X_max restricted to 2.186758 to stay on the LP01 branch
# X_max restricted to 2.186967 to stay on the LP01 branch
# X_max restricted to 2.187177 to stay on the LP01 branch
# X_max restricted to 2.187386 to stay on the LP01 branch
# X_max restricted to 2.187596 to stay on the LP01 branch
# X_max restricted to 2.187805 to stay on the LP01 branch
# X_max restricted to 2.188015 to stay on the LP01 branch
# X_max restricted to 2.188224 to stay on the LP01 branch
# X_max restricted to 2.188433 to stay on the LP01 branch
# X_max restricted to 2.188643 to stay on the LP01 branch
# X_max restricted to 2.188852 to stay on the LP01 branch
# X_max restricted to 2.189062 to stay on the LP01 branch
# X_max restricted to 2.189271 to stay on the LP01 branch
# X_max restricted to 2.189481 to stay on the LP01 branch
# X_max restricted to 2.189690 to stay on the LP01 branch
# X_max restricted to 2.189900 to stay on the LP01 branch
# X_max restricted to 2.190109 to stay on the LP01 branch
# X_max restricted to 2.190318 to stay on the LP01 branch
# X_max restricted to 2.190528 to stay on the LP01 branch
# X_max restricted to 2.190737 to stay on the LP01 branch
# X_max restricted to 2.190947 to stay on the LP01 branch
# X_max restricted to 2.191156 to stay on the LP01 branch
# X_max restricted to 2.191366 to stay on the LP01 branch
# X_max restricted to 2.191575 to stay on the LP01 branch
# X_max restricted to 2.191784 to stay on the LP01 branch
# X_max restricted to 2.191994 to stay on the LP01 branch
# X_max restricted to 2.192203 to stay on the LP01 branch
# X_max restricted to 2.192413 to stay on the LP01 branch
# X_max restricted to 2.192622 to stay on the LP01 branch
# X_max restricted to 2.192832 to stay on the LP01 branch
# X_max restricted to 2.193041 to stay on the LP01 branch
# X_max restricted to 2.193251 to stay on the LP01 branch
# X_max restricted to 2.193460 to stay on the LP01 branch
# X_max restricted to 2.193669 to stay on the LP01 branch
# X_max restricted to 2.193879 to stay on the LP01 branch
# X_max restricted to 2.194088 to stay on the LP01 branch
# X_max restricted to 2.194298 to stay on the LP01 branch
# X_max restricted to 2.194507 to stay on the LP01 branch
# X_max restricted to 2.194717 to stay on the LP01 branch
# X_max restricted to 2.194926 to stay on the LP01 branch
# X_max restricted to 2.195135 to stay on the LP01 branch
# X_max restricted to 2.195345 to stay on the LP01 branch
# X_max restricted to 2.195554 to stay on the LP01 branch
# X_max restricted to 2.195764 to stay on the LP01 branch
# X_max restricted to 2.195973 to stay on the LP01 branch
# X_max restricted to 2.196183 to stay on the LP01 branch
# X_max restricted to 2.196392 to stay on the LP01 branch
# X_max restricted to 2.196602 to stay on the LP01 branch
# X_max restricted to 2.196811 to stay on the LP01 branch
# X_max restricted to 2.197020 to stay on the LP01 branch
# X_max restricted to 2.197230 to stay on the LP01 branch
# X_max restricted to 2.197439 to stay on the LP01 branch
# X_max restricted to 2.197649 to stay on the LP01 branch
# X_max restricted to 2.197858 to stay on the LP01 branch
# X_max restricted to 2.198068 to stay on the LP01 branch
# X_max restricted to 2.198277 to stay on the LP01 branch
# X_max restricted to 2.198487 to stay on the LP01 branch
# X_max restricted to 2.198696 to stay on the LP01 branch
# X_max restricted to 2.198905 to stay on the LP01 branch
# X_max restricted to 2.199115 to stay on the LP01 branch
# X_max restricted to 2.199324 to stay on the LP01 branch
# X_max restricted to 2.199534 to stay on the LP01 branch
# X_max restricted to 2.199743 to stay on the LP01 branch
# X_max restricted to 2.199953 to stay on the LP01 branch
# X_max restricted to 2.200162 to stay on the LP01 branch
# X_max restricted to 2.200371 to stay on the LP01 branch
# X_max restricted to 2.200581 to stay on the LP01 branch
# X_max restricted to 2.200790 to stay on the LP01 branch
# X_max restricted to 2.201000 to stay on the LP01 branch
# X_max restricted to 2.201209 to stay on the LP01 branch
# X_max restricted to 2.201419 to stay on the LP01 branch
# X_max restricted to 2.201628 to stay on the LP01 branch
# X_max restricted to 2.201838 to stay on the LP01 branch
# X_max restricted to 2.202047 to stay on the LP01 branch
# X_max restricted to 2.202256 to stay on the LP01 branch
# X_max restricted to 2.202466 to stay on the LP01 branch
# X_max restricted to 2.202675 to stay on the LP01 branch
# X_max restricted to 2.202885 to stay on the LP01 branch
# X_max restricted to 2.203094 to stay on the LP01 branch
# X_max restricted to 2.203304 to stay on the LP01 branch
# X_max restricted to 2.203513 to stay on the LP01 branch
# X_max restricted to 2.203723 to stay on the LP01 branch
# X_max restricted to 2.203932 to stay on the LP01 branch
# X_max restricted to 2.204141 to stay on the LP01 branch
# X_max restricted to 2.204351 to stay on the LP01 branch
# X_max restricted to 2.204560 to stay on the LP01 branch
# X_max restricted to 2.204770 to stay on the LP01 branch
# X_max restricted to 2.204979 to stay on the LP01 branch
# X_max restricted to 2.205189 to stay on the LP01 branch
# X_max restricted to 2.205398 to stay on the LP01 branch
# X_max restricted to 2.205607 to stay on the LP01 branch
# X_max restricted to 2.205817 to stay on the LP01 branch
# X_max restricted to 2.206026 to stay on the LP01 branch
# X_max restricted to 2.206236 to stay on the LP01 branch
# X_max restricted to 2.206445 to stay on the LP01 branch
# X_max restricted to 2.206655 to stay on the LP01 branch
# X_max restricted to 2.206864 to stay on the LP01 branch
# X_max restricted to 2.207074 to stay on the LP01 branch
# X_max restricted to 2.207283 to stay on the LP01 branch
# X_max restricted to 2.207492 to stay on the LP01 branch
# X_max restricted to 2.207702 to stay on the LP01 branch
# X_max restricted to 2.207911 to stay on the LP01 branch
# X_max restricted to 2.208121 to stay on the LP01 branch
# X_max restricted to 2.208330 to stay on the LP01 branch
# X_max restricted to 2.208540 to stay on the LP01 branch
# X_max restricted to 2.208749 to stay on the LP01 branch
# X_max restricted to 2.208959 to stay on the LP01 branch
# X_max restricted to 2.209168 to stay on the LP01 branch
# X_max restricted to 2.209377 to stay on the LP01 branch
# X_max restricted to 2.209587 to stay on the LP01 branch
# X_max restricted to 2.209796 to stay on the LP01 branch
# X_max restricted to 2.210006 to stay on the LP01 branch
# X_max restricted to 2.210215 to stay on the LP01 branch
# X_max restricted to 2.210425 to stay on the LP01 branch
# X_max restricted to 2.210634 to stay on the LP01 branch
# X_max restricted to 2.210843 to stay on the LP01 branch
# X_max restricted to 2.211053 to stay on the LP01 branch
# X_max restricted to 2.211262 to stay on the LP01 branch
# X_max restricted to 2.211472 to stay on the LP01 branch
# X_max restricted to 2.211681 to stay on the LP01 branch
# X_max restricted to 2.211891 to stay on the LP01 branch
# X_max restricted to 2.212100 to stay on the LP01 branch
# X_max restricted to 2.212310 to stay on the LP01 branch
# X_max restricted to 2.212519 to stay on the LP01 branch
# X_max restricted to 2.212728 to stay on the LP01 branch
# X_max restricted to 2.212938 to stay on the LP01 branch
# X_max restricted to 2.213147 to stay on the LP01 branch
# X_max restricted to 2.213357 to stay on the LP01 branch
# X_max restricted to 2.213566 to stay on the LP01 branch
# X_max restricted to 2.213776 to stay on the LP01 branch
# X_max restricted to 2.213985 to stay on the LP01 branch
# X_max restricted to 2.214194 to stay on the LP01 branch
# X_max restricted to 2.214404 to stay on the LP01 branch
# X_max restricted to 2.214613 to stay on the LP01 branch
# X_max restricted to 2.214823 to stay on the LP01 branch
# X_max restricted to 2.215032 to stay on the LP01 branch
# X_max restricted to 2.215242 to stay on the LP01 branch
# X_max restricted to 2.215451 to stay on the LP01 branch
# X_max restricted to 2.215661 to stay on the LP01 branch
# X_max restricted to 2.215870 to stay on the LP01 branch
# X_max restricted to 2.216079 to stay on the LP01 branch
# X_max restricted to 2.216289 to stay on the LP01 branch
# X_max restricted to 2.216498 to stay on the LP01 branch
# X_max restricted to 2.216708 to stay on the LP01 branch
# X_max restricted to 2.216917 to stay on the LP01 branch
# X_max restricted to 2.217127 to stay on the LP01 branch
# X_max restricted to 2.217336 to stay on the LP01 branch
# X_max restricted to 2.217546 to stay on the LP01 branch
# X_max restricted to 2.217755 to stay on the LP01 branch
# X_max restricted to 2.217964 to stay on the LP01 branch
# X_max restricted to 2.218174 to stay on the LP01 branch
# X_max restricted to 2.218383 to stay on the LP01 branch
# X_max restricted to 2.218593 to stay on the LP01 branch
# X_max restricted to 2.218802 to stay on the LP01 branch
# X_max restricted to 2.219012 to stay on the LP01 branch
# X_max restricted to 2.219221 to stay on the LP01 branch
# X_max restricted to 2.219430 to stay on the LP01 branch
# X_max restricted to 2.219640 to stay on the LP01 branch
# X_max restricted to 2.219849 to stay on the LP01 branch
# X_max restricted to 2.220059 to stay on the LP01 branch
# X_max restricted to 2.220268 to stay on the LP01 branch
# X_max restricted to 2.220478 to stay on the LP01 branch
# X_max restricted to 2.220687 to stay on the LP01 branch
# X_max restricted to 2.220897 to stay on the LP01 branch
# X_max restricted to 2.221106 to stay on the LP01 branch
# X_max restricted to 2.221315 to stay on the LP01 branch
# X_max restricted to 2.221525 to stay on the LP01 branch
# X_max restricted to 2.221734 to stay on the LP01 branch
# X_max restricted to 2.221944 to stay on the LP01 branch
# X_max restricted to 2.222153 to stay on the LP01 branch
# X_max restricted to 2.222363 to stay on the LP01 branch
# X_max restricted to 2.222572 to stay on the LP01 branch
# X_max restricted to 2.222782 to stay on the LP01 branch
# X_max restricted to 2.222991 to stay on the LP01 branch
# X_max restricted to 2.223200 to stay on the LP01 branch
# X_max restricted to 2.223410 to stay on the LP01 branch
# X_max restricted to 2.223619 to stay on the LP01 branch
# X_max restricted to 2.223829 to stay on the LP01 branch
# X_max restricted to 2.224038 to stay on the LP01 branch
# X_max restricted to 2.224248 to stay on the LP01 branch
# X_max restricted to 2.224457 to stay on the LP01 branch
# X_max restricted to 2.224666 to stay on the LP01 branch
# X_max restricted to 2.224876 to stay on the LP01 branch
# X_max restricted to 2.225085 to stay on the LP01 branch
# X_max restricted to 2.225295 to stay on the LP01 branch
# X_max restricted to 2.225504 to stay on the LP01 branch
# X_max restricted to 2.225714 to stay on the LP01 branch
# X_max restricted to 2.225923 to stay on the LP01 branch
# X_max restricted to 2.226133 to stay on the LP01 branch
# X_max restricted to 2.226342 to stay on the LP01 branch
# X_max restricted to 2.226551 to stay on the LP01 branch
# X_max restricted to 2.226761 to stay on the LP01 branch
# X_max restricted to 2.226970 to stay on the LP01 branch
# X_max restricted to 2.227180 to stay on the LP01 branch
# X_max restricted to 2.227389 to stay on the LP01 branch
# X_max restricted to 2.227599 to stay on the LP01 branch
# X_max restricted to 2.227808 to stay on the LP01 branch
# X_max restricted to 2.228017 to stay on the LP01 branch
# X_max restricted to 2.228227 to stay on the LP01 branch
# X_max restricted to 2.228436 to stay on the LP01 branch
# X_max restricted to 2.228646 to stay on the LP01 branch
# X_max restricted to 2.228855 to stay on the LP01 branch
# X_max restricted to 2.229065 to stay on the LP01 branch
# X_max restricted to 2.229274 to stay on the LP01 branch
# X_max restricted to 2.229484 to stay on the LP01 branch
# X_max restricted to 2.229693 to stay on the LP01 branch
# X_max restricted to 2.229902 to stay on the LP01 branch
# X_max restricted to 2.230112 to stay on the LP01 branch
# X_max restricted to 2.230321 to stay on the LP01 branch
# X_max restricted to 2.230531 to stay on the LP01 branch
# X_max restricted to 2.230740 to stay on the LP01 branch
# X_max restricted to 2.230950 to stay on the LP01 branch
# X_max restricted to 2.231159 to stay on the LP01 branch
# X_max restricted to 2.231369 to stay on the LP01 branch
# X_max restricted to 2.231578 to stay on the LP01 branch
# X_max restricted to 2.231787 to stay on the LP01 branch
# X_max restricted to 2.231997 to stay on the LP01 branch
# X_max restricted to 2.232206 to stay on the LP01 branch
# X_max restricted to 2.232416 to stay on the LP01 branch
# X_max restricted to 2.232625 to stay on the LP01 branch
# X_max restricted to 2.232835 to stay on the LP01 branch
# X_max restricted to 2.233044 to stay on the LP01 branch
# X_max restricted to 2.233253 to stay on the LP01 branch
# X_max restricted to 2.233463 to stay on the LP01 branch
# X_max restricted to 2.233672 to stay on the LP01 branch
# X_max restricted to 2.233882 to stay on the LP01 branch
# X_max restricted to 2.234091 to stay on the LP01 branch
# X_max restricted to 2.234301 to stay on the LP01 branch
# X_max restricted to 2.234510 to stay on the LP01 branch
# X_max restricted to 2.234720 to stay on the LP01 branch
# X_max restricted to 2.234929 to stay on the LP01 branch
# X_max restricted to 2.235138 to stay on the LP01 branch
# X_max restricted to 2.235348 to stay on the LP01 branch
# X_max restricted to 2.235557 to stay on the LP01 branch
# X_max restricted to 2.235767 to stay on the LP01 branch
# X_max restricted to 2.235976 to stay on the LP01 branch
# X_max restricted to 2.236186 to stay on the LP01 branch
# X_max restricted to 2.236395 to stay on the LP01 branch
# X_max restricted to 2.236605 to stay on the LP01 branch
# X_max restricted to 2.236814 to stay on the LP01 branch
# X_max restricted to 2.237023 to stay on the LP01 branch
# X_max restricted to 2.237233 to stay on the LP01 branch
# X_max restricted to 2.237442 to stay on the LP01 branch
# X_max restricted to 2.237652 to stay on the LP01 branch
# X_max restricted to 2.237861 to stay on the LP01 branch
# X_max restricted to 2.238071 to stay on the LP01 branch
# X_max restricted to 2.238280 to stay on the LP01 branch
# X_max restricted to 2.238489 to stay on the LP01 branch
# X_max restricted to 2.238699 to stay on the LP01 branch
# X_max restricted to 2.238908 to stay on the LP01 branch
# X_max restricted to 2.239118 to stay on the LP01 branch
# X_max restricted to 2.239327 to stay on the LP01 branch
# X_max restricted to 2.239537 to stay on the LP01 branch
# X_max restricted to 2.239746 to stay on the LP01 branch
# X_max restricted to 2.239956 to stay on the LP01 branch
# X_max restricted to 2.240165 to stay on the LP01 branch
# X_max restricted to 2.240374 to stay on the LP01 branch
# X_max restricted to 2.240584 to stay on the LP01 branch
# X_max restricted to 2.240793 to stay on the LP01 branch
# X_max restricted to 2.241003 to stay on the LP01 branch
# X_max restricted to 2.241212 to stay on the LP01 branch
# X_max restricted to 2.241422 to stay on the LP01 branch
# X_max restricted to 2.241631 to stay on the LP01 branch
# X_max restricted to 2.241841 to stay on the LP01 branch
# X_max restricted to 2.242050 to stay on the LP01 branch
# X_max restricted to 2.242259 to stay on the LP01 branch
# X_max restricted to 2.242469 to stay on the LP01 branch
# X_max restricted to 2.242678 to stay on the LP01 branch
# X_max restricted to 2.242888 to stay on the LP01 branch
# X_max restricted to 2.243097 to stay on the LP01 branch
# X_max restricted to 2.243307 to stay on the LP01 branch
# X_max restricted to 2.243516 to stay on the LP01 branch
# X_max restricted to 2.243725 to stay on the LP01 branch
# X_max restricted to 2.243935 to stay on the LP01 branch
# X_max restricted to 2.244144 to stay on the LP01 branch
# X_max restricted to 2.244354 to stay on the LP01 branch
# X_max restricted to 2.244563 to stay on the LP01 branch
# X_max restricted to 2.244773 to stay on the LP01 branch
# X_max restricted to 2.244982 to stay on the LP01 branch
# X_max restricted to 2.245192 to stay on the LP01 branch
# X_max restricted to 2.245401 to stay on the LP01 branch
# X_max restricted to 2.245610 to stay on the LP01 branch
# X_max restricted to 2.245820 to stay on the LP01 branch
# X_max restricted to 2.246029 to stay on the LP01 branch
# X_max restricted to 2.246239 to stay on the LP01 branch
# X_max restricted to 2.246448 to stay on the LP01 branch
# X_max restricted to 2.246658 to stay on the LP01 branch
# X_max restricted to 2.246867 to stay on the LP01 branch
# X_max restricted to 2.247076 to stay on the LP01 branch
# X_max restricted to 2.247286 to stay on the LP01 branch
# X_max restricted to 2.247495 to stay on the LP01 branch
# X_max restricted to 2.247705 to stay on the LP01 branch
# X_max restricted to 2.247914 to stay on the LP01 branch
# X_max restricted to 2.248124 to stay on the LP01 branch
# X_max restricted to 2.248333 to stay on the LP01 branch
# X_max restricted to 2.248543 to stay on the LP01 branch
# X_max restricted to 2.248752 to stay on the LP01 branch
# X_max restricted to 2.248961 to stay on the LP01 branch
# X_max restricted to 2.249171 to stay on the LP01 branch
# X_max restricted to 2.249380 to stay on the LP01 branch
# X_max restricted to 2.249590 to stay on the LP01 branch
# X_max restricted to 2.249799 to stay on the LP01 branch
# X_max restricted to 2.250009 to stay on the LP01 branch
# X_max restricted to 2.250218 to stay on the LP01 branch
# X_max restricted to 2.250428 to stay on the LP01 branch
# X_max restricted to 2.250637 to stay on the LP01 branch
# X_max restricted to 2.250846 to stay on the LP01 branch
# X_max restricted to 2.251056 to stay on the LP01 branch
# X_max restricted to 2.251265 to stay on the LP01 branch
# X_max restricted to 2.251475 to stay on the LP01 branch
# X_max restricted to 2.251684 to stay on the LP01 branch
# X_max restricted to 2.251894 to stay on the LP01 branch
# X_max restricted to 2.252103 to stay on the LP01 branch
# X_max restricted to 2.252312 to stay on the LP01 branch
# X_max restricted to 2.252522 to stay on the LP01 branch
# X_max restricted to 2.252731 to stay on the LP01 branch
# X_max restricted to 2.252941 to stay on the LP01 branch
# X_max restricted to 2.253150 to stay on the LP01 branch
# X_max restricted to 2.253360 to stay on the LP01 branch
# X_max restricted to 2.253569 to stay on the LP01 branch
# X_max restricted to 2.253779 to stay on the LP01 branch
# X_max restricted to 2.253988 to stay on the LP01 branch
# X_max restricted to 2.254197 to stay on the LP01 branch
# X_max restricted to 2.254407 to stay on the LP01 branch
# X_max restricted to 2.254616 to stay on the LP01 branch
# X_max restricted to 2.254826 to stay on the LP01 branch
# X_max restricted to 2.255035 to stay on the LP01 branch
# X_max restricted to 2.255245 to stay on the LP01 branch
# X_max restricted to 2.255454 to stay on the LP01 branch
# X_max restricted to 2.255664 to stay on the LP01 branch
# X_max restricted to 2.255873 to stay on the LP01 branch
# X_max restricted to 2.256082 to stay on the LP01 branch
# X_max restricted to 2.256292 to stay on the LP01 branch
# X_max restricted to 2.256501 to stay on the LP01 branch
# X_max restricted to 2.256711 to stay on the LP01 branch
# X_max restricted to 2.256920 to stay on the LP01 branch
# X_max restricted to 2.257130 to stay on the LP01 branch
# X_max restricted to 2.257339 to stay on the LP01 branch
# X_max restricted to 2.257548 to stay on the LP01 branch
# X_max restricted to 2.257758 to stay on the LP01 branch
# X_max restricted to 2.257967 to stay on the LP01 branch
# X_max restricted to 2.258177 to stay on the LP01 branch
# X_max restricted to 2.258386 to stay on the LP01 branch
# X_max restricted to 2.258596 to stay on the LP01 branch
# X_max restricted to 2.258805 to stay on the LP01 branch
# X_max restricted to 2.259015 to stay on the LP01 branch
# X_max restricted to 2.259224 to stay on the LP01 branch
# X_max restricted to 2.259433 to stay on the LP01 branch
# X_max restricted to 2.259643 to stay on the LP01 branch
# X_max restricted to 2.259852 to stay on the LP01 branch
# X_max restricted to 2.260062 to stay on the LP01 branch
# X_max restricted to 2.260271 to stay on the LP01 branch
# X_max restricted to 2.260481 to stay on the LP01 branch
# X_max restricted to 2.260690 to stay on the LP01 branch
# X_max restricted to 2.260900 to stay on the LP01 branch
# X_max restricted to 2.261109 to stay on the LP01 branch
# X_max restricted to 2.261318 to stay on the LP01 branch
# X_max restricted to 2.261528 to stay on the LP01 branch
# X_max restricted to 2.261737 to stay on the LP01 branch
# X_max restricted to 2.261947 to stay on the LP01 branch
# X_max restricted to 2.262156 to stay on the LP01 branch
# X_max restricted to 2.262366 to stay on the LP01 branch
# X_max restricted to 2.262575 to stay on the LP01 branch
# X_max restricted to 2.262784 to stay on the LP01 branch
# X_max restricted to 2.262994 to stay on the LP01 branch
# X_max restricted to 2.263203 to stay on the LP01 branch
# X_max restricted to 2.263413 to stay on the LP01 branch
# X_max restricted to 2.263622 to stay on the LP01 branch
# X_max restricted to 2.263832 to stay on the LP01 branch
# X_max restricted to 2.264041 to stay on the LP01 branch
# X_max restricted to 2.264251 to stay on the LP01 branch
# X_max restricted to 2.264460 to stay on the LP01 branch
# X_max restricted to 2.264669 to stay on the LP01 branch
# X_max restricted to 2.264879 to stay on the LP01 branch
# X_max restricted to 2.265088 to stay on the LP01 branch
# X_max restricted to 2.265298 to stay on the LP01 branch
# X_max restricted to 2.265507 to stay on the LP01 branch
# X_max restricted to 2.265717 to stay on the LP01 branch
# X_max restricted to 2.265926 to stay on the LP01 branch
# X_max restricted to 2.266135 to stay on the LP01 branch
# X_max restricted to 2.266345 to stay on the LP01 branch
# X_max restricted to 2.266554 to stay on the LP01 branch
# X_max restricted to 2.266764 to stay on the LP01 branch
# X_max restricted to 2.266973 to stay on the LP01 branch
# X_max restricted to 2.267183 to stay on the LP01 branch
# X_max restricted to 2.267392 to stay on the LP01 branch
# X_max restricted to 2.267602 to stay on the LP01 branch
# X_max restricted to 2.267811 to stay on the LP01 branch
# X_max restricted to 2.268020 to stay on the LP01 branch
# X_max restricted to 2.268230 to stay on the LP01 branch
# X_max restricted to 2.268439 to stay on the LP01 branch
# X_max restricted to 2.268649 to stay on the LP01 branch
# X_max restricted to 2.268858 to stay on the LP01 branch
# X_max restricted to 2.269068 to stay on the LP01 branch
# X_max restricted to 2.269277 to stay on the LP01 branch
# X_max restricted to 2.269487 to stay on the LP01 branch
# X_max restricted to 2.269696 to stay on the LP01 branch
# X_max restricted to 2.269905 to stay on the LP01 branch
# X_max restricted to 2.270115 to stay on the LP01 branch
# X_max restricted to 2.270324 to stay on the LP01 branch
# X_max restricted to 2.270534 to stay on the LP01 branch
# X_max restricted to 2.270743 to stay on the LP01 branch
# X_max restricted to 2.270953 to stay on the LP01 branch
# X_max restricted to 2.271162 to stay on the LP01 branch
# X_max restricted to 2.271371 to stay on the LP01 branch
# X_max restricted to 2.271581 to stay on the LP01 branch
# X_max restricted to 2.271790 to stay on the LP01 branch
# X_max restricted to 2.272000 to stay on the LP01 branch
# X_max restricted to 2.272209 to stay on the LP01 branch
# X_max restricted to 2.272419 to stay on the LP01 branch
# X_max restricted to 2.272628 to stay on the LP01 branch
# X_max restricted to 2.272838 to stay on the LP01 branch
# X_max restricted to 2.273047 to stay on the LP01 branch
# X_max restricted to 2.273256 to stay on the LP01 branch
# X_max restricted to 2.273466 to stay on the LP01 branch
# X_max restricted to 2.273675 to stay on the LP01 branch
# ...
# X_max restricted to 2.345513 to stay on the LP01 branch
# X_max restricted to 2.345723 to stay on the LP01 branch
# X_max restricted to 2.345932 to stay on the LP01 branch
# X_max restricted to 2.346141 to stay on the LP01 branch
# X_max restricted to 2.346351 to stay on the LP01 branch
# X_max restricted to 2.346560 to stay on the LP01 branch
# X_max restricted to 2.346770 to stay on the LP01 branch
# X_max restricted to 2.346979 to stay on the LP01 branch
# X_max restricted to 2.347189 to stay on the LP01 branch
# X_max restricted to 2.347398 to stay on the LP01 branch
# X_max restricted to 2.347607 to stay on the LP01 branch
# X_max restricted to 2.347817 to stay on the LP01 branch
# X_max restricted to 2.348026 to stay on the LP01 branch
# X_max restricted to 2.348236 to stay on the LP01 branch
# X_max restricted to 2.348445 to stay on the LP01 branch
# X_max restricted to 2.348655 to stay on the LP01 branch
# X_max restricted to 2.348864 to stay on the LP01 branch
# X_max restricted to 2.349074 to stay on the LP01 branch
# X_max restricted to 2.349283 to stay on the LP01 branch
# X_max restricted to 2.349492 to stay on the LP01 branch
# X_max restricted to 2.349702 to stay on the LP01 branch
# X_max restricted to 2.349911 to stay on the LP01 branch
# X_max restricted to 2.350121 to stay on the LP01 branch
# X_max restricted to 2.350330 to stay on the LP01 branch
# X_max restricted to 2.350540 to stay on the LP01 branch
# X_max restricted to 2.350749 to stay on the LP01 branch
# X_max restricted to 2.350958 to stay on the LP01 branch
# X_max restricted to 2.351168 to stay on the LP01 branch
# X_max restricted to 2.351377 to stay on the LP01 branch
# X_max restricted to 2.351587 to stay on the LP01 branch
# X_max restricted to 2.351796 to stay on the LP01 branch
# X_max restricted to 2.352006 to stay on the LP01 branch
# X_max restricted to 2.352215 to stay on the LP01 branch
# X_max restricted to 2.352425 to stay on the LP01 branch
# X_max restricted to 2.352634 to stay on the LP01 branch
# X_max restricted to 2.352843 to stay on the LP01 branch
# X_max restricted to 2.353053 to stay on the LP01 branch
# X_max restricted to 2.353262 to stay on the LP01 branch
# X_max restricted to 2.353472 to stay on the LP01 branch
# X_max restricted to 2.353681 to stay on the LP01 branch
# X_max restricted to 2.353891 to stay on the LP01 branch
# X_max restricted to 2.354100 to stay on the LP01 branch
# X_max restricted to 2.354310 to stay on the LP01 branch
# X_max restricted to 2.354519 to stay on the LP01 branch
# X_max restricted to 2.354728 to stay on the LP01 branch
# X_max restricted to 2.354938 to stay on the LP01 branch
# X_max restricted to 2.355147 to stay on the LP01 branch
# X_max restricted to 2.355357 to stay on the LP01 branch
# X_max restricted to 2.355566 to stay on the LP01 branch
# X_max restricted to 2.355776 to stay on the LP01 branch
# X_max restricted to 2.355985 to stay on the LP01 branch
# X_max restricted to 2.356194 to stay on the LP01 branch
# X_max restricted to 2.356404 to stay on the LP01 branch
# X_max restricted to 2.356613 to stay on the LP01 branch
# X_max restricted to 2.356823 to stay on the LP01 branch
# X_max restricted to 2.357032 to stay on the LP01 branch
# X_max restricted to 2.357242 to stay on the LP01 branch
# X_max restricted to 2.357451 to stay on the LP01 branch
# X_max restricted to 2.357661 to stay on the LP01 branch
# X_max restricted to 2.357870 to stay on the LP01 branch
# X_max restricted to 2.358079 to stay on the LP01 branch
# X_max restricted to 2.358289 to stay on the LP01 branch
# X_max restricted to 2.358498 to stay on the LP01 branch
# X_max restricted to 2.358708 to stay on the LP01 branch
# X_max restricted to 2.358917 to stay on the LP01 branch
# X_max restricted to 2.359127 to stay on the LP01 branch
# X_max restricted to 2.359336 to stay on the LP01 branch
# X_max restricted to 2.359546 to stay on the LP01 branch
# X_max restricted to 2.359755 to stay on the LP01 branch
# X_max restricted to 2.359964 to stay on the LP01 branch
# X_max restricted to 2.360174 to stay on the LP01 branch
# X_max restricted to 2.360383 to stay on the LP01 branch
# X_max restricted to 2.360593 to stay on the LP01 branch
# X_max restricted to 2.360802 to stay on the LP01 branch
# X_max restricted to 2.361012 to stay on the LP01 branch
# X_max restricted to 2.361221 to stay on the LP01 branch
# X_max restricted to 2.361430 to stay on the LP01 branch
# X_max restricted to 2.361640 to stay on the LP01 branch
# X_max restricted to 2.361849 to stay on the LP01 branch
# X_max restricted to 2.362059 to stay on the LP01 branch
# X_max restricted to 2.362268 to stay on the LP01 branch
# X_max restricted to 2.362478 to stay on the LP01 branch
# X_max restricted to 2.362687 to stay on the LP01 branch
# X_max restricted to 2.362897 to stay on the LP01 branch
# X_max restricted to 2.363106 to stay on the LP01 branch
# X_max restricted to 2.363315 to stay on the LP01 branch
# X_max restricted to 2.363525 to stay on the LP01 branch
# X_max restricted to 2.363734 to stay on the LP01 branch
# X_max restricted to 2.363944 to stay on the LP01 branch
# X_max restricted to 2.364153 to stay on the LP01 branch
# X_max restricted to 2.364363 to stay on the LP01 branch
# X_max restricted to 2.364572 to stay on the LP01 branch
# X_max restricted to 2.364782 to stay on the LP01 branch
# X_max restricted to 2.364991 to stay on the LP01 branch
# X_max restricted to 2.365200 to stay on the LP01 branch
# X_max restricted to 2.365410 to stay on the LP01 branch
# X_max restricted to 2.365619 to stay on the LP01 branch
# X_max restricted to 2.365829 to stay on the LP01 branch
# X_max restricted to 2.366038 to stay on the LP01 branch
# X_max restricted to 2.366248 to stay on the LP01 branch
# X_max restricted to 2.366457 to stay on the LP01 branch
# X_max restricted to 2.366666 to stay on the LP01 branch
# X_max restricted to 2.366876 to stay on the LP01 branch
# X_max restricted to 2.367085 to stay on the LP01 branch
# X_max restricted to 2.367295 to stay on the LP01 branch
# X_max restricted to 2.367504 to stay on the LP01 branch
# X_max restricted to 2.367714 to stay on the LP01 branch
# X_max restricted to 2.367923 to stay on the LP01 branch
# X_max restricted to 2.368133 to stay on the LP01 branch
# X_max restricted to 2.368342 to stay on the LP01 branch
# X_max restricted to 2.368551 to stay on the LP01 branch
# X_max restricted to 2.368761 to stay on the LP01 branch
# X_max restricted to 2.368970 to stay on the LP01 branch
# X_max restricted to 2.369180 to stay on the LP01 branch
# X_max restricted to 2.369389 to stay on the LP01 branch
# X_max restricted to 2.369599 to stay on the LP01 branch
# X_max restricted to 2.369808 to stay on the LP01 branch
# X_max restricted to 2.370017 to stay on the LP01 branch
# X_max restricted to 2.370227 to stay on the LP01 branch
# X_max restricted to 2.370436 to stay on the LP01 branch
# X_max restricted to 2.370646 to stay on the LP01 branch
# X_max restricted to 2.370855 to stay on the LP01 branch
# X_max restricted to 2.371065 to stay on the LP01 branch
# X_max restricted to 2.371274 to stay on the LP01 branch
# X_max restricted to 2.371484 to stay on the LP01 branch
# X_max restricted to 2.371693 to stay on the LP01 branch
# X_max restricted to 2.371902 to stay on the LP01 branch
# X_max restricted to 2.372112 to stay on the LP01 branch
# X_max restricted to 2.372321 to stay on the LP01 branch
# X_max restricted to 2.372531 to stay on the LP01 branch
# X_max restricted to 2.372740 to stay on the LP01 branch
# X_max restricted to 2.372950 to stay on the LP01 branch
# X_max restricted to 2.373159 to stay on the LP01 branch
# X_max restricted to 2.373369 to stay on the LP01 branch
# X_max restricted to 2.373578 to stay on the LP01 branch
# X_max restricted to 2.373787 to stay on the LP01 branch
# X_max restricted to 2.373997 to stay on the LP01 branch
# X_max restricted to 2.374206 to stay on the LP01 branch
# X_max restricted to 2.374416 to stay on the LP01 branch
# X_max restricted to 2.374625 to stay on the LP01 branch
# X_max restricted to 2.374835 to stay on the LP01 branch
# X_max restricted to 2.375044 to stay on the LP01 branch
# X_max restricted to 2.375253 to stay on the LP01 branch
# X_max restricted to 2.375463 to stay on the LP01 branch
# X_max restricted to 2.375672 to stay on the LP01 branch
# X_max restricted to 2.375882 to stay on the LP01 branch
# X_max restricted to 2.376091 to stay on the LP01 branch
# X_max restricted to 2.376301 to stay on the LP01 branch
# X_max restricted to 2.376510 to stay on the LP01 branch
# X_max restricted to 2.376720 to stay on the LP01 branch
# X_max restricted to 2.376929 to stay on the LP01 branch
# X_max restricted to 2.377138 to stay on the LP01 branch
# X_max restricted to 2.377348 to stay on the LP01 branch
# X_max restricted to 2.377557 to stay on the LP01 branch
# X_max restricted to 2.377767 to stay on the LP01 branch
# X_max restricted to 2.377976 to stay on the LP01 branch
# X_max restricted to 2.378186 to stay on the LP01 branch
# X_max restricted to 2.378395 to stay on the LP01 branch
# X_max restricted to 2.378605 to stay on the LP01 branch
# X_max restricted to 2.378814 to stay on the LP01 branch
# X_max restricted to 2.379023 to stay on the LP01 branch
# X_max restricted to 2.379233 to stay on the LP01 branch
# X_max restricted to 2.379442 to stay on the LP01 branch
# X_max restricted to 2.379652 to stay on the LP01 branch
# X_max restricted to 2.379861 to stay on the LP01 branch
# X_max restricted to 2.380071 to stay on the LP01 branch
# X_max restricted to 2.380280 to stay on the LP01 branch
# X_max restricted to 2.380489 to stay on the LP01 branch
# X_max restricted to 2.380699 to stay on the LP01 branch
# X_max restricted to 2.380908 to stay on the LP01 branch
# X_max restricted to 2.381118 to stay on the LP01 branch
# X_max restricted to 2.381327 to stay on the LP01 branch
# X_max restricted to 2.381537 to stay on the LP01 branch
# X_max restricted to 2.381746 to stay on the LP01 branch
# X_max restricted to 2.381956 to stay on the LP01 branch
# X_max restricted to 2.382165 to stay on the LP01 branch
# X_max restricted to 2.382374 to stay on the LP01 branch
# X_max restricted to 2.382584 to stay on the LP01 branch
# X_max restricted to 2.382793 to stay on the LP01 branch
# X_max restricted to 2.383003 to stay on the LP01 branch
# X_max restricted to 2.383212 to stay on the LP01 branch
# X_max restricted to 2.383422 to stay on the LP01 branch
# X_max restricted to 2.383631 to stay on the LP01 branch
# X_max restricted to 2.383840 to stay on the LP01 branch
# X_max restricted to 2.384050 to stay on the LP01 branch
# X_max restricted to 2.384259 to stay on the LP01 branch
# X_max restricted to 2.384469 to stay on the LP01 branch
# X_max restricted to 2.384678 to stay on the LP01 branch
# X_max restricted to 2.384888 to stay on the LP01 branch
# X_max restricted to 2.385097 to stay on the LP01 branch
# X_max restricted to 2.385307 to stay on the LP01 branch
# X_max restricted to 2.385516 to stay on the LP01 branch
# X_max restricted to 2.385725 to stay on the LP01 branch
# X_max restricted to 2.385935 to stay on the LP01 branch
# X_max restricted to 2.386144 to stay on the LP01 branch
# X_max restricted to 2.386354 to stay on the LP01 branch
# X_max restricted to 2.386563 to stay on the LP01 branch
# X_max restricted to 2.386773 to stay on the LP01 branch
# X_max restricted to 2.386982 to stay on the LP01 branch
# X_max restricted to 2.387192 to stay on the LP01 branch
# X_max restricted to 2.387401 to stay on the LP01 branch
# X_max restricted to 2.387610 to stay on the LP01 branch
# X_max restricted to 2.387820 to stay on the LP01 branch
# X_max restricted to 2.388029 to stay on the LP01 branch
# X_max restricted to 2.388239 to stay on the LP01 branch
# X_max restricted to 2.388448 to stay on the LP01 branch
# X_max restricted to 2.388658 to stay on the LP01 branch
# X_max restricted to 2.388867 to stay on the LP01 branch
# X_max restricted to 2.389076 to stay on the LP01 branch
# X_max restricted to 2.389286 to stay on the LP01 branch
# X_max restricted to 2.389495 to stay on the LP01 branch
# X_max restricted to 2.389705 to stay on the LP01 branch
# X_max restricted to 2.389914 to stay on the LP01 branch
# X_max restricted to 2.390124 to stay on the LP01 branch
# X_max restricted to 2.390333 to stay on the LP01 branch
# X_max restricted to 2.390543 to stay on the LP01 branch
# X_max restricted to 2.390752 to stay on the LP01 branch
# X_max restricted to 2.390961 to stay on the LP01 branch
# X_max restricted to 2.391171 to stay on the LP01 branch
# X_max restricted to 2.391380 to stay on the LP01 branch
# X_max restricted to 2.391590 to stay on the LP01 branch
# X_max restricted to 2.391799 to stay on the LP01 branch
# X_max restricted to 2.392009 to stay on the LP01 branch
# X_max restricted to 2.392218 to stay on the LP01 branch
# X_max restricted to 2.392428 to stay on the LP01 branch
# X_max restricted to 2.392637 to stay on the LP01 branch
# X_max restricted to 2.392846 to stay on the LP01 branch
# X_max restricted to 2.393056 to stay on the LP01 branch
# X_max restricted to 2.393265 to stay on the LP01 branch
# X_max restricted to 2.393475 to stay on the LP01 branch
# X_max restricted to 2.393684 to stay on the LP01 branch
# X_max restricted to 2.393894 to stay on the LP01 branch
# X_max restricted to 2.394103 to stay on the LP01 branch
# X_max restricted to 2.394312 to stay on the LP01 branch
# X_max restricted to 2.394522 to stay on the LP01 branch
# X_max restricted to 2.394731 to stay on the LP01 branch
# X_max restricted to 2.394941 to stay on the LP01 branch
# X_max restricted to 2.395150 to stay on the LP01 branch
# X_max restricted to 2.395360 to stay on the LP01 branch
# X_max restricted to 2.395569 to stay on the LP01 branch
# X_max restricted to 2.395779 to stay on the LP01 branch
# X_max restricted to 2.395988 to stay on the LP01 branch
# X_max restricted to 2.396197 to stay on the LP01 branch
# X_max restricted to 2.396407 to stay on the LP01 branch
# X_max restricted to 2.396616 to stay on the LP01 branch
# X_max restricted to 2.396826 to stay on the LP01 branch
# X_max restricted to 2.397035 to stay on the LP01 branch
# X_max restricted to 2.397245 to stay on the LP01 branch
# X_max restricted to 2.397454 to stay on the LP01 branch
# X_max restricted to 2.397664 to stay on the LP01 branch
# X_max restricted to 2.397873 to stay on the LP01 branch
# X_max restricted to 2.398082 to stay on the LP01 branch
# X_max restricted to 2.398292 to stay on the LP01 branch
# X_max restricted to 2.398501 to stay on the LP01 branch
# X_max restricted to 2.398711 to stay on the LP01 branch
# X_max restricted to 2.398920 to stay on the LP01 branch
# X_max restricted to 2.399130 to stay on the LP01 branch
# X_max restricted to 2.399339 to stay on the LP01 branch
# X_max restricted to 2.399548 to stay on the LP01 branch
# X_max restricted to 2.399758 to stay on the LP01 branch
# X_max restricted to 2.399967 to stay on the LP01 branch
# X_max restricted to 2.400177 to stay on the LP01 branch
# X_max restricted to 2.400386 to stay on the LP01 branch
# X_max restricted to 2.400596 to stay on the LP01 branch
# X_max restricted to 2.400805 to stay on the LP01 branch
# X_max restricted to 2.401015 to stay on the LP01 branch
# X_max restricted to 2.401224 to stay on the LP01 branch
# X_max restricted to 2.401433 to stay on the LP01 branch
# X_max restricted to 2.401643 to stay on the LP01 branch
# X_max restricted to 2.401852 to stay on the LP01 branch
# X_max restricted to 2.402062 to stay on the LP01 branch
# X_max restricted to 2.402271 to stay on the LP01 branch
# X_max restricted to 2.402481 to stay on the LP01 branch
# X_max restricted to 2.402690 to stay on the LP01 branch
# X_max restricted to 2.402899 to stay on the LP01 branch
# X_max restricted to 2.403109 to stay on the LP01 branch
# X_max restricted to 2.403318 to stay on the LP01 branch
# X_max restricted to 2.403528 to stay on the LP01 branch
# X_max restricted to 2.403737 to stay on the LP01 branch
# X_max restricted to 2.403947 to stay on the LP01 branch
# X_max restricted to 2.404156 to stay on the LP01 branch
# X_max restricted to 2.404366 to stay on the LP01 branch
# X_max restricted to 2.404575 to stay on the LP01 branch
# X_max restricted to 2.404784 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch

# %%
plt.figure(figsize=(8,4))
plt.scatter(core_radius_range, efficiency_array_noise, s=1, marker='o')
# plt.scatter(core_radius_range[index], efficiency_array[index], color='red', marker = 'x',
            # label=f'Max Efficiency: {efficiency_array[index]:.4f} at a={core_radius_range[index]*1e6:.2f} µm')
plt.xlabel('Core radius (m)')
plt.ylabel('Coupling Efficiency (η)')
plt.title('Noise Coupling Efficiency vs Core Radius')
plt.legend()
# Out:
# /var/folders/pk/ftg5vwzs3r1dhbzyhbqk09580000gp/T/ipykernel_78924/3678072642.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## Signal to Noise Ratio

# %% [markdown]
# - **Signal**: light from the source that is coupled into the fibre
# - **Background**: sky emission entering the fibre
# - **Noise**: assumed to be dominated by Poisson fluctuations of the **background ONLY **.
#
# ### Signal (Point Source)
#
# The signal is computed by integrating the image intensity over the fibre input plane / image (focal) plane by integrating the intensity over the fibre cross-section.
#
# For a circularly symmetric point spread function (PSF):
#
# $$
# S = 2\pi \int I_{\text{image}}(r)\, r\, dr
# $$
#
# where \(r\) is the physical radius at the fibre input (in meters). This gives the total power (or counts) entering the fibre from the source.
#
# In practice, for a **single-mode fibre (SMF)**, the detected signal is determined by the **overlap between the image field and the fibre mode**.
#
# The coupled signal is then:
#
# $
# S_{\text{coupled}} \propto \eta
# $
#
# This formulation accounts for the fact that the fibre acts as a **mode filter**, not a simple geometric aperture.
#
# Note that the Signal of a point source is integrated over the image intensity, which gives S(r) in units of:
# $[\mathrm{counts} \; \mathrm{s}^{-1} \, \mathrm{m}^{-2}]$
#
# ### Background (Sky Noise)
#
# The sky background is assumed to be spatially uniform, with **surface** brightness:
#
# $$
# I_{\text{flat}} \;\; [\mathrm{counts} \; \mathrm{s}^{-1} \, \mathrm{m}^{-2} \, \mathrm{arcsec}^{-2}]
# $$
#
# Since the background is uniform, the total background is simply:
#
# $$
# B = I_{\text{flat}} \times \Omega_{\text{aperture}}
# $$
#
# The fibre core radius $$a$$ is defined in physical units (m), so it must be converted to an angular field of view using the plate scale:
#
# $$
# \text{} = 2a \times (\text{plate scale})
# $$
#
# The corresponding angular area is:
#
# $$
# \Omega_{\text{aperture}} = \pi \left(\frac{\text{FOV}}{2}\right)^2
# $$
#
# ---
#
# ### Final Expression
#
# $$
# \boxed{
# B = \pi \, I_{\text{flat}} \left(\frac{\text{FOV}}{2}\right)^2
# }
# $$
#
# ---
#
# ### Key Point
#
# The signal is integrated over physical area, while the background is defined per angular area. Therefore, $$a^2$$ must be converted to $$\text{FOV}^2$$ to ensure consistent units.

# %%
I_flat = 1 **2 # flat intensity of the background noise across the fibre input plane, in normalised units

rad_to_arcsec = (180 / np.pi) * 3600 # conversion factor from radians to arcseconds

plate_scale_coude = rad_to_arcsec / (F_focus * D_M1) # in arcseconds per meter at the focal plane
plate_scale_demag = plate_scale_coude / Magnification # in arcseconds per meter at the fibre input plane

FOV_array = np.zeros_like(core_radius_range)
snr_array = np.zeros_like(core_radius_range)
signal_array = np.zeros_like(core_radius_range)
background_array = np.zeros_like(core_radius_range)

for i, a in enumerate(core_radius_range): 

    V = 2 * np.pi * (a / lam0) * NA # Calculate the V-number for the given radius
    X_min = 0 + 1e-8
    X_max = V - 1e-8
    # Find the X and Y roots for the given core radius a
    X_root, Y_root = find_root_LP01(V, X_min, X_max)
    # define a normalised radius r / a, with maximum at cladding size 125/2 micron
    fibre_rho = np.linspace(0, cladding_radius_max / a, 10000) 
    fibre_r = fibre_rho * a

    # core_mask = fibre_r <= a # Create a mask for the core region where the fibre can couple light

    # Fibre field
    E_smf, I_smf = calculate_electric_field(fibre_rho, X_root, Y_root)
    # Image field
    E_image, I_image = demagnified_diffraction_limited_E_field(fibre_r, lam0, F_focus, alpha, E_S, Magnification)

    # Calculate Field of View for the fibre
    # plate scale = FOV / fibre radius, so FOV = plate scale * fibre radius (in arcseconds)
    FOV = plate_scale_demag * 2*a # in arcseconds 

    r_FOV = np.linspace(0, FOV, 10000) * plate_scale_demag # Convert FOV from arcseconds to meters at the fibre input plane for the core region
    
    Signal = 2*np.pi * integrate.simpson(I_image * fibre_r, x=fibre_r) # Total signal coupled into the fibre, integrating over the fibre cross-section
    Background = np.pi * I_flat * (FOV / 2) **2  # Total noise coupled into the fibre, integrating over the fibre cross-section

    snr = Signal / np.sqrt(Background) # Signal-to-noise ratio, assuming noise is dominated by the background and follows Poisson statistics

    FOV_array[i] = FOV
    snr_array[i] = snr
    signal_array[i] = Signal
    background_array[i] = Background
# Out:
# X_max restricted to 2.094395 to stay on the LP01 branch
# X_max restricted to 2.094605 to stay on the LP01 branch
# X_max restricted to 2.094814 to stay on the LP01 branch
# X_max restricted to 2.095023 to stay on the LP01 branch
# X_max restricted to 2.095233 to stay on the LP01 branch
# X_max restricted to 2.095442 to stay on the LP01 branch
# X_max restricted to 2.095652 to stay on the LP01 branch
# X_max restricted to 2.095861 to stay on the LP01 branch
# X_max restricted to 2.096071 to stay on the LP01 branch
# X_max restricted to 2.096280 to stay on the LP01 branch
# X_max restricted to 2.096489 to stay on the LP01 branch
# X_max restricted to 2.096699 to stay on the LP01 branch
# X_max restricted to 2.096908 to stay on the LP01 branch
# X_max restricted to 2.097118 to stay on the LP01 branch
# X_max restricted to 2.097327 to stay on the LP01 branch
# X_max restricted to 2.097537 to stay on the LP01 branch
# X_max restricted to 2.097746 to stay on the LP01 branch
# X_max restricted to 2.097956 to stay on the LP01 branch
# X_max restricted to 2.098165 to stay on the LP01 branch
# X_max restricted to 2.098374 to stay on the LP01 branch
# X_max restricted to 2.098584 to stay on the LP01 branch
# X_max restricted to 2.098793 to stay on the LP01 branch
# X_max restricted to 2.099003 to stay on the LP01 branch
# X_max restricted to 2.099212 to stay on the LP01 branch
# X_max restricted to 2.099422 to stay on the LP01 branch
# X_max restricted to 2.099631 to stay on the LP01 branch
# X_max restricted to 2.099841 to stay on the LP01 branch
# X_max restricted to 2.100050 to stay on the LP01 branch
# X_max restricted to 2.100259 to stay on the LP01 branch
# X_max restricted to 2.100469 to stay on the LP01 branch
# X_max restricted to 2.100678 to stay on the LP01 branch
# X_max restricted to 2.100888 to stay on the LP01 branch
# X_max restricted to 2.101097 to stay on the LP01 branch
# X_max restricted to 2.101307 to stay on the LP01 branch
# X_max restricted to 2.101516 to stay on the LP01 branch
# X_max restricted to 2.101725 to stay on the LP01 branch
# X_max restricted to 2.101935 to stay on the LP01 branch
# X_max restricted to 2.102144 to stay on the LP01 branch
# X_max restricted to 2.102354 to stay on the LP01 branch
# X_max restricted to 2.102563 to stay on the LP01 branch
# X_max restricted to 2.102773 to stay on the LP01 branch
# X_max restricted to 2.102982 to stay on the LP01 branch
# X_max restricted to 2.103192 to stay on the LP01 branch
# X_max restricted to 2.103401 to stay on the LP01 branch
# X_max restricted to 2.103610 to stay on the LP01 branch
# X_max restricted to 2.103820 to stay on the LP01 branch
# X_max restricted to 2.104029 to stay on the LP01 branch
# X_max restricted to 2.104239 to stay on the LP01 branch
# X_max restricted to 2.104448 to stay on the LP01 branch
# X_max restricted to 2.104658 to stay on the LP01 branch
# X_max restricted to 2.104867 to stay on the LP01 branch
# X_max restricted to 2.105077 to stay on the LP01 branch
# X_max restricted to 2.105286 to stay on the LP01 branch
# X_max restricted to 2.105495 to stay on the LP01 branch
# X_max restricted to 2.105705 to stay on the LP01 branch
# X_max restricted to 2.105914 to stay on the LP01 branch
# X_max restricted to 2.106124 to stay on the LP01 branch
# X_max restricted to 2.106333 to stay on the LP01 branch
# X_max restricted to 2.106543 to stay on the LP01 branch
# X_max restricted to 2.106752 to stay on the LP01 branch
# X_max restricted to 2.106961 to stay on the LP01 branch
# X_max restricted to 2.107171 to stay on the LP01 branch
# X_max restricted to 2.107380 to stay on the LP01 branch
# X_max restricted to 2.107590 to stay on the LP01 branch
# X_max restricted to 2.107799 to stay on the LP01 branch
# X_max restricted to 2.108009 to stay on the LP01 branch
# X_max restricted to 2.108218 to stay on the LP01 branch
# X_max restricted to 2.108428 to stay on the LP01 branch
# X_max restricted to 2.108637 to stay on the LP01 branch
# X_max restricted to 2.108846 to stay on the LP01 branch
# X_max restricted to 2.109056 to stay on the LP01 branch
# X_max restricted to 2.109265 to stay on the LP01 branch
# X_max restricted to 2.109475 to stay on the LP01 branch
# X_max restricted to 2.109684 to stay on the LP01 branch
# X_max restricted to 2.109894 to stay on the LP01 branch
# X_max restricted to 2.110103 to stay on the LP01 branch
# X_max restricted to 2.110312 to stay on the LP01 branch
# X_max restricted to 2.110522 to stay on the LP01 branch
# X_max restricted to 2.110731 to stay on the LP01 branch
# X_max restricted to 2.110941 to stay on the LP01 branch
# X_max restricted to 2.111150 to stay on the LP01 branch
# X_max restricted to 2.111360 to stay on the LP01 branch
# X_max restricted to 2.111569 to stay on the LP01 branch
# X_max restricted to 2.111779 to stay on the LP01 branch
# X_max restricted to 2.111988 to stay on the LP01 branch
# X_max restricted to 2.112197 to stay on the LP01 branch
# X_max restricted to 2.112407 to stay on the LP01 branch
# X_max restricted to 2.112616 to stay on the LP01 branch
# X_max restricted to 2.112826 to stay on the LP01 branch
# X_max restricted to 2.113035 to stay on the LP01 branch
# X_max restricted to 2.113245 to stay on the LP01 branch
# X_max restricted to 2.113454 to stay on the LP01 branch
# X_max restricted to 2.113664 to stay on the LP01 branch
# X_max restricted to 2.113873 to stay on the LP01 branch
# X_max restricted to 2.114082 to stay on the LP01 branch
# X_max restricted to 2.114292 to stay on the LP01 branch
# X_max restricted to 2.114501 to stay on the LP01 branch
# X_max restricted to 2.114711 to stay on the LP01 branch
# X_max restricted to 2.114920 to stay on the LP01 branch
# X_max restricted to 2.115130 to stay on the LP01 branch
# X_max restricted to 2.115339 to stay on the LP01 branch
# X_max restricted to 2.115548 to stay on the LP01 branch
# X_max restricted to 2.115758 to stay on the LP01 branch
# X_max restricted to 2.115967 to stay on the LP01 branch
# X_max restricted to 2.116177 to stay on the LP01 branch
# X_max restricted to 2.116386 to stay on the LP01 branch
# X_max restricted to 2.116596 to stay on the LP01 branch
# X_max restricted to 2.116805 to stay on the LP01 branch
# X_max restricted to 2.117015 to stay on the LP01 branch
# X_max restricted to 2.117224 to stay on the LP01 branch
# X_max restricted to 2.117433 to stay on the LP01 branch
# X_max restricted to 2.117643 to stay on the LP01 branch
# X_max restricted to 2.117852 to stay on the LP01 branch
# X_max restricted to 2.118062 to stay on the LP01 branch
# X_max restricted to 2.118271 to stay on the LP01 branch
# X_max restricted to 2.118481 to stay on the LP01 branch
# X_max restricted to 2.118690 to stay on the LP01 branch
# X_max restricted to 2.118900 to stay on the LP01 branch
# X_max restricted to 2.119109 to stay on the LP01 branch
# X_max restricted to 2.119318 to stay on the LP01 branch
# X_max restricted to 2.119528 to stay on the LP01 branch
# X_max restricted to 2.119737 to stay on the LP01 branch
# X_max restricted to 2.119947 to stay on the LP01 branch
# X_max restricted to 2.120156 to stay on the LP01 branch
# X_max restricted to 2.120366 to stay on the LP01 branch
# X_max restricted to 2.120575 to stay on the LP01 branch
# X_max restricted to 2.120784 to stay on the LP01 branch
# X_max restricted to 2.120994 to stay on the LP01 branch
# X_max restricted to 2.121203 to stay on the LP01 branch
# X_max restricted to 2.121413 to stay on the LP01 branch
# X_max restricted to 2.121622 to stay on the LP01 branch
# X_max restricted to 2.121832 to stay on the LP01 branch
# X_max restricted to 2.122041 to stay on the LP01 branch
# X_max restricted to 2.122251 to stay on the LP01 branch
# X_max restricted to 2.122460 to stay on the LP01 branch
# X_max restricted to 2.122669 to stay on the LP01 branch
# X_max restricted to 2.122879 to stay on the LP01 branch
# X_max restricted to 2.123088 to stay on the LP01 branch
# X_max restricted to 2.123298 to stay on the LP01 branch
# X_max restricted to 2.123507 to stay on the LP01 branch
# X_max restricted to 2.123717 to stay on the LP01 branch
# X_max restricted to 2.123926 to stay on the LP01 branch
# X_max restricted to 2.124136 to stay on the LP01 branch
# X_max restricted to 2.124345 to stay on the LP01 branch
# X_max restricted to 2.124554 to stay on the LP01 branch
# X_max restricted to 2.124764 to stay on the LP01 branch
# X_max restricted to 2.124973 to stay on the LP01 branch
# X_max restricted to 2.125183 to stay on the LP01 branch
# X_max restricted to 2.125392 to stay on the LP01 branch
# X_max restricted to 2.125602 to stay on the LP01 branch
# X_max restricted to 2.125811 to stay on the LP01 branch
# X_max restricted to 2.126020 to stay on the LP01 branch
# X_max restricted to 2.126230 to stay on the LP01 branch
# X_max restricted to 2.126439 to stay on the LP01 branch
# X_max restricted to 2.126649 to stay on the LP01 branch
# X_max restricted to 2.126858 to stay on the LP01 branch
# X_max restricted to 2.127068 to stay on the LP01 branch
# X_max restricted to 2.127277 to stay on the LP01 branch
# X_max restricted to 2.127487 to stay on the LP01 branch
# X_max restricted to 2.127696 to stay on the LP01 branch
# X_max restricted to 2.127905 to stay on the LP01 branch
# X_max restricted to 2.128115 to stay on the LP01 branch
# X_max restricted to 2.128324 to stay on the LP01 branch
# X_max restricted to 2.128534 to stay on the LP01 branch
# X_max restricted to 2.128743 to stay on the LP01 branch
# X_max restricted to 2.128953 to stay on the LP01 branch
# X_max restricted to 2.129162 to stay on the LP01 branch
# X_max restricted to 2.129371 to stay on the LP01 branch
# X_max restricted to 2.129581 to stay on the LP01 branch
# X_max restricted to 2.129790 to stay on the LP01 branch
# X_max restricted to 2.130000 to stay on the LP01 branch
# X_max restricted to 2.130209 to stay on the LP01 branch
# X_max restricted to 2.130419 to stay on the LP01 branch
# X_max restricted to 2.130628 to stay on the LP01 branch
# X_max restricted to 2.130838 to stay on the LP01 branch
# X_max restricted to 2.131047 to stay on the LP01 branch
# X_max restricted to 2.131256 to stay on the LP01 branch
# X_max restricted to 2.131466 to stay on the LP01 branch
# X_max restricted to 2.131675 to stay on the LP01 branch
# X_max restricted to 2.131885 to stay on the LP01 branch
# X_max restricted to 2.132094 to stay on the LP01 branch
# X_max restricted to 2.132304 to stay on the LP01 branch
# X_max restricted to 2.132513 to stay on the LP01 branch
# X_max restricted to 2.132723 to stay on the LP01 branch
# X_max restricted to 2.132932 to stay on the LP01 branch
# X_max restricted to 2.133141 to stay on the LP01 branch
# X_max restricted to 2.133351 to stay on the LP01 branch
# X_max restricted to 2.133560 to stay on the LP01 branch
# X_max restricted to 2.133770 to stay on the LP01 branch
# X_max restricted to 2.133979 to stay on the LP01 branch
# X_max restricted to 2.134189 to stay on the LP01 branch
# X_max restricted to 2.134398 to stay on the LP01 branch
# X_max restricted to 2.134607 to stay on the LP01 branch
# X_max restricted to 2.134817 to stay on the LP01 branch
# X_max restricted to 2.135026 to stay on the LP01 branch
# X_max restricted to 2.135236 to stay on the LP01 branch
# X_max restricted to 2.135445 to stay on the LP01 branch
# X_max restricted to 2.135655 to stay on the LP01 branch
# X_max restricted to 2.135864 to stay on the LP01 branch
# X_max restricted to 2.136074 to stay on the LP01 branch
# X_max restricted to 2.136283 to stay on the LP01 branch
# X_max restricted to 2.136492 to stay on the LP01 branch
# X_max restricted to 2.136702 to stay on the LP01 branch
# X_max restricted to 2.136911 to stay on the LP01 branch
# X_max restricted to 2.137121 to stay on the LP01 branch
# X_max restricted to 2.137330 to stay on the LP01 branch
# X_max restricted to 2.137540 to stay on the LP01 branch
# X_max restricted to 2.137749 to stay on the LP01 branch
# X_max restricted to 2.137959 to stay on the LP01 branch
# X_max restricted to 2.138168 to stay on the LP01 branch
# X_max restricted to 2.138377 to stay on the LP01 branch
# X_max restricted to 2.138587 to stay on the LP01 branch
# X_max restricted to 2.138796 to stay on the LP01 branch
# X_max restricted to 2.139006 to stay on the LP01 branch
# X_max restricted to 2.139215 to stay on the LP01 branch
# X_max restricted to 2.139425 to stay on the LP01 branch
# X_max restricted to 2.139634 to stay on the LP01 branch
# X_max restricted to 2.139843 to stay on the LP01 branch
# X_max restricted to 2.140053 to stay on the LP01 branch
# X_max restricted to 2.140262 to stay on the LP01 branch
# X_max restricted to 2.140472 to stay on the LP01 branch
# X_max restricted to 2.140681 to stay on the LP01 branch
# X_max restricted to 2.140891 to stay on the LP01 branch
# X_max restricted to 2.141100 to stay on the LP01 branch
# X_max restricted to 2.141310 to stay on the LP01 branch
# X_max restricted to 2.141519 to stay on the LP01 branch
# X_max restricted to 2.141728 to stay on the LP01 branch
# X_max restricted to 2.141938 to stay on the LP01 branch
# X_max restricted to 2.142147 to stay on the LP01 branch
# X_max restricted to 2.142357 to stay on the LP01 branch
# X_max restricted to 2.142566 to stay on the LP01 branch
# X_max restricted to 2.142776 to stay on the LP01 branch
# X_max restricted to 2.142985 to stay on the LP01 branch
# X_max restricted to 2.143194 to stay on the LP01 branch
# X_max restricted to 2.143404 to stay on the LP01 branch
# X_max restricted to 2.143613 to stay on the LP01 branch
# X_max restricted to 2.143823 to stay on the LP01 branch
# X_max restricted to 2.144032 to stay on the LP01 branch
# X_max restricted to 2.144242 to stay on the LP01 branch
# X_max restricted to 2.144451 to stay on the LP01 branch
# X_max restricted to 2.144661 to stay on the LP01 branch
# X_max restricted to 2.144870 to stay on the LP01 branch
# X_max restricted to 2.145079 to stay on the LP01 branch
# X_max restricted to 2.145289 to stay on the LP01 branch
# X_max restricted to 2.145498 to stay on the LP01 branch
# X_max restricted to 2.145708 to stay on the LP01 branch
# X_max restricted to 2.145917 to stay on the LP01 branch
# X_max restricted to 2.146127 to stay on the LP01 branch
# X_max restricted to 2.146336 to stay on the LP01 branch
# X_max restricted to 2.146546 to stay on the LP01 branch
# X_max restricted to 2.146755 to stay on the LP01 branch
# X_max restricted to 2.146964 to stay on the LP01 branch
# X_max restricted to 2.147174 to stay on the LP01 branch
# X_max restricted to 2.147383 to stay on the LP01 branch
# X_max restricted to 2.147593 to stay on the LP01 branch
# X_max restricted to 2.147802 to stay on the LP01 branch
# X_max restricted to 2.148012 to stay on the LP01 branch
# X_max restricted to 2.148221 to stay on the LP01 branch
# X_max restricted to 2.148430 to stay on the LP01 branch
# X_max restricted to 2.148640 to stay on the LP01 branch
# X_max restricted to 2.148849 to stay on the LP01 branch
# X_max restricted to 2.149059 to stay on the LP01 branch
# X_max restricted to 2.149268 to stay on the LP01 branch
# X_max restricted to 2.149478 to stay on the LP01 branch
# X_max restricted to 2.149687 to stay on the LP01 branch
# X_max restricted to 2.149897 to stay on the LP01 branch
# X_max restricted to 2.150106 to stay on the LP01 branch
# X_max restricted to 2.150315 to stay on the LP01 branch
# X_max restricted to 2.150525 to stay on the LP01 branch
# X_max restricted to 2.150734 to stay on the LP01 branch
# X_max restricted to 2.150944 to stay on the LP01 branch
# X_max restricted to 2.151153 to stay on the LP01 branch
# X_max restricted to 2.151363 to stay on the LP01 branch
# X_max restricted to 2.151572 to stay on the LP01 branch
# X_max restricted to 2.151782 to stay on the LP01 branch
# X_max restricted to 2.151991 to stay on the LP01 branch
# X_max restricted to 2.152200 to stay on the LP01 branch
# X_max restricted to 2.152410 to stay on the LP01 branch
# X_max restricted to 2.152619 to stay on the LP01 branch
# X_max restricted to 2.152829 to stay on the LP01 branch
# X_max restricted to 2.153038 to stay on the LP01 branch
# X_max restricted to 2.153248 to stay on the LP01 branch
# X_max restricted to 2.153457 to stay on the LP01 branch
# X_max restricted to 2.153666 to stay on the LP01 branch
# X_max restricted to 2.153876 to stay on the LP01 branch
# X_max restricted to 2.154085 to stay on the LP01 branch
# X_max restricted to 2.154295 to stay on the LP01 branch
# X_max restricted to 2.154504 to stay on the LP01 branch
# X_max restricted to 2.154714 to stay on the LP01 branch
# X_max restricted to 2.154923 to stay on the LP01 branch
# X_max restricted to 2.155133 to stay on the LP01 branch
# X_max restricted to 2.155342 to stay on the LP01 branch
# X_max restricted to 2.155551 to stay on the LP01 branch
# X_max restricted to 2.155761 to stay on the LP01 branch
# X_max restricted to 2.155970 to stay on the LP01 branch
# X_max restricted to 2.156180 to stay on the LP01 branch
# X_max restricted to 2.156389 to stay on the LP01 branch
# X_max restricted to 2.156599 to stay on the LP01 branch
# X_max restricted to 2.156808 to stay on the LP01 branch
# X_max restricted to 2.157018 to stay on the LP01 branch
# X_max restricted to 2.157227 to stay on the LP01 branch
# X_max restricted to 2.157436 to stay on the LP01 branch
# X_max restricted to 2.157646 to stay on the LP01 branch
# X_max restricted to 2.157855 to stay on the LP01 branch
# X_max restricted to 2.158065 to stay on the LP01 branch
# X_max restricted to 2.158274 to stay on the LP01 branch
# X_max restricted to 2.158484 to stay on the LP01 branch
# X_max restricted to 2.158693 to stay on the LP01 branch
# X_max restricted to 2.158902 to stay on the LP01 branch
# X_max restricted to 2.159112 to stay on the LP01 branch
# X_max restricted to 2.159321 to stay on the LP01 branch
# X_max restricted to 2.159531 to stay on the LP01 branch
# X_max restricted to 2.159740 to stay on the LP01 branch
# X_max restricted to 2.159950 to stay on the LP01 branch
# X_max restricted to 2.160159 to stay on the LP01 branch
# X_max restricted to 2.160369 to stay on the LP01 branch
# X_max restricted to 2.160578 to stay on the LP01 branch
# X_max restricted to 2.160787 to stay on the LP01 branch
# X_max restricted to 2.160997 to stay on the LP01 branch
# X_max restricted to 2.161206 to stay on the LP01 branch
# X_max restricted to 2.161416 to stay on the LP01 branch
# X_max restricted to 2.161625 to stay on the LP01 branch
# X_max restricted to 2.161835 to stay on the LP01 branch
# X_max restricted to 2.162044 to stay on the LP01 branch
# X_max restricted to 2.162253 to stay on the LP01 branch
# X_max restricted to 2.162463 to stay on the LP01 branch
# X_max restricted to 2.162672 to stay on the LP01 branch
# X_max restricted to 2.162882 to stay on the LP01 branch
# X_max restricted to 2.163091 to stay on the LP01 branch
# X_max restricted to 2.163301 to stay on the LP01 branch
# X_max restricted to 2.163510 to stay on the LP01 branch
# X_max restricted to 2.163720 to stay on the LP01 branch
# X_max restricted to 2.163929 to stay on the LP01 branch
# X_max restricted to 2.164138 to stay on the LP01 branch
# X_max restricted to 2.164348 to stay on the LP01 branch
# X_max restricted to 2.164557 to stay on the LP01 branch
# X_max restricted to 2.164767 to stay on the LP01 branch
# X_max restricted to 2.164976 to stay on the LP01 branch
# X_max restricted to 2.165186 to stay on the LP01 branch
# X_max restricted to 2.165395 to stay on the LP01 branch
# X_max restricted to 2.165605 to stay on the LP01 branch
# X_max restricted to 2.165814 to stay on the LP01 branch
# X_max restricted to 2.166023 to stay on the LP01 branch
# X_max restricted to 2.166233 to stay on the LP01 branch
# X_max restricted to 2.166442 to stay on the LP01 branch
# X_max restricted to 2.166652 to stay on the LP01 branch
# X_max restricted to 2.166861 to stay on the LP01 branch
# X_max restricted to 2.167071 to stay on the LP01 branch
# X_max restricted to 2.167280 to stay on the LP01 branch
# X_max restricted to 2.167489 to stay on the LP01 branch
# X_max restricted to 2.167699 to stay on the LP01 branch
# X_max restricted to 2.167908 to stay on the LP01 branch
# X_max restricted to 2.168118 to stay on the LP01 branch
# X_max restricted to 2.168327 to stay on the LP01 branch
# X_max restricted to 2.168537 to stay on the LP01 branch
# X_max restricted to 2.168746 to stay on the LP01 branch
# X_max restricted to 2.168956 to stay on the LP01 branch
# X_max restricted to 2.169165 to stay on the LP01 branch
# X_max restricted to 2.169374 to stay on the LP01 branch
# X_max restricted to 2.169584 to stay on the LP01 branch
# X_max restricted to 2.169793 to stay on the LP01 branch
# X_max restricted to 2.170003 to stay on the LP01 branch
# X_max restricted to 2.170212 to stay on the LP01 branch
# X_max restricted to 2.170422 to stay on the LP01 branch
# X_max restricted to 2.170631 to stay on the LP01 branch
# X_max restricted to 2.170841 to stay on the LP01 branch
# X_max restricted to 2.171050 to stay on the LP01 branch
# X_max restricted to 2.171259 to stay on the LP01 branch
# X_max restricted to 2.171469 to stay on the LP01 branch
# X_max restricted to 2.171678 to stay on the LP01 branch
# X_max restricted to 2.171888 to stay on the LP01 branch
# X_max restricted to 2.172097 to stay on the LP01 branch
# X_max restricted to 2.172307 to stay on the LP01 branch
# X_max restricted to 2.172516 to stay on the LP01 branch
# X_max restricted to 2.172725 to stay on the LP01 branch
# X_max restricted to 2.172935 to stay on the LP01 branch
# X_max restricted to 2.173144 to stay on the LP01 branch
# X_max restricted to 2.173354 to stay on the LP01 branch
# X_max restricted to 2.173563 to stay on the LP01 branch
# X_max restricted to 2.173773 to stay on the LP01 branch
# X_max restricted to 2.173982 to stay on the LP01 branch
# X_max restricted to 2.174192 to stay on the LP01 branch
# X_max restricted to 2.174401 to stay on the LP01 branch
# X_max restricted to 2.174610 to stay on the LP01 branch
# X_max restricted to 2.174820 to stay on the LP01 branch
# X_max restricted to 2.175029 to stay on the LP01 branch
# X_max restricted to 2.175239 to stay on the LP01 branch
# X_max restricted to 2.175448 to stay on the LP01 branch
# X_max restricted to 2.175658 to stay on the LP01 branch
# X_max restricted to 2.175867 to stay on the LP01 branch
# X_max restricted to 2.176077 to stay on the LP01 branch
# X_max restricted to 2.176286 to stay on the LP01 branch
# X_max restricted to 2.176495 to stay on the LP01 branch
# X_max restricted to 2.176705 to stay on the LP01 branch
# X_max restricted to 2.176914 to stay on the LP01 branch
# X_max restricted to 2.177124 to stay on the LP01 branch
# X_max restricted to 2.177333 to stay on the LP01 branch
# X_max restricted to 2.177543 to stay on the LP01 branch
# X_max restricted to 2.177752 to stay on the LP01 branch
# X_max restricted to 2.177961 to stay on the LP01 branch
# X_max restricted to 2.178171 to stay on the LP01 branch
# X_max restricted to 2.178380 to stay on the LP01 branch
# X_max restricted to 2.178590 to stay on the LP01 branch
# X_max restricted to 2.178799 to stay on the LP01 branch
# X_max restricted to 2.179009 to stay on the LP01 branch
# X_max restricted to 2.179218 to stay on the LP01 branch
# X_max restricted to 2.179428 to stay on the LP01 branch
# X_max restricted to 2.179637 to stay on the LP01 branch
# X_max restricted to 2.179846 to stay on the LP01 branch
# X_max restricted to 2.180056 to stay on the LP01 branch
# X_max restricted to 2.180265 to stay on the LP01 branch
# X_max restricted to 2.180475 to stay on the LP01 branch
# X_max restricted to 2.180684 to stay on the LP01 branch
# X_max restricted to 2.180894 to stay on the LP01 branch
# X_max restricted to 2.181103 to stay on the LP01 branch
# X_max restricted to 2.181312 to stay on the LP01 branch
# X_max restricted to 2.181522 to stay on the LP01 branch
# X_max restricted to 2.181731 to stay on the LP01 branch
# X_max restricted to 2.181941 to stay on the LP01 branch
# X_max restricted to 2.182150 to stay on the LP01 branch
# X_max restricted to 2.182360 to stay on the LP01 branch
# X_max restricted to 2.182569 to stay on the LP01 branch
# X_max restricted to 2.182779 to stay on the LP01 branch
# X_max restricted to 2.182988 to stay on the LP01 branch
# X_max restricted to 2.183197 to stay on the LP01 branch
# X_max restricted to 2.183407 to stay on the LP01 branch
# X_max restricted to 2.183616 to stay on the LP01 branch
# X_max restricted to 2.183826 to stay on the LP01 branch
# X_max restricted to 2.184035 to stay on the LP01 branch
# X_max restricted to 2.184245 to stay on the LP01 branch
# X_max restricted to 2.184454 to stay on the LP01 branch
# X_max restricted to 2.184664 to stay on the LP01 branch
# X_max restricted to 2.184873 to stay on the LP01 branch
# X_max restricted to 2.185082 to stay on the LP01 branch
# X_max restricted to 2.185292 to stay on the LP01 branch
# X_max restricted to 2.185501 to stay on the LP01 branch
# X_max restricted to 2.185711 to stay on the LP01 branch
# X_max restricted to 2.185920 to stay on the LP01 branch
# X_max restricted to 2.186130 to stay on the LP01 branch
# X_max restricted to 2.186339 to stay on the LP01 branch
# X_max restricted to 2.186548 to stay on the LP01 branch
# X_max restricted to 2.186758 to stay on the LP01 branch
# X_max restricted to 2.186967 to stay on the LP01 branch
# X_max restricted to 2.187177 to stay on the LP01 branch
# X_max restricted to 2.187386 to stay on the LP01 branch
# X_max restricted to 2.187596 to stay on the LP01 branch
# X_max restricted to 2.187805 to stay on the LP01 branch
# X_max restricted to 2.188015 to stay on the LP01 branch
# X_max restricted to 2.188224 to stay on the LP01 branch
# X_max restricted to 2.188433 to stay on the LP01 branch
# X_max restricted to 2.188643 to stay on the LP01 branch
# X_max restricted to 2.188852 to stay on the LP01 branch
# X_max restricted to 2.189062 to stay on the LP01 branch
# X_max restricted to 2.189271 to stay on the LP01 branch
# X_max restricted to 2.189481 to stay on the LP01 branch
# X_max restricted to 2.189690 to stay on the LP01 branch
# X_max restricted to 2.189900 to stay on the LP01 branch
# X_max restricted to 2.190109 to stay on the LP01 branch
# X_max restricted to 2.190318 to stay on the LP01 branch
# X_max restricted to 2.190528 to stay on the LP01 branch
# X_max restricted to 2.190737 to stay on the LP01 branch
# X_max restricted to 2.190947 to stay on the LP01 branch
# X_max restricted to 2.191156 to stay on the LP01 branch
# X_max restricted to 2.191366 to stay on the LP01 branch
# X_max restricted to 2.191575 to stay on the LP01 branch
# X_max restricted to 2.191784 to stay on the LP01 branch
# X_max restricted to 2.191994 to stay on the LP01 branch
# X_max restricted to 2.192203 to stay on the LP01 branch
# X_max restricted to 2.192413 to stay on the LP01 branch
# X_max restricted to 2.192622 to stay on the LP01 branch
# X_max restricted to 2.192832 to stay on the LP01 branch
# X_max restricted to 2.193041 to stay on the LP01 branch
# X_max restricted to 2.193251 to stay on the LP01 branch
# X_max restricted to 2.193460 to stay on the LP01 branch
# X_max restricted to 2.193669 to stay on the LP01 branch
# X_max restricted to 2.193879 to stay on the LP01 branch
# X_max restricted to 2.194088 to stay on the LP01 branch
# X_max restricted to 2.194298 to stay on the LP01 branch
# X_max restricted to 2.194507 to stay on the LP01 branch
# X_max restricted to 2.194717 to stay on the LP01 branch
# X_max restricted to 2.194926 to stay on the LP01 branch
# X_max restricted to 2.195135 to stay on the LP01 branch
# X_max restricted to 2.195345 to stay on the LP01 branch
# X_max restricted to 2.195554 to stay on the LP01 branch
# X_max restricted to 2.195764 to stay on the LP01 branch
# X_max restricted to 2.195973 to stay on the LP01 branch
# X_max restricted to 2.196183 to stay on the LP01 branch
# X_max restricted to 2.196392 to stay on the LP01 branch
# X_max restricted to 2.196602 to stay on the LP01 branch
# X_max restricted to 2.196811 to stay on the LP01 branch
# X_max restricted to 2.197020 to stay on the LP01 branch
# X_max restricted to 2.197230 to stay on the LP01 branch
# X_max restricted to 2.197439 to stay on the LP01 branch
# X_max restricted to 2.197649 to stay on the LP01 branch
# X_max restricted to 2.197858 to stay on the LP01 branch
# X_max restricted to 2.198068 to stay on the LP01 branch
# X_max restricted to 2.198277 to stay on the LP01 branch
# X_max restricted to 2.198487 to stay on the LP01 branch
# X_max restricted to 2.198696 to stay on the LP01 branch
# X_max restricted to 2.198905 to stay on the LP01 branch
# X_max restricted to 2.199115 to stay on the LP01 branch
# X_max restricted to 2.199324 to stay on the LP01 branch
# X_max restricted to 2.199534 to stay on the LP01 branch
# X_max restricted to 2.199743 to stay on the LP01 branch
# X_max restricted to 2.199953 to stay on the LP01 branch
# X_max restricted to 2.200162 to stay on the LP01 branch
# X_max restricted to 2.200371 to stay on the LP01 branch
# X_max restricted to 2.200581 to stay on the LP01 branch
# X_max restricted to 2.200790 to stay on the LP01 branch
# X_max restricted to 2.201000 to stay on the LP01 branch
# X_max restricted to 2.201209 to stay on the LP01 branch
# X_max restricted to 2.201419 to stay on the LP01 branch
# X_max restricted to 2.201628 to stay on the LP01 branch
# X_max restricted to 2.201838 to stay on the LP01 branch
# X_max restricted to 2.202047 to stay on the LP01 branch
# X_max restricted to 2.202256 to stay on the LP01 branch
# X_max restricted to 2.202466 to stay on the LP01 branch
# X_max restricted to 2.202675 to stay on the LP01 branch
# X_max restricted to 2.202885 to stay on the LP01 branch
# X_max restricted to 2.203094 to stay on the LP01 branch
# X_max restricted to 2.203304 to stay on the LP01 branch
# X_max restricted to 2.203513 to stay on the LP01 branch
# X_max restricted to 2.203723 to stay on the LP01 branch
# X_max restricted to 2.203932 to stay on the LP01 branch
# X_max restricted to 2.204141 to stay on the LP01 branch
# X_max restricted to 2.204351 to stay on the LP01 branch
# X_max restricted to 2.204560 to stay on the LP01 branch
# X_max restricted to 2.204770 to stay on the LP01 branch
# X_max restricted to 2.204979 to stay on the LP01 branch
# X_max restricted to 2.205189 to stay on the LP01 branch
# X_max restricted to 2.205398 to stay on the LP01 branch
# X_max restricted to 2.205607 to stay on the LP01 branch
# X_max restricted to 2.205817 to stay on the LP01 branch
# X_max restricted to 2.206026 to stay on the LP01 branch
# X_max restricted to 2.206236 to stay on the LP01 branch
# X_max restricted to 2.206445 to stay on the LP01 branch
# X_max restricted to 2.206655 to stay on the LP01 branch
# X_max restricted to 2.206864 to stay on the LP01 branch
# X_max restricted to 2.207074 to stay on the LP01 branch
# X_max restricted to 2.207283 to stay on the LP01 branch
# X_max restricted to 2.207492 to stay on the LP01 branch
# X_max restricted to 2.207702 to stay on the LP01 branch
# X_max restricted to 2.207911 to stay on the LP01 branch
# X_max restricted to 2.208121 to stay on the LP01 branch
# X_max restricted to 2.208330 to stay on the LP01 branch
# X_max restricted to 2.208540 to stay on the LP01 branch
# X_max restricted to 2.208749 to stay on the LP01 branch
# X_max restricted to 2.208959 to stay on the LP01 branch
# X_max restricted to 2.209168 to stay on the LP01 branch
# X_max restricted to 2.209377 to stay on the LP01 branch
# X_max restricted to 2.209587 to stay on the LP01 branch
# X_max restricted to 2.209796 to stay on the LP01 branch
# X_max restricted to 2.210006 to stay on the LP01 branch
# X_max restricted to 2.210215 to stay on the LP01 branch
# X_max restricted to 2.210425 to stay on the LP01 branch
# X_max restricted to 2.210634 to stay on the LP01 branch
# X_max restricted to 2.210843 to stay on the LP01 branch
# X_max restricted to 2.211053 to stay on the LP01 branch
# X_max restricted to 2.211262 to stay on the LP01 branch
# X_max restricted to 2.211472 to stay on the LP01 branch
# X_max restricted to 2.211681 to stay on the LP01 branch
# X_max restricted to 2.211891 to stay on the LP01 branch
# X_max restricted to 2.212100 to stay on the LP01 branch
# X_max restricted to 2.212310 to stay on the LP01 branch
# X_max restricted to 2.212519 to stay on the LP01 branch
# X_max restricted to 2.212728 to stay on the LP01 branch
# X_max restricted to 2.212938 to stay on the LP01 branch
# X_max restricted to 2.213147 to stay on the LP01 branch
# X_max restricted to 2.213357 to stay on the LP01 branch
# X_max restricted to 2.213566 to stay on the LP01 branch
# X_max restricted to 2.213776 to stay on the LP01 branch
# X_max restricted to 2.213985 to stay on the LP01 branch
# X_max restricted to 2.214194 to stay on the LP01 branch
# X_max restricted to 2.214404 to stay on the LP01 branch
# X_max restricted to 2.214613 to stay on the LP01 branch
# X_max restricted to 2.214823 to stay on the LP01 branch
# X_max restricted to 2.215032 to stay on the LP01 branch
# X_max restricted to 2.215242 to stay on the LP01 branch
# X_max restricted to 2.215451 to stay on the LP01 branch
# X_max restricted to 2.215661 to stay on the LP01 branch
# X_max restricted to 2.215870 to stay on the LP01 branch
# X_max restricted to 2.216079 to stay on the LP01 branch
# X_max restricted to 2.216289 to stay on the LP01 branch
# X_max restricted to 2.216498 to stay on the LP01 branch
# X_max restricted to 2.216708 to stay on the LP01 branch
# X_max restricted to 2.216917 to stay on the LP01 branch
# X_max restricted to 2.217127 to stay on the LP01 branch
# X_max restricted to 2.217336 to stay on the LP01 branch
# X_max restricted to 2.217546 to stay on the LP01 branch
# X_max restricted to 2.217755 to stay on the LP01 branch
# X_max restricted to 2.217964 to stay on the LP01 branch
# X_max restricted to 2.218174 to stay on the LP01 branch
# X_max restricted to 2.218383 to stay on the LP01 branch
# X_max restricted to 2.218593 to stay on the LP01 branch
# X_max restricted to 2.218802 to stay on the LP01 branch
# X_max restricted to 2.219012 to stay on the LP01 branch
# X_max restricted to 2.219221 to stay on the LP01 branch
# X_max restricted to 2.219430 to stay on the LP01 branch
# X_max restricted to 2.219640 to stay on the LP01 branch
# X_max restricted to 2.219849 to stay on the LP01 branch
# X_max restricted to 2.220059 to stay on the LP01 branch
# X_max restricted to 2.220268 to stay on the LP01 branch
# X_max restricted to 2.220478 to stay on the LP01 branch
# X_max restricted to 2.220687 to stay on the LP01 branch
# X_max restricted to 2.220897 to stay on the LP01 branch
# X_max restricted to 2.221106 to stay on the LP01 branch
# X_max restricted to 2.221315 to stay on the LP01 branch
# X_max restricted to 2.221525 to stay on the LP01 branch
# X_max restricted to 2.221734 to stay on the LP01 branch
# X_max restricted to 2.221944 to stay on the LP01 branch
# X_max restricted to 2.222153 to stay on the LP01 branch
# X_max restricted to 2.222363 to stay on the LP01 branch
# X_max restricted to 2.222572 to stay on the LP01 branch
# X_max restricted to 2.222782 to stay on the LP01 branch
# X_max restricted to 2.222991 to stay on the LP01 branch
# X_max restricted to 2.223200 to stay on the LP01 branch
# X_max restricted to 2.223410 to stay on the LP01 branch
# X_max restricted to 2.223619 to stay on the LP01 branch
# X_max restricted to 2.223829 to stay on the LP01 branch
# X_max restricted to 2.224038 to stay on the LP01 branch
# X_max restricted to 2.224248 to stay on the LP01 branch
# X_max restricted to 2.224457 to stay on the LP01 branch
# X_max restricted to 2.224666 to stay on the LP01 branch
# X_max restricted to 2.224876 to stay on the LP01 branch
# X_max restricted to 2.225085 to stay on the LP01 branch
# X_max restricted to 2.225295 to stay on the LP01 branch
# X_max restricted to 2.225504 to stay on the LP01 branch
# X_max restricted to 2.225714 to stay on the LP01 branch
# X_max restricted to 2.225923 to stay on the LP01 branch
# X_max restricted to 2.226133 to stay on the LP01 branch
# X_max restricted to 2.226342 to stay on the LP01 branch
# X_max restricted to 2.226551 to stay on the LP01 branch
# X_max restricted to 2.226761 to stay on the LP01 branch
# X_max restricted to 2.226970 to stay on the LP01 branch
# X_max restricted to 2.227180 to stay on the LP01 branch
# X_max restricted to 2.227389 to stay on the LP01 branch
# X_max restricted to 2.227599 to stay on the LP01 branch
# X_max restricted to 2.227808 to stay on the LP01 branch
# X_max restricted to 2.228017 to stay on the LP01 branch
# X_max restricted to 2.228227 to stay on the LP01 branch
# X_max restricted to 2.228436 to stay on the LP01 branch
# X_max restricted to 2.228646 to stay on the LP01 branch
# X_max restricted to 2.228855 to stay on the LP01 branch
# X_max restricted to 2.229065 to stay on the LP01 branch
# X_max restricted to 2.229274 to stay on the LP01 branch
# X_max restricted to 2.229484 to stay on the LP01 branch
# X_max restricted to 2.229693 to stay on the LP01 branch
# X_max restricted to 2.229902 to stay on the LP01 branch
# X_max restricted to 2.230112 to stay on the LP01 branch
# X_max restricted to 2.230321 to stay on the LP01 branch
# X_max restricted to 2.230531 to stay on the LP01 branch
# X_max restricted to 2.230740 to stay on the LP01 branch
# X_max restricted to 2.230950 to stay on the LP01 branch
# X_max restricted to 2.231159 to stay on the LP01 branch
# X_max restricted to 2.231369 to stay on the LP01 branch
# X_max restricted to 2.231578 to stay on the LP01 branch
# X_max restricted to 2.231787 to stay on the LP01 branch
# X_max restricted to 2.231997 to stay on the LP01 branch
# X_max restricted to 2.232206 to stay on the LP01 branch
# X_max restricted to 2.232416 to stay on the LP01 branch
# X_max restricted to 2.232625 to stay on the LP01 branch
# X_max restricted to 2.232835 to stay on the LP01 branch
# X_max restricted to 2.233044 to stay on the LP01 branch
# X_max restricted to 2.233253 to stay on the LP01 branch
# X_max restricted to 2.233463 to stay on the LP01 branch
# X_max restricted to 2.233672 to stay on the LP01 branch
# X_max restricted to 2.233882 to stay on the LP01 branch
# X_max restricted to 2.234091 to stay on the LP01 branch
# X_max restricted to 2.234301 to stay on the LP01 branch
# X_max restricted to 2.234510 to stay on the LP01 branch
# X_max restricted to 2.234720 to stay on the LP01 branch
# X_max restricted to 2.234929 to stay on the LP01 branch
# X_max restricted to 2.235138 to stay on the LP01 branch
# X_max restricted to 2.235348 to stay on the LP01 branch
# X_max restricted to 2.235557 to stay on the LP01 branch
# X_max restricted to 2.235767 to stay on the LP01 branch
# X_max restricted to 2.235976 to stay on the LP01 branch
# X_max restricted to 2.236186 to stay on the LP01 branch
# X_max restricted to 2.236395 to stay on the LP01 branch
# X_max restricted to 2.236605 to stay on the LP01 branch
# X_max restricted to 2.236814 to stay on the LP01 branch
# X_max restricted to 2.237023 to stay on the LP01 branch
# X_max restricted to 2.237233 to stay on the LP01 branch
# X_max restricted to 2.237442 to stay on the LP01 branch
# X_max restricted to 2.237652 to stay on the LP01 branch
# X_max restricted to 2.237861 to stay on the LP01 branch
# X_max restricted to 2.238071 to stay on the LP01 branch
# X_max restricted to 2.238280 to stay on the LP01 branch
# X_max restricted to 2.238489 to stay on the LP01 branch
# X_max restricted to 2.238699 to stay on the LP01 branch
# X_max restricted to 2.238908 to stay on the LP01 branch
# X_max restricted to 2.239118 to stay on the LP01 branch
# X_max restricted to 2.239327 to stay on the LP01 branch
# X_max restricted to 2.239537 to stay on the LP01 branch
# X_max restricted to 2.239746 to stay on the LP01 branch
# X_max restricted to 2.239956 to stay on the LP01 branch
# X_max restricted to 2.240165 to stay on the LP01 branch
# X_max restricted to 2.240374 to stay on the LP01 branch
# X_max restricted to 2.240584 to stay on the LP01 branch
# X_max restricted to 2.240793 to stay on the LP01 branch
# X_max restricted to 2.241003 to stay on the LP01 branch
# X_max restricted to 2.241212 to stay on the LP01 branch
# X_max restricted to 2.241422 to stay on the LP01 branch
# X_max restricted to 2.241631 to stay on the LP01 branch
# X_max restricted to 2.241841 to stay on the LP01 branch
# X_max restricted to 2.242050 to stay on the LP01 branch
# X_max restricted to 2.242259 to stay on the LP01 branch
# X_max restricted to 2.242469 to stay on the LP01 branch
# X_max restricted to 2.242678 to stay on the LP01 branch
# X_max restricted to 2.242888 to stay on the LP01 branch
# X_max restricted to 2.243097 to stay on the LP01 branch
# X_max restricted to 2.243307 to stay on the LP01 branch
# X_max restricted to 2.243516 to stay on the LP01 branch
# X_max restricted to 2.243725 to stay on the LP01 branch
# X_max restricted to 2.243935 to stay on the LP01 branch
# X_max restricted to 2.244144 to stay on the LP01 branch
# X_max restricted to 2.244354 to stay on the LP01 branch
# X_max restricted to 2.244563 to stay on the LP01 branch
# X_max restricted to 2.244773 to stay on the LP01 branch
# X_max restricted to 2.244982 to stay on the LP01 branch
# X_max restricted to 2.245192 to stay on the LP01 branch
# X_max restricted to 2.245401 to stay on the LP01 branch
# X_max restricted to 2.245610 to stay on the LP01 branch
# X_max restricted to 2.245820 to stay on the LP01 branch
# X_max restricted to 2.246029 to stay on the LP01 branch
# X_max restricted to 2.246239 to stay on the LP01 branch
# X_max restricted to 2.246448 to stay on the LP01 branch
# X_max restricted to 2.246658 to stay on the LP01 branch
# X_max restricted to 2.246867 to stay on the LP01 branch
# X_max restricted to 2.247076 to stay on the LP01 branch
# X_max restricted to 2.247286 to stay on the LP01 branch
# X_max restricted to 2.247495 to stay on the LP01 branch
# X_max restricted to 2.247705 to stay on the LP01 branch
# X_max restricted to 2.247914 to stay on the LP01 branch
# X_max restricted to 2.248124 to stay on the LP01 branch
# X_max restricted to 2.248333 to stay on the LP01 branch
# X_max restricted to 2.248543 to stay on the LP01 branch
# X_max restricted to 2.248752 to stay on the LP01 branch
# X_max restricted to 2.248961 to stay on the LP01 branch
# X_max restricted to 2.249171 to stay on the LP01 branch
# X_max restricted to 2.249380 to stay on the LP01 branch
# X_max restricted to 2.249590 to stay on the LP01 branch
# X_max restricted to 2.249799 to stay on the LP01 branch
# X_max restricted to 2.250009 to stay on the LP01 branch
# X_max restricted to 2.250218 to stay on the LP01 branch
# X_max restricted to 2.250428 to stay on the LP01 branch
# X_max restricted to 2.250637 to stay on the LP01 branch
# X_max restricted to 2.250846 to stay on the LP01 branch
# X_max restricted to 2.251056 to stay on the LP01 branch
# X_max restricted to 2.251265 to stay on the LP01 branch
# X_max restricted to 2.251475 to stay on the LP01 branch
# X_max restricted to 2.251684 to stay on the LP01 branch
# X_max restricted to 2.251894 to stay on the LP01 branch
# X_max restricted to 2.252103 to stay on the LP01 branch
# X_max restricted to 2.252312 to stay on the LP01 branch
# X_max restricted to 2.252522 to stay on the LP01 branch
# X_max restricted to 2.252731 to stay on the LP01 branch
# X_max restricted to 2.252941 to stay on the LP01 branch
# X_max restricted to 2.253150 to stay on the LP01 branch
# X_max restricted to 2.253360 to stay on the LP01 branch
# X_max restricted to 2.253569 to stay on the LP01 branch
# X_max restricted to 2.253779 to stay on the LP01 branch
# X_max restricted to 2.253988 to stay on the LP01 branch
# X_max restricted to 2.254197 to stay on the LP01 branch
# X_max restricted to 2.254407 to stay on the LP01 branch
# X_max restricted to 2.254616 to stay on the LP01 branch
# X_max restricted to 2.254826 to stay on the LP01 branch
# X_max restricted to 2.255035 to stay on the LP01 branch
# X_max restricted to 2.255245 to stay on the LP01 branch
# X_max restricted to 2.255454 to stay on the LP01 branch
# X_max restricted to 2.255664 to stay on the LP01 branch
# X_max restricted to 2.255873 to stay on the LP01 branch
# X_max restricted to 2.256082 to stay on the LP01 branch
# X_max restricted to 2.256292 to stay on the LP01 branch
# X_max restricted to 2.256501 to stay on the LP01 branch
# X_max restricted to 2.256711 to stay on the LP01 branch
# X_max restricted to 2.256920 to stay on the LP01 branch
# X_max restricted to 2.257130 to stay on the LP01 branch
# X_max restricted to 2.257339 to stay on the LP01 branch
# X_max restricted to 2.257548 to stay on the LP01 branch
# X_max restricted to 2.257758 to stay on the LP01 branch
# X_max restricted to 2.257967 to stay on the LP01 branch
# X_max restricted to 2.258177 to stay on the LP01 branch
# X_max restricted to 2.258386 to stay on the LP01 branch
# X_max restricted to 2.258596 to stay on the LP01 branch
# X_max restricted to 2.258805 to stay on the LP01 branch
# X_max restricted to 2.259015 to stay on the LP01 branch
# X_max restricted to 2.259224 to stay on the LP01 branch
# X_max restricted to 2.259433 to stay on the LP01 branch
# X_max restricted to 2.259643 to stay on the LP01 branch
# X_max restricted to 2.259852 to stay on the LP01 branch
# X_max restricted to 2.260062 to stay on the LP01 branch
# X_max restricted to 2.260271 to stay on the LP01 branch
# X_max restricted to 2.260481 to stay on the LP01 branch
# X_max restricted to 2.260690 to stay on the LP01 branch
# X_max restricted to 2.260900 to stay on the LP01 branch
# X_max restricted to 2.261109 to stay on the LP01 branch
# X_max restricted to 2.261318 to stay on the LP01 branch
# X_max restricted to 2.261528 to stay on the LP01 branch
# X_max restricted to 2.261737 to stay on the LP01 branch
# X_max restricted to 2.261947 to stay on the LP01 branch
# X_max restricted to 2.262156 to stay on the LP01 branch
# X_max restricted to 2.262366 to stay on the LP01 branch
# X_max restricted to 2.262575 to stay on the LP01 branch
# X_max restricted to 2.262784 to stay on the LP01 branch
# X_max restricted to 2.262994 to stay on the LP01 branch
# X_max restricted to 2.263203 to stay on the LP01 branch
# X_max restricted to 2.263413 to stay on the LP01 branch
# X_max restricted to 2.263622 to stay on the LP01 branch
# X_max restricted to 2.263832 to stay on the LP01 branch
# X_max restricted to 2.264041 to stay on the LP01 branch
# X_max restricted to 2.264251 to stay on the LP01 branch
# X_max restricted to 2.264460 to stay on the LP01 branch
# X_max restricted to 2.264669 to stay on the LP01 branch
# X_max restricted to 2.264879 to stay on the LP01 branch
# X_max restricted to 2.265088 to stay on the LP01 branch
# X_max restricted to 2.265298 to stay on the LP01 branch
# X_max restricted to 2.265507 to stay on the LP01 branch
# X_max restricted to 2.265717 to stay on the LP01 branch
# X_max restricted to 2.265926 to stay on the LP01 branch
# X_max restricted to 2.266135 to stay on the LP01 branch
# X_max restricted to 2.266345 to stay on the LP01 branch
# X_max restricted to 2.266554 to stay on the LP01 branch
# X_max restricted to 2.266764 to stay on the LP01 branch
# X_max restricted to 2.266973 to stay on the LP01 branch
# X_max restricted to 2.267183 to stay on the LP01 branch
# X_max restricted to 2.267392 to stay on the LP01 branch
# X_max restricted to 2.267602 to stay on the LP01 branch
# X_max restricted to 2.267811 to stay on the LP01 branch
# X_max restricted to 2.268020 to stay on the LP01 branch
# X_max restricted to 2.268230 to stay on the LP01 branch
# X_max restricted to 2.268439 to stay on the LP01 branch
# X_max restricted to 2.268649 to stay on the LP01 branch
# X_max restricted to 2.268858 to stay on the LP01 branch
# X_max restricted to 2.269068 to stay on the LP01 branch
# X_max restricted to 2.269277 to stay on the LP01 branch
# X_max restricted to 2.269487 to stay on the LP01 branch
# X_max restricted to 2.269696 to stay on the LP01 branch
# X_max restricted to 2.269905 to stay on the LP01 branch
# X_max restricted to 2.270115 to stay on the LP01 branch
# X_max restricted to 2.270324 to stay on the LP01 branch
# X_max restricted to 2.270534 to stay on the LP01 branch
# X_max restricted to 2.270743 to stay on the LP01 branch
# X_max restricted to 2.270953 to stay on the LP01 branch
# X_max restricted to 2.271162 to stay on the LP01 branch
# X_max restricted to 2.271371 to stay on the LP01 branch
# X_max restricted to 2.271581 to stay on the LP01 branch
# X_max restricted to 2.271790 to stay on the LP01 branch
# X_max restricted to 2.272000 to stay on the LP01 branch
# X_max restricted to 2.272209 to stay on the LP01 branch
# X_max restricted to 2.272419 to stay on the LP01 branch
# X_max restricted to 2.272628 to stay on the LP01 branch
# X_max restricted to 2.272838 to stay on the LP01 branch
# X_max restricted to 2.273047 to stay on the LP01 branch
# X_max restricted to 2.273256 to stay on the LP01 branch
# X_max restricted to 2.273466 to stay on the LP01 branch
# X_max restricted to 2.273675 to stay on the LP01 branch
# ...
# X_max restricted to 2.345513 to stay on the LP01 branch
# X_max restricted to 2.345723 to stay on the LP01 branch
# X_max restricted to 2.345932 to stay on the LP01 branch
# X_max restricted to 2.346141 to stay on the LP01 branch
# X_max restricted to 2.346351 to stay on the LP01 branch
# X_max restricted to 2.346560 to stay on the LP01 branch
# X_max restricted to 2.346770 to stay on the LP01 branch
# X_max restricted to 2.346979 to stay on the LP01 branch
# X_max restricted to 2.347189 to stay on the LP01 branch
# X_max restricted to 2.347398 to stay on the LP01 branch
# X_max restricted to 2.347607 to stay on the LP01 branch
# X_max restricted to 2.347817 to stay on the LP01 branch
# X_max restricted to 2.348026 to stay on the LP01 branch
# X_max restricted to 2.348236 to stay on the LP01 branch
# X_max restricted to 2.348445 to stay on the LP01 branch
# X_max restricted to 2.348655 to stay on the LP01 branch
# X_max restricted to 2.348864 to stay on the LP01 branch
# X_max restricted to 2.349074 to stay on the LP01 branch
# X_max restricted to 2.349283 to stay on the LP01 branch
# X_max restricted to 2.349492 to stay on the LP01 branch
# X_max restricted to 2.349702 to stay on the LP01 branch
# X_max restricted to 2.349911 to stay on the LP01 branch
# X_max restricted to 2.350121 to stay on the LP01 branch
# X_max restricted to 2.350330 to stay on the LP01 branch
# X_max restricted to 2.350540 to stay on the LP01 branch
# X_max restricted to 2.350749 to stay on the LP01 branch
# X_max restricted to 2.350958 to stay on the LP01 branch
# X_max restricted to 2.351168 to stay on the LP01 branch
# X_max restricted to 2.351377 to stay on the LP01 branch
# X_max restricted to 2.351587 to stay on the LP01 branch
# X_max restricted to 2.351796 to stay on the LP01 branch
# X_max restricted to 2.352006 to stay on the LP01 branch
# X_max restricted to 2.352215 to stay on the LP01 branch
# X_max restricted to 2.352425 to stay on the LP01 branch
# X_max restricted to 2.352634 to stay on the LP01 branch
# X_max restricted to 2.352843 to stay on the LP01 branch
# X_max restricted to 2.353053 to stay on the LP01 branch
# X_max restricted to 2.353262 to stay on the LP01 branch
# X_max restricted to 2.353472 to stay on the LP01 branch
# X_max restricted to 2.353681 to stay on the LP01 branch
# X_max restricted to 2.353891 to stay on the LP01 branch
# X_max restricted to 2.354100 to stay on the LP01 branch
# X_max restricted to 2.354310 to stay on the LP01 branch
# X_max restricted to 2.354519 to stay on the LP01 branch
# X_max restricted to 2.354728 to stay on the LP01 branch
# X_max restricted to 2.354938 to stay on the LP01 branch
# X_max restricted to 2.355147 to stay on the LP01 branch
# X_max restricted to 2.355357 to stay on the LP01 branch
# X_max restricted to 2.355566 to stay on the LP01 branch
# X_max restricted to 2.355776 to stay on the LP01 branch
# X_max restricted to 2.355985 to stay on the LP01 branch
# X_max restricted to 2.356194 to stay on the LP01 branch
# X_max restricted to 2.356404 to stay on the LP01 branch
# X_max restricted to 2.356613 to stay on the LP01 branch
# X_max restricted to 2.356823 to stay on the LP01 branch
# X_max restricted to 2.357032 to stay on the LP01 branch
# X_max restricted to 2.357242 to stay on the LP01 branch
# X_max restricted to 2.357451 to stay on the LP01 branch
# X_max restricted to 2.357661 to stay on the LP01 branch
# X_max restricted to 2.357870 to stay on the LP01 branch
# X_max restricted to 2.358079 to stay on the LP01 branch
# X_max restricted to 2.358289 to stay on the LP01 branch
# X_max restricted to 2.358498 to stay on the LP01 branch
# X_max restricted to 2.358708 to stay on the LP01 branch
# X_max restricted to 2.358917 to stay on the LP01 branch
# X_max restricted to 2.359127 to stay on the LP01 branch
# X_max restricted to 2.359336 to stay on the LP01 branch
# X_max restricted to 2.359546 to stay on the LP01 branch
# X_max restricted to 2.359755 to stay on the LP01 branch
# X_max restricted to 2.359964 to stay on the LP01 branch
# X_max restricted to 2.360174 to stay on the LP01 branch
# X_max restricted to 2.360383 to stay on the LP01 branch
# X_max restricted to 2.360593 to stay on the LP01 branch
# X_max restricted to 2.360802 to stay on the LP01 branch
# X_max restricted to 2.361012 to stay on the LP01 branch
# X_max restricted to 2.361221 to stay on the LP01 branch
# X_max restricted to 2.361430 to stay on the LP01 branch
# X_max restricted to 2.361640 to stay on the LP01 branch
# X_max restricted to 2.361849 to stay on the LP01 branch
# X_max restricted to 2.362059 to stay on the LP01 branch
# X_max restricted to 2.362268 to stay on the LP01 branch
# X_max restricted to 2.362478 to stay on the LP01 branch
# X_max restricted to 2.362687 to stay on the LP01 branch
# X_max restricted to 2.362897 to stay on the LP01 branch
# X_max restricted to 2.363106 to stay on the LP01 branch
# X_max restricted to 2.363315 to stay on the LP01 branch
# X_max restricted to 2.363525 to stay on the LP01 branch
# X_max restricted to 2.363734 to stay on the LP01 branch
# X_max restricted to 2.363944 to stay on the LP01 branch
# X_max restricted to 2.364153 to stay on the LP01 branch
# X_max restricted to 2.364363 to stay on the LP01 branch
# X_max restricted to 2.364572 to stay on the LP01 branch
# X_max restricted to 2.364782 to stay on the LP01 branch
# X_max restricted to 2.364991 to stay on the LP01 branch
# X_max restricted to 2.365200 to stay on the LP01 branch
# X_max restricted to 2.365410 to stay on the LP01 branch
# X_max restricted to 2.365619 to stay on the LP01 branch
# X_max restricted to 2.365829 to stay on the LP01 branch
# X_max restricted to 2.366038 to stay on the LP01 branch
# X_max restricted to 2.366248 to stay on the LP01 branch
# X_max restricted to 2.366457 to stay on the LP01 branch
# X_max restricted to 2.366666 to stay on the LP01 branch
# X_max restricted to 2.366876 to stay on the LP01 branch
# X_max restricted to 2.367085 to stay on the LP01 branch
# X_max restricted to 2.367295 to stay on the LP01 branch
# X_max restricted to 2.367504 to stay on the LP01 branch
# X_max restricted to 2.367714 to stay on the LP01 branch
# X_max restricted to 2.367923 to stay on the LP01 branch
# X_max restricted to 2.368133 to stay on the LP01 branch
# X_max restricted to 2.368342 to stay on the LP01 branch
# X_max restricted to 2.368551 to stay on the LP01 branch
# X_max restricted to 2.368761 to stay on the LP01 branch
# X_max restricted to 2.368970 to stay on the LP01 branch
# X_max restricted to 2.369180 to stay on the LP01 branch
# X_max restricted to 2.369389 to stay on the LP01 branch
# X_max restricted to 2.369599 to stay on the LP01 branch
# X_max restricted to 2.369808 to stay on the LP01 branch
# X_max restricted to 2.370017 to stay on the LP01 branch
# X_max restricted to 2.370227 to stay on the LP01 branch
# X_max restricted to 2.370436 to stay on the LP01 branch
# X_max restricted to 2.370646 to stay on the LP01 branch
# X_max restricted to 2.370855 to stay on the LP01 branch
# X_max restricted to 2.371065 to stay on the LP01 branch
# X_max restricted to 2.371274 to stay on the LP01 branch
# X_max restricted to 2.371484 to stay on the LP01 branch
# X_max restricted to 2.371693 to stay on the LP01 branch
# X_max restricted to 2.371902 to stay on the LP01 branch
# X_max restricted to 2.372112 to stay on the LP01 branch
# X_max restricted to 2.372321 to stay on the LP01 branch
# X_max restricted to 2.372531 to stay on the LP01 branch
# X_max restricted to 2.372740 to stay on the LP01 branch
# X_max restricted to 2.372950 to stay on the LP01 branch
# X_max restricted to 2.373159 to stay on the LP01 branch
# X_max restricted to 2.373369 to stay on the LP01 branch
# X_max restricted to 2.373578 to stay on the LP01 branch
# X_max restricted to 2.373787 to stay on the LP01 branch
# X_max restricted to 2.373997 to stay on the LP01 branch
# X_max restricted to 2.374206 to stay on the LP01 branch
# X_max restricted to 2.374416 to stay on the LP01 branch
# X_max restricted to 2.374625 to stay on the LP01 branch
# X_max restricted to 2.374835 to stay on the LP01 branch
# X_max restricted to 2.375044 to stay on the LP01 branch
# X_max restricted to 2.375253 to stay on the LP01 branch
# X_max restricted to 2.375463 to stay on the LP01 branch
# X_max restricted to 2.375672 to stay on the LP01 branch
# X_max restricted to 2.375882 to stay on the LP01 branch
# X_max restricted to 2.376091 to stay on the LP01 branch
# X_max restricted to 2.376301 to stay on the LP01 branch
# X_max restricted to 2.376510 to stay on the LP01 branch
# X_max restricted to 2.376720 to stay on the LP01 branch
# X_max restricted to 2.376929 to stay on the LP01 branch
# X_max restricted to 2.377138 to stay on the LP01 branch
# X_max restricted to 2.377348 to stay on the LP01 branch
# X_max restricted to 2.377557 to stay on the LP01 branch
# X_max restricted to 2.377767 to stay on the LP01 branch
# X_max restricted to 2.377976 to stay on the LP01 branch
# X_max restricted to 2.378186 to stay on the LP01 branch
# X_max restricted to 2.378395 to stay on the LP01 branch
# X_max restricted to 2.378605 to stay on the LP01 branch
# X_max restricted to 2.378814 to stay on the LP01 branch
# X_max restricted to 2.379023 to stay on the LP01 branch
# X_max restricted to 2.379233 to stay on the LP01 branch
# X_max restricted to 2.379442 to stay on the LP01 branch
# X_max restricted to 2.379652 to stay on the LP01 branch
# X_max restricted to 2.379861 to stay on the LP01 branch
# X_max restricted to 2.380071 to stay on the LP01 branch
# X_max restricted to 2.380280 to stay on the LP01 branch
# X_max restricted to 2.380489 to stay on the LP01 branch
# X_max restricted to 2.380699 to stay on the LP01 branch
# X_max restricted to 2.380908 to stay on the LP01 branch
# X_max restricted to 2.381118 to stay on the LP01 branch
# X_max restricted to 2.381327 to stay on the LP01 branch
# X_max restricted to 2.381537 to stay on the LP01 branch
# X_max restricted to 2.381746 to stay on the LP01 branch
# X_max restricted to 2.381956 to stay on the LP01 branch
# X_max restricted to 2.382165 to stay on the LP01 branch
# X_max restricted to 2.382374 to stay on the LP01 branch
# X_max restricted to 2.382584 to stay on the LP01 branch
# X_max restricted to 2.382793 to stay on the LP01 branch
# X_max restricted to 2.383003 to stay on the LP01 branch
# X_max restricted to 2.383212 to stay on the LP01 branch
# X_max restricted to 2.383422 to stay on the LP01 branch
# X_max restricted to 2.383631 to stay on the LP01 branch
# X_max restricted to 2.383840 to stay on the LP01 branch
# X_max restricted to 2.384050 to stay on the LP01 branch
# X_max restricted to 2.384259 to stay on the LP01 branch
# X_max restricted to 2.384469 to stay on the LP01 branch
# X_max restricted to 2.384678 to stay on the LP01 branch
# X_max restricted to 2.384888 to stay on the LP01 branch
# X_max restricted to 2.385097 to stay on the LP01 branch
# X_max restricted to 2.385307 to stay on the LP01 branch
# X_max restricted to 2.385516 to stay on the LP01 branch
# X_max restricted to 2.385725 to stay on the LP01 branch
# X_max restricted to 2.385935 to stay on the LP01 branch
# X_max restricted to 2.386144 to stay on the LP01 branch
# X_max restricted to 2.386354 to stay on the LP01 branch
# X_max restricted to 2.386563 to stay on the LP01 branch
# X_max restricted to 2.386773 to stay on the LP01 branch
# X_max restricted to 2.386982 to stay on the LP01 branch
# X_max restricted to 2.387192 to stay on the LP01 branch
# X_max restricted to 2.387401 to stay on the LP01 branch
# X_max restricted to 2.387610 to stay on the LP01 branch
# X_max restricted to 2.387820 to stay on the LP01 branch
# X_max restricted to 2.388029 to stay on the LP01 branch
# X_max restricted to 2.388239 to stay on the LP01 branch
# X_max restricted to 2.388448 to stay on the LP01 branch
# X_max restricted to 2.388658 to stay on the LP01 branch
# X_max restricted to 2.388867 to stay on the LP01 branch
# X_max restricted to 2.389076 to stay on the LP01 branch
# X_max restricted to 2.389286 to stay on the LP01 branch
# X_max restricted to 2.389495 to stay on the LP01 branch
# X_max restricted to 2.389705 to stay on the LP01 branch
# X_max restricted to 2.389914 to stay on the LP01 branch
# X_max restricted to 2.390124 to stay on the LP01 branch
# X_max restricted to 2.390333 to stay on the LP01 branch
# X_max restricted to 2.390543 to stay on the LP01 branch
# X_max restricted to 2.390752 to stay on the LP01 branch
# X_max restricted to 2.390961 to stay on the LP01 branch
# X_max restricted to 2.391171 to stay on the LP01 branch
# X_max restricted to 2.391380 to stay on the LP01 branch
# X_max restricted to 2.391590 to stay on the LP01 branch
# X_max restricted to 2.391799 to stay on the LP01 branch
# X_max restricted to 2.392009 to stay on the LP01 branch
# X_max restricted to 2.392218 to stay on the LP01 branch
# X_max restricted to 2.392428 to stay on the LP01 branch
# X_max restricted to 2.392637 to stay on the LP01 branch
# X_max restricted to 2.392846 to stay on the LP01 branch
# X_max restricted to 2.393056 to stay on the LP01 branch
# X_max restricted to 2.393265 to stay on the LP01 branch
# X_max restricted to 2.393475 to stay on the LP01 branch
# X_max restricted to 2.393684 to stay on the LP01 branch
# X_max restricted to 2.393894 to stay on the LP01 branch
# X_max restricted to 2.394103 to stay on the LP01 branch
# X_max restricted to 2.394312 to stay on the LP01 branch
# X_max restricted to 2.394522 to stay on the LP01 branch
# X_max restricted to 2.394731 to stay on the LP01 branch
# X_max restricted to 2.394941 to stay on the LP01 branch
# X_max restricted to 2.395150 to stay on the LP01 branch
# X_max restricted to 2.395360 to stay on the LP01 branch
# X_max restricted to 2.395569 to stay on the LP01 branch
# X_max restricted to 2.395779 to stay on the LP01 branch
# X_max restricted to 2.395988 to stay on the LP01 branch
# X_max restricted to 2.396197 to stay on the LP01 branch
# X_max restricted to 2.396407 to stay on the LP01 branch
# X_max restricted to 2.396616 to stay on the LP01 branch
# X_max restricted to 2.396826 to stay on the LP01 branch
# X_max restricted to 2.397035 to stay on the LP01 branch
# X_max restricted to 2.397245 to stay on the LP01 branch
# X_max restricted to 2.397454 to stay on the LP01 branch
# X_max restricted to 2.397664 to stay on the LP01 branch
# X_max restricted to 2.397873 to stay on the LP01 branch
# X_max restricted to 2.398082 to stay on the LP01 branch
# X_max restricted to 2.398292 to stay on the LP01 branch
# X_max restricted to 2.398501 to stay on the LP01 branch
# X_max restricted to 2.398711 to stay on the LP01 branch
# X_max restricted to 2.398920 to stay on the LP01 branch
# X_max restricted to 2.399130 to stay on the LP01 branch
# X_max restricted to 2.399339 to stay on the LP01 branch
# X_max restricted to 2.399548 to stay on the LP01 branch
# X_max restricted to 2.399758 to stay on the LP01 branch
# X_max restricted to 2.399967 to stay on the LP01 branch
# X_max restricted to 2.400177 to stay on the LP01 branch
# X_max restricted to 2.400386 to stay on the LP01 branch
# X_max restricted to 2.400596 to stay on the LP01 branch
# X_max restricted to 2.400805 to stay on the LP01 branch
# X_max restricted to 2.401015 to stay on the LP01 branch
# X_max restricted to 2.401224 to stay on the LP01 branch
# X_max restricted to 2.401433 to stay on the LP01 branch
# X_max restricted to 2.401643 to stay on the LP01 branch
# X_max restricted to 2.401852 to stay on the LP01 branch
# X_max restricted to 2.402062 to stay on the LP01 branch
# X_max restricted to 2.402271 to stay on the LP01 branch
# X_max restricted to 2.402481 to stay on the LP01 branch
# X_max restricted to 2.402690 to stay on the LP01 branch
# X_max restricted to 2.402899 to stay on the LP01 branch
# X_max restricted to 2.403109 to stay on the LP01 branch
# X_max restricted to 2.403318 to stay on the LP01 branch
# X_max restricted to 2.403528 to stay on the LP01 branch
# X_max restricted to 2.403737 to stay on the LP01 branch
# X_max restricted to 2.403947 to stay on the LP01 branch
# X_max restricted to 2.404156 to stay on the LP01 branch
# X_max restricted to 2.404366 to stay on the LP01 branch
# X_max restricted to 2.404575 to stay on the LP01 branch
# X_max restricted to 2.404784 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch

# %% [markdown]
# ### Note: Why include the signal up to cladding
# In optical waveguides, we distinguish stably propagating, lossless modes as guided modes and their unbounded, lossy counterparts as radiation modes.
# The guided modes are eigenmodes inside the core, and radiation modes correspond to the exponentially decaying component in the cladding.
#
# Even though the efficiency contribution via the overlap integral is small in the cladding, we cannot make a gross assuption that ignores the signal propagating as radiation loss in the cladding. Instead the 'relative' signal is the efficiency of the image electric cield multiplied by the field of full image.

# %%
relative_signal = efficiency_array_signal * signal_array 
relative_background = efficiency_array_noise * background_array

# %%
plt.figure(figsize=(9,6))
plt.plot(core_radius_range, FOV_array)
plt.xlabel('Core radius (m)')
plt.ylabel('Field of View (arcseconds)')
plt.title('Field of View vs Core Radius')
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.plot(core_radius_range, signal_array, label='Signal', color='green')
plt.plot(core_radius_range, background_array, label='Background', color='red')
# plt.plot(core_radius_range, snr_rel_array, label='Relative SNR')
plt.xlabel('Core radius (m)')
plt.ylabel('Flux density (counts / s / m$^2$)')
plt.title('Signal, Background vs Core Radius')
plt.legend()

# %%
plt.figure(figsize=(9,6))
plt.plot(core_radius_range, relative_signal, label='Signal', color='green')
# plt.plot(core_radius_range, relative_background, label='Background', color='red')
# plt.plot(core_radius_range, snr_rel_array, label='Relative SNR')
plt.xlabel('Core radius (m)')
plt.ylabel('Flux density (counts / s / m$^2$)')
plt.title('Relative Signal vs Core Radius')
plt.legend()

# %%
plt.figure(figsize=(9,6))
plt.plot(core_radius_range, relative_background, label='Background', color='red')
plt.xlabel('Core radius (m)')
plt.ylabel('Flux density (counts / s / m$^2$)')
plt.title('Relative Background vs Core Radius')
plt.legend()

# %%
plt.figure(figsize=(9,6))
plt.plot(core_radius_range, snr_array, label='Signal')
# plt.plot(core_radius_range, snr_rel_array, label='Relative SNR')
plt.xlabel('Core radius (m)')
plt.ylabel('SNR ratio')
plt.title('SNR vs Core Radius with No transmission loss (eta = 1)')
plt.legend()

# %%
efficiency_coefficient = np.divide(efficiency_array_signal, np.sqrt(efficiency_array_noise)) 
efficiency_coefficient
# Out:
# array([49.22453002, 49.2257441 , 49.22695685, ..., 49.75490149,
#        49.75451693, 49.7541315 ], shape=(1484,))

# %%
index_overall = np.argmax(efficiency_coefficient)
print(f'The most optimal radius occurs at {core_radius_range[index_overall]} with an efficiency of {efficiency_coefficient[index_overall]}.' )
# Out:
# The most optimal radius occurs at 5.5315e-06 with an efficiency of 49.836683201378214.

# %%
plt.figure(figsize=(9,6))
plt.plot(core_radius_range, efficiency_coefficient, label='Efficiency Coefficient (η_signal / sqrt(η_noise))', color='purple')
plt.scatter(core_radius_range[index_overall], efficiency_coefficient[index_overall], color='red', marker = 'x',
            label=f'Max Efficiency Coefficient: {efficiency_coefficient[index_overall]:.4f} at a={core_radius_range[index_overall]*1e6:.2f} µm')
plt.xlabel('Core radius (m)')
plt.ylabel('Efficiency Coefficient ($\eta_\mathrm{signal}\ /\ \sqrt{\eta_\mathrm{noise}}$)')
plt.title('Efficiency Coefficient vs Core Radius')
plt.legend()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\e'
# <>:6: SyntaxWarning: invalid escape sequence '\e'
# /var/folders/pk/ftg5vwzs3r1dhbzyhbqk09580000gp/T/ipykernel_78924/745832205.py:6: SyntaxWarning: invalid escape sequence '\e'
#   plt.ylabel('Efficiency Coefficient ($\eta_\mathrm{signal}\ /\ \sqrt{\eta_\mathrm{noise}}$)')

# %%
# The relative signal to noise is multiplied by the efficiency coefficient
snr_rel = np.multiply(efficiency_coefficient, snr_array)

# %%
index_snr_rel = np.argmax(snr_rel)
print(f'The most optimal radius occurs at {core_radius_range[index_snr_rel]} with a relative SNR of {snr_rel[index_snr_rel]:.4f}.' )
# Out:
# The most optimal radius occurs at 5e-06 with a relative SNR of 0.0000.

# %%
plt.figure(figsize=(9,6))
plt.plot(core_radius_range, snr_rel, label='Signal')
plt.scatter(core_radius_range[index_snr_rel], snr_rel[index_snr_rel], color='red', marker = 'x',
            label=f'Max Relative SNR: {snr_rel[index_snr_rel]:.4f} at a={core_radius_range[index_snr_rel]*1e6:.2f} µm')
# plt.plot(core_radius_range, snr_rel_array, label='Relative SNR')
plt.xlabel('Core radius (m)')
plt.ylabel('Value (arbitrary units)')
plt.title('Relative SNR vs Core Radius')
plt.legend()

# %% [markdown]
# ## Let's test what happens if we set our fibre from 0 micron to 20 micron

# %%
core_radius_range_test = np.linspace(1.2e-6, 50e-6, 1000) # from 4 to 20 microns in meters

efficiency_signal_test = np.zeros_like(core_radius_range_test)
efficiency_noise_test = np.zeros_like(core_radius_range_test)
numerator_signal_test = np.zeros_like(core_radius_range_test)
denominator_signal_test = np.zeros_like(core_radius_range_test)
numerator_noise_test = np.zeros_like(core_radius_range_test)
denominator_noise_test = np.zeros_like(core_radius_range_test)

V_norm = np.zeros_like(core_radius_range_test)

for i, a in enumerate(core_radius_range_test): 
    
    V = 2 * np.pi * (a / lam0) * NA # Calculate the V-number for the given radius
    X_min = 0 + 1e-8
    X_max = V - 1e-8
    # Find the X and Y roots for the given core radius a
    X_root, Y_root = find_root_LP01(V, X_min, X_max)
    # define a normalised radius r / a, with maximum at cladding size 125/2 micron
    fibre_rho = np.linspace(0, cladding_radius_max / a, 1000) 
    fibre_r = fibre_rho * a
    # Fibre field
    E_smf, I_smf = calculate_electric_field(fibre_rho, X_root, Y_root)
    # Image field
    E_image, I_image = demagnified_diffraction_limited_E_field(fibre_r, lam0, F_focus, alpha, E_S, Magnification)
    E_flat = np.ones_like(fibre_r) * 1
    I_flat = np.abs(E_flat) **2
    # Calculate coupling efficiency
    eta_signal, numerator_signal, denominator_signal = coupling_efficiency_1d(E_image, E_smf, r=fibre_r)
    eta_noise, numerator_noise, denominator_noise = coupling_efficiency_1d(E_flat, E_smf, r=fibre_r)
    efficiency_signal_test[i] = eta_signal
    efficiency_noise_test[i] = eta_noise
    # store the numerator and denominator separately for signal and noise to check the behaviour of each component
    numerator_signal_test[i] = numerator_signal
    denominator_signal_test[i] = denominator_signal
    
    numerator_noise_test[i] = numerator_noise
    denominator_noise_test[i] = denominator_noise
    # Store the V-number for each core radius to check the single-mode cutoff behaviour
    V_norm[i] = V
    # print(a, V, X_root, Y_root)

    if i == -1:
        # plot the characteristic equation of lhs-rhs vs X to check the root finding
        X_scan = np.linspace(X_min, X_max, 5000)
        F_scan = function_LP01(X_scan, V)
        plt.figure(figsize=(8,4))
        plt.plot(X_scan, F_scan, label='f(X) = LHS - RHS')
        plt.axhline(0, color='gray', linestyle='--') # Add a horizontal line at y=0 for reference
        plt.xlabel('X')
        plt.ylabel('f(X)')
        plt.title(f'Characteristic Equation for a={a} m')
        plt.show()
# Out:
# X_max restricted to 0.502655 to stay on the LP01 branch
# X_max restricted to 0.523117 to stay on the LP01 branch
# X_max restricted to 0.543578 to stay on the LP01 branch
# X_max restricted to 0.564040 to stay on the LP01 branch
# X_max restricted to 0.584502 to stay on the LP01 branch
# X_max restricted to 0.604964 to stay on the LP01 branch
# X_max restricted to 0.625425 to stay on the LP01 branch
# X_max restricted to 0.645887 to stay on the LP01 branch
# X_max restricted to 0.666349 to stay on the LP01 branch
# X_max restricted to 0.686811 to stay on the LP01 branch
# X_max restricted to 0.707272 to stay on the LP01 branch
# X_max restricted to 0.727734 to stay on the LP01 branch
# X_max restricted to 0.748196 to stay on the LP01 branch
# X_max restricted to 0.768658 to stay on the LP01 branch
# X_max restricted to 0.789119 to stay on the LP01 branch
# X_max restricted to 0.809581 to stay on the LP01 branch
# X_max restricted to 0.830043 to stay on the LP01 branch
# X_max restricted to 0.850505 to stay on the LP01 branch
# X_max restricted to 0.870966 to stay on the LP01 branch
# X_max restricted to 0.891428 to stay on the LP01 branch
# X_max restricted to 0.911890 to stay on the LP01 branch
# X_max restricted to 0.932352 to stay on the LP01 branch
# X_max restricted to 0.952813 to stay on the LP01 branch
# X_max restricted to 0.973275 to stay on the LP01 branch
# X_max restricted to 0.993737 to stay on the LP01 branch
# X_max restricted to 1.014199 to stay on the LP01 branch
# X_max restricted to 1.034661 to stay on the LP01 branch
# X_max restricted to 1.055122 to stay on the LP01 branch
# X_max restricted to 1.075584 to stay on the LP01 branch
# X_max restricted to 1.096046 to stay on the LP01 branch
# X_max restricted to 1.116508 to stay on the LP01 branch
# X_max restricted to 1.136969 to stay on the LP01 branch
# X_max restricted to 1.157431 to stay on the LP01 branch
# X_max restricted to 1.177893 to stay on the LP01 branch
# X_max restricted to 1.198355 to stay on the LP01 branch
# X_max restricted to 1.218816 to stay on the LP01 branch
# X_max restricted to 1.239278 to stay on the LP01 branch
# X_max restricted to 1.259740 to stay on the LP01 branch
# X_max restricted to 1.280202 to stay on the LP01 branch
# X_max restricted to 1.300663 to stay on the LP01 branch
# X_max restricted to 1.321125 to stay on the LP01 branch
# X_max restricted to 1.341587 to stay on the LP01 branch
# X_max restricted to 1.362049 to stay on the LP01 branch
# X_max restricted to 1.382510 to stay on the LP01 branch
# X_max restricted to 1.402972 to stay on the LP01 branch
# X_max restricted to 1.423434 to stay on the LP01 branch
# X_max restricted to 1.443896 to stay on the LP01 branch
# X_max restricted to 1.464357 to stay on the LP01 branch
# X_max restricted to 1.484819 to stay on the LP01 branch
# X_max restricted to 1.505281 to stay on the LP01 branch
# X_max restricted to 1.525743 to stay on the LP01 branch
# X_max restricted to 1.546204 to stay on the LP01 branch
# X_max restricted to 1.566666 to stay on the LP01 branch
# X_max restricted to 1.587128 to stay on the LP01 branch
# X_max restricted to 1.607590 to stay on the LP01 branch
# X_max restricted to 1.628052 to stay on the LP01 branch
# X_max restricted to 1.648513 to stay on the LP01 branch
# X_max restricted to 1.668975 to stay on the LP01 branch
# X_max restricted to 1.689437 to stay on the LP01 branch
# X_max restricted to 1.709899 to stay on the LP01 branch
# X_max restricted to 1.730360 to stay on the LP01 branch
# X_max restricted to 1.750822 to stay on the LP01 branch
# X_max restricted to 1.771284 to stay on the LP01 branch
# X_max restricted to 1.791746 to stay on the LP01 branch
# X_max restricted to 1.812207 to stay on the LP01 branch
# X_max restricted to 1.832669 to stay on the LP01 branch
# X_max restricted to 1.853131 to stay on the LP01 branch
# X_max restricted to 1.873593 to stay on the LP01 branch
# X_max restricted to 1.894054 to stay on the LP01 branch
# X_max restricted to 1.914516 to stay on the LP01 branch
# X_max restricted to 1.934978 to stay on the LP01 branch
# X_max restricted to 1.955440 to stay on the LP01 branch
# X_max restricted to 1.975901 to stay on the LP01 branch
# X_max restricted to 1.996363 to stay on the LP01 branch
# X_max restricted to 2.016825 to stay on the LP01 branch
# X_max restricted to 2.037287 to stay on the LP01 branch
# X_max restricted to 2.057748 to stay on the LP01 branch
# X_max restricted to 2.078210 to stay on the LP01 branch
# X_max restricted to 2.098672 to stay on the LP01 branch
# X_max restricted to 2.119134 to stay on the LP01 branch
# X_max restricted to 2.139595 to stay on the LP01 branch
# X_max restricted to 2.160057 to stay on the LP01 branch
# X_max restricted to 2.180519 to stay on the LP01 branch
# X_max restricted to 2.200981 to stay on the LP01 branch
# X_max restricted to 2.221442 to stay on the LP01 branch
# X_max restricted to 2.241904 to stay on the LP01 branch
# X_max restricted to 2.262366 to stay on the LP01 branch
# X_max restricted to 2.282828 to stay on the LP01 branch
# X_max restricted to 2.303290 to stay on the LP01 branch
# X_max restricted to 2.323751 to stay on the LP01 branch
# X_max restricted to 2.344213 to stay on the LP01 branch
# X_max restricted to 2.364675 to stay on the LP01 branch
# X_max restricted to 2.385137 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch
# X_max restricted to 2.404826 to stay on the LP01 branch

# %%
plt.plot(core_radius_range_test * 1e6, numerator_signal_test, label='Numerator (Signal)', color='green')
# plt.plot(core_radius_range_test, denominator_signal_test, label='Denominator (Signal)', color='lightgreen')
# plt.plot(core_radius_range_test, numerator_noise_test, label='Numerator (Noise)', color='red')
# plt.plot(core_radius_range_test, denominator_noise_test, label='Denominator (Noise)', color='salmon')
plt.xlabel('Core radius (µm)')
plt.ylabel('Value (arbitrary units)')
plt.title('Numerator and Denominator for Signal and Noise vs Core Radius')
plt.legend()

# %%
# plt.plot(core_radius_range_test * 1e6, numerator_signal_test, label='Numerator (Signal)', color='green')
plt.plot(core_radius_range_test, denominator_signal_test, label='Denominator (Signal)', color='lightgreen')
# plt.plot(core_radius_range_test, numerator_noise_test, label='Numerator (Noise)', color='red')
# plt.plot(core_radius_range_test, denominator_noise_test, label='Denominator (Noise)', color='salmon')
plt.xlabel('Core radius (µm)')
plt.ylabel('Value (arbitrary units)')
plt.title('Numerator and Denominator for Signal and Noise vs Core Radius')
plt.legend()

# %%
numerator_noise_test / denominator_noise_test
# Out:
# array([9.39935159e-01, 8.97967658e-01, 8.26564851e-01, 7.14982056e-01,
#        5.65092562e-01, 4.01999842e-01, 2.61284871e-01, 1.61727774e-01,
#        9.96843114e-02, 6.29793428e-02, 4.12428465e-02, 2.80186798e-02,
#        1.96914555e-02, 1.42676774e-02, 1.06240902e-02, 8.10727011e-03,
#        6.32457884e-03, 5.03290259e-03, 4.07757137e-03, 3.35770259e-03,
#        2.80597991e-03, 2.37653649e-03, 2.03751419e-03, 1.76638979e-03,
#        1.54697732e-03, 1.36746757e-03, 1.21912294e-03, 1.09539655e-03,
#        9.91352881e-04, 9.03181731e-04, 8.27918506e-04, 7.63241034e-04,
#        7.07313467e-04, 6.58671799e-04, 6.16139000e-04, 5.78761483e-04,
#        5.45761089e-04, 5.16498468e-04, 4.90444930e-04, 4.67160615e-04,
#        4.46280544e-04, 4.27510629e-04, 4.10589210e-04, 3.95291744e-04,
#        3.81426512e-04, 3.68829093e-04, 3.57357879e-04, 3.46890414e-04,
#        3.37320395e-04, 3.28555195e-04, 3.20513819e-04, 3.13125198e-04,
#        3.06326770e-04, 3.00066018e-04, 2.94301057e-04, 2.88988269e-04,
#        2.84088460e-04, 2.79566653e-04, 2.75391556e-04, 2.71535099e-04,
#        2.67972041e-04, 2.64679634e-04, 2.61637327e-04, 2.58826510e-04,
#        2.56230295e-04, 2.53833322e-04, 2.51623558e-04, 2.49590942e-04,
#        2.47723809e-04, 2.46011479e-04, 2.44444167e-04, 2.43012891e-04,
#        2.41709394e-04, 2.40526068e-04, 2.39455892e-04, 2.38492375e-04,
#        2.37629502e-04, 2.36861693e-04, 2.36183763e-04, 2.35591680e-04,
#        2.35081634e-04, 2.34649638e-04, 2.34291983e-04, 2.34005211e-04,
#        2.33786093e-04, 2.33631607e-04, 2.33538921e-04, 2.33505377e-04,
#        2.33528472e-04, 2.33605848e-04, 2.33735278e-04, 2.33914612e-04,
#        2.34141272e-04, 2.34413409e-04, 2.34729522e-04, 2.35088196e-04,
#        2.35488095e-04, 2.35927952e-04, 2.36406567e-04, 2.36922799e-04,
#        2.37475560e-04, 2.38063809e-04, 2.38686549e-04, 2.39342824e-04,
#        2.40031411e-04, 2.40749696e-04, 2.41496810e-04, 2.42272243e-04,
#        2.43075510e-04, 2.43906146e-04, 2.44763706e-04, 2.45647761e-04,
#        2.46557895e-04, 2.47493705e-04, 2.48454797e-04, 2.49440786e-04,
#        2.50451292e-04, 2.51485099e-04, 2.52539422e-04, 2.53614026e-04,
#        2.54708866e-04, 2.55823894e-04, 2.56959067e-04, 2.58114336e-04,
#        2.59289653e-04, 2.60484965e-04, 2.61700216e-04, 2.62935342e-04,
#        2.64190277e-04, 2.65464944e-04, 2.66757548e-04, 2.68065474e-04,
#        2.69388891e-04, 2.70727998e-04, 2.72082982e-04, 2.73454026e-04,
#        2.74841302e-04, 2.76244970e-04, 2.77665184e-04, 2.79102083e-04,
#        2.80555799e-04, 2.82026448e-04, 2.83514121e-04, 2.85016011e-04,
#        2.86530175e-04, 2.88056964e-04, 2.89596717e-04, 2.91149763e-04,
#        2.92716418e-04, 2.94296987e-04, 2.95891761e-04, 2.97501019e-04,
#        2.99125027e-04, 3.00764037e-04, 3.02418285e-04, 3.04087796e-04,
#        3.05768832e-04, 3.07460248e-04, 3.09162488e-04, 3.10875980e-04,
#        3.12601142e-04, 3.14338379e-04, 3.16088081e-04, 3.17850627e-04,
#        3.19626381e-04, 3.21415695e-04, 3.23218904e-04, 3.25036329e-04,
#        3.26867629e-04, 3.28708501e-04, 3.30558519e-04, 3.32418186e-04,
#        3.34287992e-04, 3.36168416e-04, 3.38059924e-04, 3.39962968e-04,
#        3.41877988e-04, 3.43805411e-04, 3.45745649e-04, 3.47699100e-04,
#        3.49666148e-04, 3.51645766e-04, 3.53633564e-04, 3.55629680e-04,
#        3.57634660e-04, 3.59649040e-04, 3.61673341e-04, 3.63708076e-04,
#        3.65753742e-04, 3.67810825e-04, 3.69879799e-04, 3.71961125e-04,
#        3.74055248e-04, 3.76162601e-04, 3.78281133e-04, 3.80406922e-04,
#        3.82540465e-04, 3.84682342e-04, 3.86833119e-04, 3.88993355e-04,
#        3.91163594e-04, 3.93344372e-04, 3.95536209e-04, 3.97739619e-04,
#        3.99955098e-04, 4.02183132e-04, 4.04424190e-04, 4.06674850e-04,
#        4.08932266e-04, 4.11197051e-04, 4.13469808e-04, 4.15751132e-04,
#        4.18041606e-04, 4.20341803e-04, 4.22652289e-04, 4.24973614e-04,
#        4.27306320e-04, 4.29650938e-04, 4.32007986e-04, 4.34377776e-04,
#        4.36755701e-04, 4.39140100e-04, 4.41531604e-04, 4.43930839e-04,
#        4.46338419e-04, 4.48754951e-04, 4.51181031e-04, 4.53617248e-04,
#        4.56064178e-04, 4.58522390e-04, 4.60992441e-04, 4.63474878e-04,
#        4.65969548e-04, 4.68471183e-04, 4.70979102e-04, 4.73493952e-04,
#        4.76016375e-04, 4.78547004e-04, 4.81086464e-04, 4.83635371e-04,
#        4.86194335e-04, 4.88763955e-04, 4.91344821e-04, 4.93937514e-04,
#        4.96542605e-04, 4.99159150e-04, 5.01781801e-04, 5.04410612e-04,
#        5.07046244e-04, 5.09689354e-04, 5.12340590e-04, 5.15000594e-04,
#        5.17669999e-04, 5.20349434e-04, 5.23039516e-04, 5.25740855e-04,
#        5.28454054e-04, 5.31179705e-04, 5.33915727e-04, 5.36657316e-04,
#        5.39404991e-04, 5.42159428e-04, 5.44921293e-04, 5.47691250e-04,
#        5.50469954e-04, 5.53258055e-04, 5.56056197e-04, 5.58865015e-04,
#        5.61685136e-04, 5.64517183e-04, 5.67361768e-04, 5.70215309e-04,
#        5.73074213e-04, 5.75939169e-04, 5.78810861e-04, 5.81689970e-04,
#        5.84577170e-04, 5.87473131e-04, 5.90378515e-04, 5.93293981e-04,
#        5.96220180e-04, 5.99157757e-04, 6.02107349e-04, 6.05069434e-04,
#        6.08039019e-04, 6.11013952e-04, 6.13994934e-04, 6.16982658e-04,
#        6.19977813e-04, 6.22981087e-04, 6.25993159e-04, 6.29014706e-04,
#        6.32046400e-04, 6.35088906e-04, 6.38142883e-04, 6.41208986e-04,
#        6.44287224e-04, 6.47371799e-04, 6.50461736e-04, 6.53557740e-04,
#        6.56660515e-04, 6.59770759e-04, 6.62889169e-04, 6.66016437e-04,
#        6.69153251e-04, 6.72300294e-04, 6.75458245e-04, 6.78627778e-04,
#        6.81809562e-04, 6.85002792e-04, 6.88201510e-04, 6.91405620e-04,
#        6.94615837e-04, 6.97832870e-04, 7.01057430e-04, 7.04290220e-04,
#        7.07531944e-04, 7.10783300e-04, 7.14044983e-04, 7.17317685e-04,
#        7.20602092e-04, 7.23898887e-04, 7.27206091e-04, 7.30518259e-04,
#        7.33835868e-04, 7.37159637e-04, 7.40490285e-04, 7.43828530e-04,
#        7.47175086e-04, 7.50530664e-04, 7.53895973e-04, 7.57271719e-04,
#        7.60658606e-04, 7.64057332e-04, 7.67468593e-04, 7.70888864e-04,
#        7.74313915e-04, 7.77744468e-04, 7.81181249e-04, 7.84624984e-04,
#        7.88076399e-04, 7.91536215e-04, 7.95005154e-04, 7.98483934e-04,
#        8.01973271e-04, 8.05473880e-04, 8.08986471e-04, 8.12511644e-04,
#        8.16044270e-04, 8.19581736e-04, 8.23124775e-04, 8.26674122e-04,
#        8.30230509e-04, 8.33794668e-04, 8.37367330e-04, 8.40949224e-04,
#        8.44541077e-04, 8.48143617e-04, 8.51757567e-04, 8.55383648e-04,
#        8.59022024e-04, 8.62666599e-04, 8.66316090e-04, 8.69971237e-04,
#        8.73632780e-04, 8.77301457e-04, 8.80978008e-04, 8.84663171e-04,
#        8.88357684e-04, 8.92062283e-04, 8.95777703e-04, 8.99504679e-04,
#        9.03243943e-04, 9.06994857e-04, 9.10751047e-04, 9.14512239e-04,
#        9.18279177e-04, 9.22052607e-04, 9.25833274e-04, 9.29621924e-04,
#        9.33419303e-04, 9.37226155e-04, 9.41043227e-04, 9.44871262e-04,
#        9.48711004e-04, 9.52563195e-04, 9.56426025e-04, 9.60293551e-04,
#        9.64166171e-04, 9.68044635e-04, 9.71929695e-04, 9.75822100e-04,
#        9.79722605e-04, 9.83631961e-04, 9.87550921e-04, 9.91480239e-04,
#        9.95420667e-04, 9.99372958e-04, 1.00333786e-03, 1.00731202e-03,
#        1.01129065e-03, 1.01527447e-03, 1.01926424e-03, 1.02326071e-03,
#        1.02726464e-03, 1.03127680e-03, 1.03529793e-03, 1.03932881e-03,
#        1.04337018e-03, 1.04742282e-03, 1.05148748e-03, 1.05556486e-03,
#        1.05964985e-03, 1.06373938e-03, 1.06783420e-03, 1.07193509e-03,
#        1.07604279e-03, 1.08015808e-03, 1.08428171e-03, 1.08841446e-03,
#        1.09255708e-03, 1.09671036e-03, 1.10087505e-03, 1.10505193e-03,
#        1.10924130e-03, 1.11343692e-03, 1.11763719e-03, 1.12184286e-03,
#        1.12605470e-03, 1.13027348e-03, 1.13449997e-03, 1.13873494e-03,
#        1.14297916e-03, 1.14723340e-03, 1.15149844e-03, 1.15577506e-03,
#        1.16006404e-03, 1.16436491e-03, 1.16867101e-03, 1.17298187e-03,
#        1.17729825e-03, 1.18162092e-03, 1.18595065e-03, 1.19028822e-03,
#        1.19463440e-03, 1.19898997e-03, 1.20335572e-03, 1.20773242e-03,
#        1.21212086e-03, 1.21652183e-03, 1.22093372e-03, 1.22535018e-03,
#        1.22977151e-03, 1.23419848e-03, 1.23863186e-03, 1.24307243e-03,
#        1.24752098e-03, 1.25197827e-03, 1.25644510e-03, 1.26092226e-03,
#        1.26541053e-03, 1.26991071e-03, 1.27442359e-03, 1.27894602e-03,
#        1.28347273e-03, 1.28800443e-03, 1.29254189e-03, 1.29708589e-03,
#        1.30163722e-03, 1.30619665e-03, 1.31076498e-03, 1.31534299e-03,
#        1.31993148e-03, 1.32453124e-03, 1.32914308e-03, 1.33376777e-03,
#        1.33840031e-03, 1.34303719e-03, 1.34767917e-03, 1.35232704e-03,
#        1.35698159e-03, 1.36164359e-03, 1.36631384e-03, 1.37099312e-03,
#        1.37568225e-03, 1.38038200e-03, 1.38509320e-03, 1.38981665e-03,
#        1.39455277e-03, 1.39929528e-03, 1.40404225e-03, 1.40879445e-03,
#        1.41355266e-03, 1.41831768e-03, 1.42309029e-03, 1.42787129e-03,
#        1.43266148e-03, 1.43746166e-03, 1.44227264e-03, 1.44709522e-03,
#        1.45193022e-03, 1.45677736e-03, 1.46162977e-03, 1.46648676e-03,
#        1.47134911e-03, 1.47621761e-03, 1.48109305e-03, 1.48597623e-03,
#        1.49086793e-03, 1.49576898e-03, 1.50068017e-03, 1.50560233e-03,
#        1.51053625e-03, 1.51548277e-03, 1.52044050e-03, 1.52540275e-03,
#        1.53036972e-03, 1.53534217e-03, 1.54032091e-03, 1.54530672e-03,
#        1.55030041e-03, 1.55530279e-03, 1.56031465e-03, 1.56533683e-03,
#        1.57037012e-03, 1.57541536e-03, 1.58047337e-03, 1.58554126e-03,
#        1.59061332e-03, 1.59569021e-03, 1.60077272e-03, 1.60586166e-03,
#        1.61095781e-03, 1.61606199e-03, 1.62117500e-03, 1.62629765e-03,
#        1.63143078e-03, 1.63657519e-03, 1.64173172e-03, 1.64690119e-03,
#        1.65207883e-03, 1.65726065e-03, 1.66244743e-03, 1.66763998e-03,
#        1.67283908e-03, 1.67804554e-03, 1.68326017e-03, 1.68848379e-03,
#        1.69371722e-03, 1.69896127e-03, 1.70421678e-03, 1.70948459e-03,
#        1.71476524e-03, 1.72005248e-03, 1.72534403e-03, 1.73064067e-03,
#        1.73594322e-03, 1.74125246e-03, 1.74656921e-03, 1.75189428e-03,
#        1.75722849e-03, 1.76257267e-03, 1.76792764e-03, 1.77329424e-03,
#        1.77867331e-03, 1.78406474e-03, 1.78946155e-03, 1.79486280e-03,
#        1.80026929e-03, 1.80568181e-03, 1.81110117e-03, 1.81652819e-03,
#        1.82196369e-03, 1.82740848e-03, 1.83286339e-03, 1.83832927e-03,
#        1.84380696e-03, 1.84929729e-03, 1.85479910e-03, 1.86030546e-03,
#        1.86581639e-03, 1.87133270e-03, 1.87685518e-03, 1.88238466e-03,
#        1.88792194e-03, 1.89346784e-03, 1.89902320e-03, 1.90458885e-03,
#        1.91016564e-03, 1.91575440e-03, 1.92135599e-03, 1.92696777e-03,
#        1.93258366e-03, 1.93820427e-03, 1.94383039e-03, 1.94946282e-03,
#        1.95510240e-03, 1.96074993e-03, 1.96640624e-03, 1.97207217e-03,
#        1.97774855e-03, 1.98343624e-03, 1.98913608e-03, 1.99484893e-03,
#        2.00057029e-03, 2.00629570e-03, 2.01202597e-03, 2.01776188e-03,
#        2.02350427e-03, 2.02925394e-03, 2.03501171e-03, 2.04077843e-03,
#        2.04655493e-03, 2.05234205e-03, 2.05814064e-03, 2.06395157e-03,
#        2.06977548e-03, 2.07560622e-03, 2.08144114e-03, 2.08728105e-03,
#        2.09312677e-03, 2.09897909e-03, 2.10483886e-03, 2.11070688e-03,
#        2.11658401e-03, 2.12247108e-03, 2.12836894e-03, 2.13427845e-03,
#        2.14020046e-03, 2.14613505e-03, 2.15207515e-03, 2.15801959e-03,
#        2.16396915e-03, 2.16992466e-03, 2.17588692e-03, 2.18185678e-03,
#        2.18783506e-03, 2.19382260e-03, 2.19982025e-03, 2.20582886e-03,
#        2.21184929e-03, 2.21788241e-03, 2.22392728e-03, 2.22997675e-03,
#        2.23603069e-03, 2.24208990e-03, 2.24815520e-03, 2.25422742e-03,
#        2.26030737e-03, 2.26639591e-03, 2.27249387e-03, 2.27860211e-03,
#        2.28472147e-03, 2.29085284e-03, 2.29699708e-03, 2.30315184e-03,
#        2.30931068e-03, 2.31547412e-03, 2.32164298e-03, 2.32781809e-03,
#        2.33400025e-03, 2.34019032e-03, 2.34638912e-03, 2.35259751e-03,
#        2.35881635e-03, 2.36504649e-03, 2.37128881e-03, 2.37754419e-03,
#        2.38380844e-03, 2.39007664e-03, 2.39634960e-03, 2.40262812e-03,
#        2.40891303e-03, 2.41520515e-03, 2.42150533e-03, 2.42781442e-03,
#        2.43413325e-03, 2.44046270e-03, 2.44680363e-03, 2.45315692e-03,
#        2.45952331e-03, 2.46589680e-03, 2.47227437e-03, 2.47865685e-03,
#        2.48504503e-03, 2.49143976e-03, 2.49784185e-03, 2.50425216e-03,
#        2.51067154e-03, 2.51710083e-03, 2.52354091e-03, 2.52999265e-03,
#        2.53645692e-03, 2.54293395e-03, 2.54941668e-03, 2.55590363e-03,
#        2.56239563e-03, 2.56889349e-03, 2.57539804e-03, 2.58191012e-03,
#        2.58843057e-03, 2.59496025e-03, 2.60150002e-03, 2.60805075e-03,
#        2.61461331e-03, 2.62118860e-03, 2.62777587e-03, 2.63436784e-03,
#        2.64096418e-03, 2.64756572e-03, 2.65417326e-03, 2.66078765e-03,
#        2.66740973e-03, 2.67404034e-03, 2.68068035e-03, 2.68733061e-03,
#        2.69399201e-03, 2.70066542e-03, 2.70735173e-03, 2.71404887e-03,
#        2.72075009e-03, 2.72745583e-03, 2.73416691e-03, 2.74088415e-03,
#        2.74760840e-03, 2.75434049e-03, 2.76108128e-03, 2.76783162e-03,
#        2.77459240e-03, 2.78136449e-03, 2.78814877e-03, 2.79494613e-03,
#        2.80175274e-03, 2.80856323e-03, 2.81537838e-03, 2.82219902e-03,
#        2.82902597e-03, 2.83586009e-03, 2.84270221e-03, 2.84955319e-03,
#        2.85641390e-03, 2.86328522e-03, 2.87016801e-03, 2.87706319e-03,
#        2.88397155e-03, 2.89088732e-03, 2.89780708e-03, 2.90473165e-03,
#        2.91166187e-03, 2.91859856e-03, 2.92554256e-03, 2.93249473e-03,
#        2.93945593e-03, 2.94642702e-03, 2.95340889e-03, 2.96040243e-03,
#        2.96740852e-03, 2.97442752e-03, 2.98145243e-03, 2.98848149e-03,
#        2.99551550e-03, 3.00255531e-03, 3.00960174e-03, 3.01665565e-03,
#        3.02371789e-03, 3.03078933e-03, 3.03787083e-03, 3.04496328e-03,
#        3.05206757e-03, 3.05918461e-03, 3.06631387e-03, 3.07344794e-03,
#        3.08058630e-03, 3.08772977e-03, 3.09487919e-03, 3.10203539e-03,
#        3.10919922e-03, 3.11637155e-03, 3.12355325e-03, 3.13074518e-03,
#        3.13794824e-03, 3.14516332e-03, 3.15239133e-03, 3.15963045e-03,
#        3.16687370e-03, 3.17412138e-03, 3.18137432e-03, 3.18863337e-03,
#        3.19589936e-03, 3.20317314e-03, 3.21045559e-03, 3.21774756e-03,
#        3.22504995e-03, 3.23236364e-03, 3.23968954e-03, 3.24702854e-03,
#        3.25437715e-03, 3.26172958e-03, 3.26908660e-03, 3.27644904e-03,
#        3.28381773e-03, 3.29119353e-03, 3.29857729e-03, 3.30596987e-03,
#        3.31337215e-03, 3.32078502e-03, 3.32820937e-03, 3.33564611e-03,
#        3.34309610e-03, 3.35055383e-03, 3.35801547e-03, 3.36548185e-03,
#        3.37295380e-03, 3.38043217e-03, 3.38791779e-03, 3.39541154e-03,
#        3.40291428e-03, 3.41042690e-03, 3.41795028e-03, 3.42548531e-03,
#        3.43303292e-03, 3.44059359e-03, 3.44816039e-03, 3.45573126e-03,
#        3.46330702e-03, 3.47088850e-03, 3.47847656e-03, 3.48607204e-03,
#        3.49367580e-03, 3.50128873e-03, 3.50891171e-03, 3.51654562e-03,
#        3.52419137e-03, 3.53184988e-03, 3.53952083e-03, 3.54719673e-03,
#        3.55487685e-03, 3.56256201e-03, 3.57025305e-03, 3.57795082e-03,
#        3.58565617e-03, 3.59336998e-03, 3.60109312e-03, 3.60882648e-03,
#        3.61657096e-03, 3.62432746e-03, 3.63209690e-03, 3.63987774e-03,
#        3.64766276e-03, 3.65545214e-03, 3.66324672e-03, 3.67104734e-03,
#        3.67885484e-03, 3.68667010e-03, 3.69449398e-03, 3.70232736e-03,
#        3.71017113e-03, 3.71802620e-03, 3.72589348e-03, 3.73377388e-03,
#        3.74166423e-03, 3.74955838e-03, 3.75745705e-03, 3.76536107e-03,
#        3.77327129e-03, 3.78118856e-03, 3.78911374e-03, 3.79704772e-03,
#        3.80499136e-03, 3.81294558e-03, 3.82091127e-03, 3.82888936e-03,
#        3.83688074e-03, 3.84488021e-03, 3.85288352e-03, 3.86089150e-03,
#        3.86890499e-03, 3.87692483e-03, 3.88495189e-03, 3.89298702e-03,
#        3.90103112e-03, 3.90908506e-03, 3.91714975e-03, 3.92522609e-03,
#        3.93331502e-03, 3.94141711e-03, 3.94952561e-03, 3.95763810e-03,
#        3.96575541e-03, 3.97387839e-03, 3.98200788e-03, 3.99014475e-03,
#        3.99828987e-03, 4.00644411e-03, 4.01460838e-03, 4.02278357e-03,
#        4.03097060e-03, 4.03917039e-03, 4.04738281e-03, 4.05560036e-03,
#        4.06382205e-03, 4.07204872e-03, 4.08028121e-03, 4.08852038e-03,
#        4.09676709e-03, 4.10502221e-03, 4.11328663e-03, 4.12156125e-03,
#        4.12984698e-03, 4.13814472e-03, 4.14645541e-03, 4.15477778e-03,
#        4.16310439e-03, 4.17143531e-03, 4.17977136e-03, 4.18811339e-03,
#        4.19646225e-03, 4.20481883e-03, 4.21318399e-03, 4.22155862e-03,
#        4.22994362e-03, 4.23833991e-03, 4.24674840e-03, 4.25517003e-03,
#        4.26360194e-03, 4.27203765e-03, 4.28047781e-03, 4.28892326e-03,
#        4.29737486e-03, 4.30583345e-03, 4.31429992e-03, 4.32277514e-03,
#        4.33126001e-03, 4.33975543e-03, 4.34826231e-03, 4.35678158e-03,
#        4.36531418e-03, 4.37385524e-03, 4.38240007e-03, 4.39094950e-03,
#        4.39950438e-03, 4.40806557e-03, 4.41663392e-03, 4.42521031e-03,
#        4.43379562e-03, 4.44239076e-03, 4.45099662e-03, 4.45961413e-03,
#        4.46824422e-03, 4.47688758e-03, 4.48553763e-03, 4.49419160e-03,
#        4.50285033e-03, 4.51151467e-03, 4.52018547e-03, 4.52886360e-03,
#        4.53754994e-03, 4.54624538e-03, 4.55495081e-03, 4.56366715e-03,
#        4.57239532e-03, 4.58113626e-03, 4.58989000e-03, 4.59864906e-03,
#        4.60741219e-03, 4.61618025e-03, 4.62495407e-03, 4.63373452e-03,
#        4.64252246e-03, 4.65131878e-03, 4.66012437e-03, 4.66894013e-03,
#        4.67776698e-03, 4.68660584e-03, 4.69545765e-03, 4.70432139e-03,
#        4.71318948e-03, 4.72206180e-03, 4.73093921e-03, 4.73982254e-03,
#        4.74871266e-03, 4.75761044e-03, 4.76651677e-03, 4.77543254e-03,
#        4.78435866e-03, 4.79329605e-03, 4.80224564e-03, 4.81120837e-03,
#        4.82018170e-03, 4.82915885e-03, 4.83814039e-03, 4.84712717e-03,
#        4.85612003e-03, 4.86511985e-03, 4.87412750e-03, 4.88314387e-03,
#        4.89216985e-03, 4.90120637e-03, 4.91025433e-03, 4.91931468e-03])

# %%
from matplotlib.pyplot import subplot

# ...existing code...
fig, ax = plt.subplots(1, 2, figsize=(14, 5))



# Subplot 1
ax[0].plot(core_radius_range_test * 1e6, denominator_noise_test,
           label='Denominator (Noise)', color='red')
ax[0].set_xlabel('Core radius (µm)')
ax[0].set_ylabel('Value (arbitrary units)')
# ax[0].set_ylim(-1e-17, 1e-13) # Adjust y-axis limits for better visibility of the noise components

ax[0].legend()

# Subplot 2
ax[1].plot(core_radius_range_test * 1e6, numerator_noise_test,
           label='Numerator (Noise)', color='orange')
ax[1].set_xlabel('Core radius (µm)')
ax[1].set_ylabel('Value (arbitrary units)')
# ax[1].set_ylim(-1e-17, 1e-13) # Adjust y-axis limits for better visibility of the noise components
ax[1].legend()

fig.tight_layout()

plt.show()

# %%
# Separate figure for ratio

plt.figure(figsize=(8, 4))
plt.plot(core_radius_range_test * 1e6,
         numerator_noise_test / denominator_noise_test,
         label='Numerator / Denominator (Noise)', color='purple')
plt.xlabel('Core radius (µm)')
plt.ylabel('Value (arbitrary units)')
plt.title('Numerator / Denominator for Noise vs Core Radius')
plt.xlim(5,5.75) # zoom in to the single-mode cutoff region
plt.ylim(0.00023, 0.00024) # limit y-axis to better visualize the behaviour near cutoff
plt.legend()
plt.tight_layout()
plt.show()
# ...existing code...

# %%
index_signal_test = np.argmax(efficiency_signal_test)
print(f'The most optimal radius occurs at {core_radius_range_test[index_signal_test]} µm with an efficiency of {efficiency_signal_test[index_signal_test]}.' )
# Out:
# The most optimal radius occurs at 5.645245245245245e-06 µm with an efficiency of 0.7610876997058391.

# %%
plt.figure(figsize=(12,6))
plt.plot(core_radius_range_test * 1e6, efficiency_signal_test, label='Efficiency Signal Only', color='blue')
plt.scatter(core_radius_range_test[index_signal_test] * 1e6, efficiency_signal_test[index_signal_test], color='red', marker = 'x',
            label=f'Max Efficiency Signal: {efficiency_signal_test[index_signal_test]:.4f} at a={core_radius_range_test[index_signal_test]*1e6:.2f} µm')
# plt.plot(core_radius_range_test, efficiency_noise_test, label='Efficiency Noise Only (η_noise)', color='red')
# plt.plot(core_radius_range_test, efficiency_signal_test / np.sqrt(efficiency_noise_test), label='Efficiency Coefficient (η_signal / sqrt(η_noise))', color='purple')
plt.xlabel('Core radius (µm)')
plt.ylabel('Efficiency')
plt.legend()

# %%
plt.figure(figsize=(12,6))
plt.plot(V_norm, efficiency_signal_test, label='Efficiency Signal Only', color='blue')
plt.scatter(V_norm[index_signal_test], efficiency_signal_test[index_signal_test], color='red', marker = 'x',
            label=f'Max Efficiency Signal: {efficiency_signal_test[index_signal_test]:.4f} at V={V_norm[index_signal_test]:.2f}')
# plt.plot(core_radius_range_test, efficiency_noise_test, label='Efficiency Noise Only (η_noise)', color='red')
# plt.plot(core_radius_range_test, efficiency_signal_test / np.sqrt(efficiency_noise_test), label='Efficiency Coefficient (η_signal / sqrt(η_noise))', color='purple')
plt.xlabel('V-number')
plt.ylabel('Efficiency')
plt.legend()

# %%
plt.figure(figsize=(12,6))
plt.plot(core_radius_range_test, efficiency_signal_test, label='Efficiency Signal Only', color='blue')
plt.plot(core_radius_range_test, efficiency_noise_test, label='Efficiency Noise Only (η_noise)', color='red')
plt.plot(core_radius_range_test, efficiency_signal_test / np.sqrt(efficiency_noise_test), label='Efficiency Coefficient (η_signal / sqrt(η_noise))', color='purple')
plt.xlabel('Core radius (m)')
plt.ylabel('Efficiency')
plt.xlim(4e-6, 6e-6)
plt.legend()

# %%
plt.figure(figsize=(12,6))
# plt.plot(core_radius_range_test, efficiency_signal_test, label='Efficiency Signal Only', color='blue')
plt.plot(core_radius_range_test, efficiency_noise_test, label='Efficiency Noise Only (η_noise)', color='red')
# plt.plot(core_radius_range_test, efficiency_signal_test / np.sqrt(efficiency_noise_test), label='Efficiency Coefficient (η_signal / sqrt(η_noise))', color='purple')
plt.xlabel('Core radius (m)')
plt.ylabel('Efficiency')
# plt.ylim(0, 0.2)
# plt.xlim(4e-6, 6e-6)
plt.legend()

# %%
efficiency_coefficient.shape
# Out:
# (1484,)

# %%
I_flat = 1 **2 # flat intensity of the background noise across the fibre input plane, in normalised units

rad_to_arcsec = (180 / np.pi) * 3600 # conversion factor from radians to arcseconds

plate_scale_coude = rad_to_arcsec / (F_focus * D_M1) # in arcseconds per meter at the focal plane
plate_scale_demag = plate_scale_coude / Magnification # in arcseconds per meter at the fibre input plane


Signal_test_array = np.zeros_like(core_radius_range_test)
Background_test_array = np.zeros_like(core_radius_range_test)
snr_test_array = np.zeros_like(core_radius_range_test)
FOV_test_array = np.zeros_like(core_radius_range_test)


for i, a in enumerate(core_radius_range_test): 
    fibre_r = np.linspace(0, cladding_radius_max, 10000)
    # core_mask = fibre_r <= a # Create a mask for the core region where the fibre can couple light
    E_image, I_image = demagnified_diffraction_limited_E_field(fibre_r, lam0, F_focus, alpha, E_S, Magnification)
    FOV_value = plate_scale_demag * 2*a
    # Signal_test = 2*np.pi * integrate.simpson(I_image[core_mask] * fibre_r[core_mask], x=fibre_r[core_mask])
    Signal_test = 2*np.pi * integrate.simpson(I_image * fibre_r, x=fibre_r)
    Background_test = np.pi * I_flat * (FOV_value / 2) **2
    snr_test = Signal_test / np.sqrt(Background_test)

    FOV_test_array[i] = FOV_value
    Signal_test_array[i] = Signal_test
    Background_test_array[i] = Background_test
    snr_test_array[i] = snr_test

# %%
plt.plot(core_radius_range_test, Signal_test_array, label='Signal', color='green')
plt.xlabel('Core radius (m)')
plt.ylabel('Flux density (counts / s / m$^2$)')
plt.title('Signal vs Core Radius')
# Out:
# Text(0.5, 1.0, 'Signal vs Core Radius')

# %%
plt.plot(core_radius_range_test, Background_test_array, label='Background', color='red')
plt.xlabel('Core radius (m)')
plt.ylabel('Flux density (counts / s / m$^2$)')
# Out:
# Text(0, 0.5, 'Flux density (counts / s / m$^2$)')

# %%
# relative_signal_test = efficiency_signal_test * Signal_test_array
# relative_background_test = efficiency_noise_test * Background_test_array

# %%
efficiency_coefficient_test = np.divide(efficiency_signal_test, np.sqrt(efficiency_noise_test))

# %%
relative_snr_test = np.multiply(efficiency_coefficient_test, snr_test_array)
argmax_relative_snr_test = np.argmax(relative_snr_test)
print(f'The most optimal radius occurs at {core_radius_range[argmax_relative_snr_test]} with a relative SNR of {relative_snr_test[argmax_relative_snr_test]:.4e}.' )
# Out:
# The most optimal radius occurs at 5.028e-06 with a relative SNR of 8.3564e-08.

# %%
plt.plot(core_radius_range_test, efficiency_coefficient_test * snr_test_array, label='Efficiency Coefficient (η / sqrt(η_noise))')
plt.scatter(core_radius_range_test[argmax_relative_snr_test], relative_snr_test[argmax_relative_snr_test], color='red', marker = 'x',
            label=f'Max Relative SNR: {relative_snr_test[argmax_relative_snr_test]:.4e} at a={core_radius_range_test[argmax_relative_snr_test]*1e6:.2f} µm')
plt.xlabel('Core radius (m)')
plt.ylabel('Value (arbitrary units)')
plt.legend()

# %%
plt.plot(core_radius_range_test, efficiency_coefficient_test * snr_test_array, label='Efficiency Coefficient (η / sqrt(η_noise))')
plt.scatter(core_radius_range_test[argmax_relative_snr_test], relative_snr_test[argmax_relative_snr_test], color='red', marker = 'x',
            label=f'Max Relative SNR: {relative_snr_test[argmax_relative_snr_test]:.4e} at a={core_radius_range_test[argmax_relative_snr_test]*1e6:.2f} µm')
plt.xlabel('Core radius (m)')
plt.ylabel('Value (arbitrary units)')
plt.xlim(1e-6, 5e-6)
plt.legend()

# %%
print(f"Maximum relative SNR occurs at core radius = {core_radius_range_test[argmax_relative_snr_test]*1e6:.2f} microns with a relative SNR of {relative_snr_test[argmax_relative_snr_test]:.4e}.")
# Out:
# Maximum relative SNR occurs at core radius = 3.94 microns with a relative SNR of 8.3564e-08.

# %% [markdown]
# ### What if we limit the integral to core radius?

# %%
# I_flat = 1 **2 # flat intensity of the background noise across the fibre input plane, in normalised units

# Signal_test_array = np.zeros_like(core_radius_range_test)
# Background_test_array = np.zeros_like(core_radius_range_test)
# snr_test_array = np.zeros_like(core_radius_range_test)
# FOV_test_array = np.zeros_like(core_radius_range_test)


# for i, a in enumerate(core_radius_range_test): 
#     fibre_r = np.linspace(0, cladding_radius_max, 10000)
#     core_mask = fibre_r <= a # Create a mask for the core region where the fibre can couple light
#     E_image, I_image = demagnified_diffraction_limited_E_field(fibre_r, lam0, F_focus, alpha, E_S, Magnification)
#     FOV_value = plate_scale_demag * 2*a
#     Signal_test = 2*np.pi * integrate.simpson(I_image[core_mask] * fibre_r[core_mask], x=fibre_r[core_mask])
#     # Signal_test = 2*np.pi * integrate.simpson(I_image * fibre_r, x=fibre_r)
#     Background_test = np.pi * I_flat * (FOV_value / 2) **2
#     snr_test = Signal_test / np.sqrt(Background_test)
#     FOV_test_array[i] = FOV_value
#     Signal_test_array[i] = Signal_test
#     Background_test_array[i] = Background_test
#     snr_test_array[i] = snr_test

# %%
# plt.plot(core_radius_range_test, Signal_test_array, label='Signal', color='green')
# plt.xlabel('Core radius (m)')
# plt.ylabel('Flux density (counts / s / m$^2$)')
# plt.title('Signal vs Core Radius')

# %%
# plt.plot(core_radius_range_test, Background_test_array, label='Background', color='red')
# plt.xlabel('Core radius (m)')
# plt.ylabel('Flux density (counts / s / m$^2$)')

# %%
# relative_signal_test = efficiency_signal_test * Signal_test_array
# relative_background_test = efficiency_noise_test * Background_test_array

# %%
# plt.plot(core_radius_range_test, relative_signal_test, label='Relative Signal', color='green')

# plt.ylabel('Flux density (counts / s / m$^2$)')
# plt.xlabel('Core radius (m)')

# %%
# plt.plot(core_radius_range_test, relative_background_test, label='Relative Background', color='red')
# plt.xlabel('Core radius (m)')
# plt.ylabel('Flux density (counts / s / m$^2$)')

# %%
# efficiency_coefficient_test = np.divide(efficiency_signal_test, np.sqrt(efficiency_noise_test))

# %%
# plt.plot(core_radius_range_test, relative_background_test, label='Relative Background', color='red')
# plt.xlabel('Core radius (m)')
# plt.ylabel('SNR ratio')

# %%
# relative_snr_test = np.multiply(efficiency_coefficient_test, snr_test_array)
# argmax_relative_snr_test = np.argmax(relative_snr_test)
# print(f'The most optimal radius occurs at {core_radius_range[argmax_relative_snr_test]} with a relative SNR of {relative_snr_test[argmax_relative_snr_test]:.4e}.' )

# %%
# plt.plot(core_radius_range_test, efficiency_coefficient_test * snr_test_array, label='Efficiency Coefficient (η / sqrt(η_noise))')
# plt.scatter(core_radius_range_test[argmax_relative_snr_test], relative_snr_test[argmax_relative_snr_test], color='red', marker = 'x',
#             label=f'Max Relative SNR: {relative_snr_test[argmax_relative_snr_test]:.4e} at a={core_radius_range_test[argmax_relative_snr_test]*1e6:.2f} µm')
# plt.xlabel('Core radius (m)')
# plt.ylabel('Value (arbitrary units)')
# plt.legend()
